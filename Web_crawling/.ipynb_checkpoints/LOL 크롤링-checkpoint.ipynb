# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep

# %%
delay = 5
driver = webdriver.Chrome('./chromedriver.exe')
driver.get('https://www.leagueofgraphs.com/rankings/blue-vs-red/na')
sleep(delay)

# %%
x=driver.find_element_by_xpath('//*[@id="mainContent"]/div[2]/div[2]/div/div/div/table/tbody')

# %%
trs = x.find_elements_by_xpath('.//tr')

# %%
arr = list()

# %%
for tr in trs[1:]:
    name=tr.find_element_by_xpath('.//img').get_attribute('alt')
    td=tr.find_element_by_xpath('./td[2]')
    blue_rate = td.find_element_by_xpath('./div[1]/progressbar').get_attribute('data-value')
    red_rate = td.find_element_by_xpath('./div[2]/progressbar').get_attribute('data-value')
    arr.append([name,blue_rate,red_rate])

# %%
arr
# Out:
# [['Sivir', '0.5144', '0.4623'],
#  ['Fizz', '0.5482', '0.5006'],
#  ['Poppy', '0.4808', '0.5277'],
#  ['Corki', '0.4972', '0.453'],
#  ['Varus', '0.4661', '0.4221'],
#  ['Neeko', '0.4961', '0.5398'],
#  ['Brand', '0.5192', '0.4781'],
#  ['Renekton', '0.4791', '0.5185'],
#  ['Yorick', '0.5183', '0.4801'],
#  ['Rumble', '0.5412', '0.5037'],
#  ['Lissandra', '0.4831', '0.5199'],
#  ['Vi', '0.5153', '0.4788'],
#  ['Trundle', '0.5049', '0.469'],
#  ['Camille', '0.5225', '0.4894'],
#  ['Zyra', '0.5114', '0.4785'],
#  ['Sejuani', '0.4946', '0.4626'],
#  ['Tryndamere', '0.5069', '0.4755'],
#  ['Fiddlesticks', '0.5067', '0.5362'],
#  ["Vel'Koz", '0.507', '0.5355'],
#  ['Zilean', '0.5355', '0.5076'],
#  ['Garen', '0.5163', '0.4885'],
#  ['Ekko', '0.5149', '0.4876'],
#  ['Nocturne', '0.5258', '0.4988'],
#  ['Veigar', '0.5169', '0.4907'],
#  ['Nasus', '0.5119', '0.4859'],
#  ['Quinn', '0.525', '0.5'],
#  ['Gragas', '0.4828', '0.4582'],
#  ['Xerath', '0.5253', '0.5012'],
#  ['Soraka', '0.4843', '0.5081'],
#  ['Cassiopeia', '0.5252', '0.5485'],
#  ['Rengar', '0.5026', '0.5258'],
#  ['Tristana', '0.4874', '0.4642'],
#  ['Pyke', '0.4799', '0.503'],
#  ["Rek'Sai", '0.5278', '0.5048'],
#  ['Kayle', '0.5022', '0.5248'],
#  ['Sion', '0.4989', '0.4764'],
#  ['Evelynn', '0.4757', '0.4982'],
#  ['Riven', '0.4993', '0.5216'],
#  ['Zac', '0.5094', '0.4875'],
#  ['Katarina', '0.5143', '0.5361'],
#  ['Aatrox', '0.4821', '0.4604'],
#  ["Cho'Gath", '0.4816', '0.4609'],
#  ['Aphelios', '0.4486', '0.4688'],
#  ['Hecarim', '0.5301', '0.5106'],
#  ['Braum', '0.5141', '0.4947'],
#  ['Master Yi', '0.5', '0.4808'],
#  ['Jayce', '0.4621', '0.4809'],
#  ['Gangplank', '0.4615', '0.4793'],
#  ['Udyr', '0.4772', '0.4947'],
#  ['Yone', '0.4912', '0.4742'],
#  ['Jhin', '0.5197', '0.5028'],
#  ['Rammus', '0.5262', '0.5098'],
#  ['Urgot', '0.5149', '0.5312'],
#  ['Kayn', '0.5053', '0.5215'],
#  ['Annie', '0.52', '0.5041'],
#  ['Skarner', '0.5304', '0.5147'],
#  ['Shyvana', '0.5173', '0.5329'],
#  ['Anivia', '0.4908', '0.506'],
#  ['Elise', '0.5108', '0.4956'],
#  ['Zed', '0.5078', '0.5227'],
#  ['Maokai', '0.5217', '0.5075'],
#  ['Volibear', '0.5057', '0.4917'],
#  ['Lee Sin', '0.4701', '0.4562'],
#  ['Nidalee', '0.4777', '0.4639'],
#  ['Yuumi', '0.5062', '0.4927'],
#  ['Orianna', '0.4757', '0.4885'],
#  ['Taliyah', '0.544', '0.5314'],
#  ['Lux', '0.5161', '0.5036'],
#  ['Leona', '0.5133', '0.5008'],
#  ['Talon', '0.536', '0.5483'],
#  ['Kennen', '0.4895', '0.4772'],
#  ['Galio', '0.5337', '0.5221'],
#  ['Akali', '0.4731', '0.4615'],
#  ['Sona', '0.5104', '0.4989'],
#  ['Graves', '0.4927', '0.504'],
#  ['Senna', '0.5141', '0.5028'],
#  ['Vladimir', '0.4995', '0.5104'],
#  ["Kai'Sa", '0.4941', '0.4834'],
#  ['Shaco', '0.5333', '0.5226'],
#  ['Morgana', '0.5126', '0.5021'],
#  ['Karma', '0.4675', '0.4571'],
#  ['Teemo', '0.5031', '0.4929'],
#  ['Olaf', '0.5134', '0.5233'],
#  ['Irelia', '0.4655', '0.4559'],
#  ['Ahri', '0.5123', '0.5219'],
#  ['Lillia', '0.4859', '0.4765'],
#  ['Thresh', '0.4987', '0.4893'],
#  ['Warwick', '0.5238', '0.5145'],
#  ['Karthus', '0.5112', '0.5205'],
#  ['Dr. Mundo', '0.5092', '0.5185'],
#  ['Azir', '0.4394', '0.4302'],
#  ['Kalista', '0.4862', '0.4771'],
#  ['Ivern', '0.49', '0.481'],
#  ['Xayah', '0.4807', '0.4717'],
#  ['Blitzcrank', '0.5304', '0.5217'],
#  ['LeBlanc', '0.46', '0.4686'],
#  ['Lucian', '0.4857', '0.4775'],
#  ['Swain', '0.4948', '0.503'],
#  ['Jax', '0.4899', '0.498'],
#  ['Miss Fortune', '0.5245', '0.5165'],
#  ['Alistar', '0.5199', '0.5279'],
#  ['Jarvan IV', '0.5046', '0.4968'],
#  ['Xin Zhao', '0.4775', '0.4852'],
#  ['Viktor', '0.5035', '0.4961'],
#  ['Draven', '0.509', '0.5018'],
#  ['Singed', '0.5089', '0.5161'],
#  ['Diana', '0.5088', '0.5017'],
#  ['Kled', '0.5113', '0.5045'],
#  ['Malphite', '0.5043', '0.4976'],
#  ['Wukong', '0.5227', '0.5164'],
#  ['Nunu & Willump', '0.5268', '0.5205'],
#  ['Heimerdinger', '0.5106', '0.5169'],
#  ['Samira', '0.4959', '0.5019'],
#  ['Taric', '0.5263', '0.5203'],
#  ['Malzahar', '0.4971', '0.4913'],
#  ['Amumu', '0.5172', '0.5115'],
#  ['Qiyana', '0.4622', '0.4677'],
#  ['Janna', '0.5112', '0.5061'],
#  ['Vayne', '0.5121', '0.5171'],
#  ["Kha'Zix", '0.5192', '0.5142'],
#  ['Kassadin', '0.5122', '0.5077'],
#  ['Caitlyn', '0.4956', '0.4911'],
#  ['Zoe', '0.4855', '0.4899'],
#  ['Nautilus', '0.49', '0.4942'],
#  ['Twitch', '0.5154', '0.5194'],
#  ['Shen', '0.5151', '0.5112'],
#  ["Kog'Maw", '0.4887', '0.4925'],
#  ['Ziggs', '0.5058', '0.5022'],
#  ['Kindred', '0.502', '0.5053'],
#  ['Gnar', '0.4756', '0.4789'],
#  ['Mordekaiser', '0.4893', '0.4924'],
#  ['Sylas', '0.4721', '0.4692'],
#  ['Nami', '0.4919', '0.4944'],
#  ['Pantheon', '0.495', '0.4925'],
#  ['Aurelion Sol', '0.5063', '0.5041'],
#  ['Bard', '0.5133', '0.5111'],
#  ['Rakan', '0.4956', '0.4935'],
#  ['Lulu', '0.5133', '0.5154'],
#  ['Jinx', '0.5233', '0.5254'],
#  ['Darius', '0.5247', '0.5264'],
#  ['Ryze', '0.5018', '0.5032'],
#  ['Fiora', '0.5148', '0.5135'],
#  ['Tahm Kench', '0.4488', '0.4498'],
#  ['Syndra', '0.4737', '0.4727'],
#  ['Sett', '0.4755', '0.4763'],
#  ['Ashe', '0.5078', '0.507'],
#  ['Twisted Fate', '0.4813', '0.4819'],
#  ['Yasuo', '0.5022', '0.5018'],
#  ['Illaoi', '0.5129', '0.5125'],
#  ['Ornn', '0.4786', '0.4783'],
#  ['Ezreal', '0.4718', '0.4721']]

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame

# %%
dataframe= dataframe(arr,columns=['Champion','Blue W_R','Red W_R'])

# %%
dataframe
# Out:
#          Champion Blue W_R Red W_R
# 0           Sivir   0.5144  0.4623
# 1            Fizz   0.5482  0.5006
# 2           Poppy   0.4808  0.5277
# 3           Corki   0.4972   0.453
# 4           Varus   0.4661  0.4221
# ..            ...      ...     ...
# 146  Twisted Fate   0.4813  0.4819
# 147         Yasuo   0.5022  0.5018
# 148        Illaoi   0.5129  0.5125
# 149          Ornn   0.4786  0.4783
# 150        Ezreal   0.4718  0.4721
#
# [151 rows x 3 columns]

# %%
driver.get('https://www.leagueofgraphs.com/rankings/afk-stats/na')

# %%
x=driver.find_element_by_xpath('//*[@id="mainContent"]/div/div[2]/div/table/tbody')

# %%
trs = x.find_elements_by_xpath('.//tr')

# %%
arr2=list()

# %%
for tr in trs[1:]:
    name=tr.find_element_by_xpath('.//img').get_attribute('alt')
    td=tr.find_element_by_xpath('./td[2]')
    AFK_rate = td.find_element_by_xpath('./progressbar').get_attribute('data-value')
    arr2.append([name,AFK_rate])

# %%
arr2
# Out:
# [['Rengar', '0.010643591914877031'],
#  ['Jayce', '0.009917936940877507'],
#  ['Kennen', '0.008926304276315645'],
#  ['Yasuo', '0.008758322011035172'],
#  ['Irelia', '0.008733646852719714'],
#  ['Xin Zhao', '0.008702762836906207'],
#  ['Draven', '0.008638229923542066'],
#  ['Udyr', '0.008177328203716291'],
#  ['Master Yi', '0.008170227804314496'],
#  ['Olaf', '0.00808129317366259'],
#  ['Talon', '0.007983822528733133'],
#  ['Tahm Kench', '0.007880009596040427'],
#  ['Aatrox', '0.007865272861388118'],
#  ["Kog'Maw", '0.007750357171930618'],
#  ['Zed', '0.0077421962643155345'],
#  ['Jax', '0.007673597755459521'],
#  ['Varus', '0.007537001722052061'],
#  ['Akali', '0.007523991162016828'],
#  ['Sett', '0.007522418417084242'],
#  ['Darius', '0.00748621383953767'],
#  ['Kindred', '0.007470291280599965'],
#  ['Mordekaiser', '0.0074151866863902665'],
#  ['Tryndamere', '0.007406362008859665'],
#  ['Lee Sin', '0.0072746473318935695'],
#  ['Aphelios', '0.007247953493186781'],
#  ['Qiyana', '0.007242517813908879'],
#  ['Kled', '0.007209759109923169'],
#  ['Nasus', '0.007161723385405576'],
#  ['Riven', '0.007158835321910176'],
#  ['Kayn', '0.0071303714877387625'],
#  ['Yone', '0.007118259209441412'],
#  ['Camille', '0.007086754636154543'],
#  ['Karthus', '0.006961785005532034'],
#  ['Warwick', '0.006950234091511214'],
#  ['Heimerdinger', '0.0068885389458224295'],
#  ["Cho'Gath", '0.006882195731612079'],
#  ['Volibear', '0.006869867542751225'],
#  ['Cassiopeia', '0.006826705151034893'],
#  ['Gnar', '0.006777095060077126'],
#  ['Wukong', '0.006716049326364948'],
#  ['Katarina', '0.006708864778026316'],
#  ['Vladimir', '0.00670499191324144'],
#  ["Kha'Zix", '0.006626709052423392'],
#  ['Tristana', '0.006579117640715533'],
#  ['Graves', '0.006533855323086069'],
#  ['Gangplank', '0.006496668820686885'],
#  ['Poppy', '0.006462726379154026'],
#  ['Lucian', '0.006442724507947129'],
#  ['Teemo', '0.006439942133010221'],
#  ['Evelynn', '0.0064133639138909005'],
#  ['Jarvan IV', '0.006407968433188822'],
#  ['Renekton', '0.0063856122869715756'],
#  ['Nidalee', '0.006328763743356822'],
#  ['Twitch', '0.006323188907027999'],
#  ['Kalista', '0.00632114013706216'],
#  ['Sylas', '0.006295785967881964'],
#  ['Taliyah', '0.006288978418625302'],
#  ['Pyke', '0.0062746925161965075'],
#  ['Illaoi', '0.006274300425637761'],
#  ['Kayle', '0.006266570854425755'],
#  ['Trundle', '0.006236976735856575'],
#  ['Ryze', '0.006209115395762685'],
#  ['Fiora', '0.006207747428814955'],
#  ['Twisted Fate', '0.006159012793460575'],
#  ['Ekko', '0.006100267547378008'],
#  ['LeBlanc', '0.006098121923012512'],
#  ['Garen', '0.006030517986371893'],
#  ['Veigar', '0.006023112300064407'],
#  ['Zoe', '0.00597795980544736'],
#  ['Ivern', '0.005976360707014338'],
#  ['Nocturne', '0.005968854032977547'],
#  ['Shaco', '0.0059686525330869475'],
#  ['Azir', '0.005961434787922671'],
#  ['Fizz', '0.005913700716697988'],
#  ['Shyvana', '0.005878208579760673'],
#  ['Pantheon', '0.005876964891254326'],
#  ['Neeko', '0.005836860917446828'],
#  ['Yorick', '0.005833159688211574'],
#  ['Xayah', '0.0058317401714509266'],
#  ['Xerath', '0.0057796939503836735'],
#  ["Kai'Sa", '0.005761719756956658'],
#  ["Rek'Sai", '0.005761649906870452'],
#  ['Sion', '0.005725746530837911'],
#  ['Quinn', '0.00570669914852069'],
#  ['Singed', '0.005695302294447016'],
#  ['Blitzcrank', '0.005686690177802535'],
#  ['Kassadin', '0.005658984495939046'],
#  ['Dr. Mundo', '0.005644225483066697'],
#  ['Vayne', '0.005636819197833297'],
#  ['Diana', '0.005635829716577781'],
#  ['Ornn', '0.0055922878016429365'],
#  ['Sivir', '0.005578738631544444'],
#  ['Karma', '0.005435615184186043'],
#  ['Nunu & Willump', '0.005400863974016114'],
#  ['Braum', '0.005337222456615973'],
#  ['Malphite', '0.005311012369393212'],
#  ['Elise', '0.005293174569127923'],
#  ['Jhin', '0.005243798440363698'],
#  ['Shen', '0.005200737400226624'],
#  ['Amumu', '0.005144259653386702'],
#  ['Fiddlesticks', '0.005138717987508941'],
#  ['Hecarim', '0.005103244445348421'],
#  ['Yuumi', '0.0051007472883750965'],
#  ['Lillia', '0.005040430267646655'],
#  ['Rammus', '0.005005781423414249'],
#  ['Urgot', '0.0049684999201024555'],
#  ['Lux', '0.004967054296350489'],
#  ['Nautilus', '0.0049546549976281235'],
#  ['Ashe', '0.0049528038817421155'],
#  ['Samira', '0.004927237237136879'],
#  ['Annie', '0.004922651605603535'],
#  ['Aurelion Sol', '0.004907015818034776'],
#  ['Vi', '0.004863756500484385'],
#  ['Morgana', '0.004774029807084172'],
#  ['Ezreal', '0.004773421832639596'],
#  ['Gragas', '0.004758987764950944'],
#  ['Thresh', '0.004757537297832911'],
#  ['Galio', '0.004685551898393217'],
#  ['Syndra', '0.004679066190583301'],
#  ['Brand', '0.004673164097055304'],
#  ['Rumble', '0.004671377942261661'],
#  ['Ziggs', '0.0046675992121922045'],
#  ['Senna', '0.004665014909633518'],
#  ['Sejuani', '0.004601640095007643'],
#  ['Skarner', '0.0045852097794398155'],
#  ['Ahri', '0.004582371838393541'],
#  ['Zilean', '0.004576838947792968'],
#  ['Miss Fortune', '0.00456327945287925'],
#  ['Swain', '0.0045563195670844745'],
#  ['Malzahar', '0.004546703773603457'],
#  ['Jinx', '0.00452970396252496'],
#  ['Rakan', '0.004480929300620914'],
#  ['Janna', '0.004474235270989334'],
#  ['Lissandra', '0.004436977344354977'],
#  ['Bard', '0.004408633952064964'],
#  ['Orianna', '0.0044002283211107'],
#  ['Anivia', '0.004388917004400811'],
#  ['Alistar', '0.004377678696138398'],
#  ['Viktor', '0.0043700422203549446'],
#  ['Taric', '0.004355339319007031'],
#  ['Corki', '0.004238141126140322'],
#  ['Maokai', '0.004195453942945052'],
#  ["Vel'Koz", '0.004193450413954024'],
#  ['Caitlyn', '0.0041454230161482'],
#  ['Soraka', '0.00410582985838712'],
#  ['Zac', '0.004096259036223872'],
#  ['Sona', '0.003948399676623988'],
#  ['Zyra', '0.0037029065066175463'],
#  ['Leona', '0.0035512555450598338'],
#  ['Lulu', '0.003100822225712524'],
#  ['Nami', '0.003045045688561811']]

# %%
dataframe2=pd.DataFrame(arr2,columns=['Champion','AFK rate'])

# %%
dataframe2
# Out:
#     Champion               AFK rate
# 0     Rengar   0.010643591914877031
# 1      Jayce   0.009917936940877507
# 2     Kennen   0.008926304276315645
# 3      Yasuo   0.008758322011035172
# 4     Irelia   0.008733646852719714
# ..       ...                    ...
# 146     Sona   0.003948399676623988
# 147     Zyra  0.0037029065066175463
# 148    Leona  0.0035512555450598338
# 149     Lulu   0.003100822225712524
# 150     Nami   0.003045045688561811
#
# [151 rows x 2 columns]

# %%
table = dataframe.merge(dataframe2, how='outer')

# %%
table
# Out:
#          Champion Blue W_R Red W_R               AFK rate
# 0           Sivir   0.5144  0.4623   0.005578738631544444
# 1            Fizz   0.5482  0.5006   0.005913700716697988
# 2           Poppy   0.4808  0.5277   0.006462726379154026
# 3           Corki   0.4972   0.453   0.004238141126140322
# 4           Varus   0.4661  0.4221   0.007537001722052061
# ..            ...      ...     ...                    ...
# 146  Twisted Fate   0.4813  0.4819   0.006159012793460575
# 147         Yasuo   0.5022  0.5018   0.008758322011035172
# 148        Illaoi   0.5129  0.5125   0.006274300425637761
# 149          Ornn   0.4786  0.4783  0.0055922878016429365
# 150        Ezreal   0.4718  0.4721   0.004773421832639596
#
# [151 rows x 4 columns]

# %%
table['Champion'].
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# Name: Champion, Length: 151, dtype: bool

# %%
len(data)
# Out:
# 919200

# %%
data
# Out:
# [{'gameId': 3508539941,
#   'summonerName': 'Isla',
#   'championId': 3,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3508539941,
#   'summonerName': 'slug 95',
#   'championId': 13,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3508539941,
#   'summonerName': '2019MMMMM',
#   'championId': 25,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3508539941,
#   'summonerName': '김태민 사생팬',
#   'championId': 164,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3508539941,
#   'summonerName': '미국인김성운',
#   'championId': 51,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3508539941,
#   'summonerName': '다딱이인생',
#   'championId': 38,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3508539941,
#   'summonerName': '싯카리 시로 용준',
#   'championId': 60,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3508539941,
#   'summonerName': 'Rep1ica',
#   'championId': 6,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3508539941,
#   'summonerName': 'breave heart',
#   'championId': 44,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3508539941,
#   'summonerName': '추억속의 미련',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3510680882,
#   'summonerName': '암스오 장인',
#   'championId': 12,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3510680882,
#   'summonerName': '강블린',
#   'championId': 56,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3510680882,
#   'summonerName': '탈리야합니다',
#   'championId': 112,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3510680882,
#   'summonerName': 'zhiqiang   HuYa',
#   'championId': 91,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3510680882,
#   'summonerName': '진쏘뤼',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3510680882,
#   'summonerName': 'qubp',
#   'championId': 497,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3510680882,
#   'summonerName': 'Kanavi',
#   'championId': 126,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3510680882,
#   'summonerName': 'yaturi',
#   'championId': 236,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3510680882,
#   'summonerName': '해바라기씨',
#   'championId': 7,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3510680882,
#   'summonerName': 'bbq HeoKong',
#   'championId': 6,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3510731607,
#   'summonerName': 'ESS Glorie',
#   'championId': 69,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3510731607,
#   'summonerName': 'ESS GuGer',
#   'championId': 412,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3510731607,
#   'summonerName': '아무도알지못해날',
#   'championId': 39,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3510731607,
#   'summonerName': '쪼꼬맹이 꼬꼬미',
#   'championId': 38,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3510731607,
#   'summonerName': 'Thresh an Leona',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3510731607,
#   'summonerName': '진희전',
#   'championId': 112,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3510731607,
#   'summonerName': 'mangfu jdm',
#   'championId': 121,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3510731607,
#   'summonerName': 'no mistake',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3510731607,
#   'summonerName': '암스오 장인',
#   'championId': 12,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3510731607,
#   'summonerName': '해바라기씨',
#   'championId': 127,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3512273966,
#   'summonerName': 'whisper snow',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3512273966,
#   'summonerName': 'By 불비',
#   'championId': 555,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3512273966,
#   'summonerName': 'Nimm dein Leben',
#   'championId': 107,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3512273966,
#   'summonerName': '뿡 형',
#   'championId': 121,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3512273966,
#   'summonerName': '해바라기씨',
#   'championId': 127,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3512273966,
#   'summonerName': '꿀 칸',
#   'championId': 79,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3512273966,
#   'summonerName': 'z1999',
#   'championId': 236,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3512273966,
#   'summonerName': 'PACT pkt',
#   'championId': 76,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3512273966,
#   'summonerName': '나는 동생이다',
#   'championId': 266,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3512273966,
#   'summonerName': 'cCracker',
#   'championId': 7,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3514387059,
#   'summonerName': 'Jin Air Malrang',
#   'championId': 164,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3514387059,
#   'summonerName': 'C0bra',
#   'championId': 6,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3514387059,
#   'summonerName': 'LoL Tim Woon',
#   'championId': 161,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3514387059,
#   'summonerName': '어릴땐 잘했는데',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3514387059,
#   'summonerName': '돌잔치때도란잡음',
#   'championId': 245,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3514387059,
#   'summonerName': '몽키 D 펭귄',
#   'championId': 127,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3514387059,
#   'summonerName': '김태민 사생팬',
#   'championId': 5,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3514387059,
#   'summonerName': 'tnedifnoc syawla',
#   'championId': 51,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3514387059,
#   'summonerName': 'Destiny',
#   'championId': 412,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3514387059,
#   'summonerName': 'TOP GUY',
#   'championId': 112,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3514863366,
#   'summonerName': '미췬순발력',
#   'championId': 27,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3514863366,
#   'summonerName': 'BEE DO BEE DO',
#   'championId': 43,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3514863366,
#   'summonerName': 'Erioe',
#   'championId': 5,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3514863366,
#   'summonerName': 'AuSong',
#   'championId': 91,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3514863366,
#   'summonerName': 'kimoddiyo',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3514863366,
#   'summonerName': 'Babyy9',
#   'championId': 164,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3514863366,
#   'summonerName': 'Luniju',
#   'championId': 12,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3514863366,
#   'summonerName': 'lak and lol',
#   'championId': 157,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3514863366,
#   'summonerName': '티 신',
#   'championId': 17,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3514863366,
#   'summonerName': 'Korea5',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3514880337,
#   'summonerName': 'BEE DO BEE DO',
#   'championId': 497,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3514880337,
#   'summonerName': '그물에 든 고기',
#   'championId': 68,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3514880337,
#   'summonerName': '사나이 성민',
#   'championId': 555,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3514880337,
#   'summonerName': '미아된폼',
#   'championId': 67,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3514880337,
#   'summonerName': '캬체테',
#   'championId': 30,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3514880337,
#   'summonerName': '미췬순발력',
#   'championId': 27,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3514880337,
#   'summonerName': 'S1n9',
#   'championId': 516,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3514880337,
#   'summonerName': '아담 단발 큰 눈',
#   'championId': 92,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3514880337,
#   'summonerName': 'Korea5',
#   'championId': 236,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3514880337,
#   'summonerName': '태초의 진혼곡',
#   'championId': 45,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3515443319,
#   'summonerName': 'Christmas Time',
#   'championId': 142,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3515443319,
#   'summonerName': '미아된폼',
#   'championId': 60,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3515443319,
#   'summonerName': 'bushed',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3515443319,
#   'summonerName': '소드아트777',
#   'championId': 12,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3515443319,
#   'summonerName': '미췬순발력',
#   'championId': 27,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3515443319,
#   'summonerName': 'smile mame',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3515443319,
#   'summonerName': 'FaLSE1',
#   'championId': 113,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3515443319,
#   'summonerName': '9gnik',
#   'championId': 24,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3515443319,
#   'summonerName': 'Viod',
#   'championId': 25,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3515443319,
#   'summonerName': 'nef10',
#   'championId': 39,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3519571685,
#   'summonerName': '유렉이',
#   'championId': 201,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3519571685,
#   'summonerName': '이용2용',
#   'championId': 60,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3519571685,
#   'summonerName': '갱생연우',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3519571685,
#   'summonerName': 'Jln Alr SoHwan',
#   'championId': 266,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3519571685,
#   'summonerName': '다음시즌챌갈캐릭',
#   'championId': 14,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3519571685,
#   'summonerName': '사스갓지지',
#   'championId': 3,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3519571685,
#   'summonerName': '아담 단발 큰 눈',
#   'championId': 92,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3519571685,
#   'summonerName': 'ALLLLLLLLL',
#   'championId': 6,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3519571685,
#   'summonerName': 'Walk on the Edge',
#   'championId': 110,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3519571685,
#   'summonerName': '세체룰',
#   'championId': 117,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3523256747,
#   'summonerName': '개재석',
#   'championId': 86,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3523256747,
#   'summonerName': '세체룰',
#   'championId': 117,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3523256747,
#   'summonerName': 'Black shaco',
#   'championId': 35,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3523256747,
#   'summonerName': 'inuya',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3523256747,
#   'summonerName': '하늘별자리',
#   'championId': 8,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3523256747,
#   'summonerName': 'Just Azir',
#   'championId': 268,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3523256747,
#   'summonerName': '양학하러왔어욤',
#   'championId': 412,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3523256747,
#   'summonerName': '대마불사',
#   'championId': 79,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3523256747,
#   'summonerName': '스바라시맨',
#   'championId': 31,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3523256747,
#   'summonerName': '잉잉돈최',
#   'championId': 236,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3523290782,
#   'summonerName': '원몽이',
#   'championId': 518,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3523290782,
#   'summonerName': 'novelnandos',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3523290782,
#   'summonerName': '김태민 사생팬',
#   'championId': 6,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3523290782,
#   'summonerName': '칼날부리믜 반격',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3523290782,
#   'summonerName': 'qwerdfdrewq',
#   'championId': 53,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3523290782,
#   'summonerName': '1so1ation',
#   'championId': 555,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3523290782,
#   'summonerName': '연승하는사람',
#   'championId': 30,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3523290782,
#   'summonerName': 'NewYorkNewYork',
#   'championId': 114,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3523290782,
#   'summonerName': '카트라이더11',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3523290782,
#   'summonerName': '왔어요 동생',
#   'championId': 91,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3523306354,
#   'summonerName': 'we cant win',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3523306354,
#   'summonerName': 'Firework37',
#   'championId': 157,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3523306354,
#   'summonerName': 'Nimm dein Leben',
#   'championId': 107,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3523306354,
#   'summonerName': 'IG OOT',
#   'championId': 15,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3523306354,
#   'summonerName': '용군먹자',
#   'championId': 412,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3523306354,
#   'summonerName': '세체룰',
#   'championId': 117,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3523306354,
#   'summonerName': '프리즘스톤',
#   'championId': 103,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3523306354,
#   'summonerName': '카트라이더11',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3523306354,
#   'summonerName': 'IllllIllIllIl',
#   'championId': 164,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3523306354,
#   'summonerName': '멘탈잡은사람',
#   'championId': 24,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3527432766,
#   'summonerName': '김수민',
#   'championId': 245,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3527432766,
#   'summonerName': 'Windlolz',
#   'championId': 58,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3527432766,
#   'summonerName': '세체룰',
#   'championId': 117,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3527432766,
#   'summonerName': '왕이 되려는자',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3527432766,
#   'summonerName': 'CGA ArT',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3527432766,
#   'summonerName': '화가 잔뜩난 한규',
#   'championId': 112,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3527432766,
#   'summonerName': '분노관리병 애디',
#   'championId': 38,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3527432766,
#   'summonerName': 'rouruanerwuxie',
#   'championId': 91,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3527432766,
#   'summonerName': 'T0P MAIN',
#   'championId': 56,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3527432766,
#   'summonerName': 'lllIllIIlllllIl',
#   'championId': 26,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3527448086,
#   'summonerName': '악마의재능2',
#   'championId': 91,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3527448086,
#   'summonerName': 'Ahri OwO',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3527448086,
#   'summonerName': '꿀버섯밟아라',
#   'championId': 17,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3527448086,
#   'summonerName': 'Star Of Star',
#   'championId': 412,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3527448086,
#   'summonerName': '버터링꿀맛',
#   'championId': 421,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3527448086,
#   'summonerName': '부쉬에들어가볼까',
#   'championId': 107,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3527448086,
#   'summonerName': '죽음불꽃 태진이',
#   'championId': 25,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3527448086,
#   'summonerName': '승리가절박한사람',
#   'championId': 157,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3527448086,
#   'summonerName': '언쾅살려',
#   'championId': 121,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3527448086,
#   'summonerName': '닥인베',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3527486150,
#   'summonerName': '박둘리',
#   'championId': 112,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3527486150,
#   'summonerName': '하루치',
#   'championId': 89,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3527486150,
#   'summonerName': '효 끼',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3527486150,
#   'summonerName': '듀     코',
#   'championId': 121,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3527486150,
#   'summonerName': 'pust killer',
#   'championId': 266,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3527486150,
#   'summonerName': '버터링꿀맛',
#   'championId': 421,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3527486150,
#   'summonerName': '블리뜨크랭크',
#   'championId': 53,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3527486150,
#   'summonerName': 'MoonDor2',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3527486150,
#   'summonerName': 'qxrb',
#   'championId': 268,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3527486150,
#   'summonerName': 'cqy',
#   'championId': 39,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3528510352,
#   'summonerName': 'MyEyeSee',
#   'championId': 61,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3528510352,
#   'summonerName': 'TrialMaker',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3528510352,
#   'summonerName': 'BadaPyobum',
#   'championId': 126,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3528510352,
#   'summonerName': 'S9 Grandmaster',
#   'championId': 43,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3528510352,
#   'summonerName': '삐빅 언랭입니다',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3528510352,
#   'summonerName': 'IlIIIlIlIIIlIllI',
#   'championId': 163,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3528510352,
#   'summonerName': '제발때리지말아요',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3528510352,
#   'summonerName': 'leondicaprio',
#   'championId': 266,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3528510352,
#   'summonerName': '내옆에누워바',
#   'championId': 412,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3528510352,
#   'summonerName': '엘더스크롤',
#   'championId': 6,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3528518466,
#   'summonerName': 'leondicaprio',
#   'championId': 61,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3528518466,
#   'summonerName': '킴과누',
#   'championId': 127,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3528518466,
#   'summonerName': 'Jamm',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3528518466,
#   'summonerName': '메뚝메둑메뚝',
#   'championId': 76,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3528518466,
#   'summonerName': '대충해벌자',
#   'championId': 412,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3528518466,
#   'summonerName': '0299',
#   'championId': 79,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3528518466,
#   'summonerName': '자부심강한사람',
#   'championId': 51,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3528518466,
#   'summonerName': 'venzi',
#   'championId': 268,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3528518466,
#   'summonerName': 'Nunu Captain',
#   'championId': 43,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3528518466,
#   'summonerName': '짱구엄마',
#   'championId': 64,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3529074409,
#   'summonerName': '담배좀끊어봐',
#   'championId': 68,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3529074409,
#   'summonerName': '조시나뱅뱅',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3529074409,
#   'summonerName': 'TML 일 강',
#   'championId': 267,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3529074409,
#   'summonerName': 'R키가안써져요',
#   'championId': 30,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3529074409,
#   'summonerName': '죄송해요부캐에요',
#   'championId': 90,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3529074409,
#   'summonerName': '그냥시로',
#   'championId': 58,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3529074409,
#   'summonerName': 'leondicaprio',
#   'championId': 13,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3529074409,
#   'summonerName': '인성나름좋아',
#   'championId': 5,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3529074409,
#   'summonerName': '이채은님',
#   'championId': 37,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3529074409,
#   'summonerName': '소방청장',
#   'championId': 119,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3530560279,
#   'summonerName': '호인2',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3530560279,
#   'summonerName': '전생해보니슬라임',
#   'championId': 157,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3530560279,
#   'summonerName': '리쳔시 ',
#   'championId': 33,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3530560279,
#   'summonerName': '3학년6반박창규',
#   'championId': 9,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3530560279,
#   'summonerName': '쿠로야키',
#   'championId': 74,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3530560279,
#   'summonerName': 'CHOVYFANBOY',
#   'championId': 39,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3530560279,
#   'summonerName': 'leondicaprio',
#   'championId': 38,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3530560279,
#   'summonerName': '연승을하는법',
#   'championId': 64,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3530560279,
#   'summonerName': '모두의마동석',
#   'championId': 22,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3530560279,
#   'summonerName': 'Piao Zheng xian',
#   'championId': 53,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3530568180,
#   'summonerName': '줄게없다',
#   'championId': 127,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3530568180,
#   'summonerName': '징징지잉',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3530568180,
#   'summonerName': '달팽달팽달팽달팽',
#   'championId': 25,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3530568180,
#   'summonerName': 'CAVE Bear',
#   'championId': 133,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3530568180,
#   'summonerName': 'Cystia',
#   'championId': 77,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3530568180,
#   'summonerName': '부소대장입니다',
#   'championId': 63,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3530568180,
#   'summonerName': '항공대19학번원딜',
#   'championId': 51,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3530568180,
#   'summonerName': 'leondicaprio',
#   'championId': 61,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3530568180,
#   'summonerName': 'SKTOFaker',
#   'championId': 69,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3530568180,
#   'summonerName': 'Heines',
#   'championId': 30,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3530634710,
#   'summonerName': 'topking517',
#   'championId': 24,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3530634710,
#   'summonerName': '마마둔워리',
#   'championId': 142,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3530634710,
#   'summonerName': '김태민 사생팬',
#   'championId': 77,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3530634710,
#   'summonerName': '롤드컵결승전5셋',
#   'championId': 412,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3530634710,
#   'summonerName': '1 J',
#   'championId': 429,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3530634710,
#   'summonerName': '혜지 임근열',
#   'championId': 8,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3530634710,
#   'summonerName': '내 마음 속 LCK',
#   'championId': 12,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3530634710,
#   'summonerName': 'Want attention',
#   'championId': 104,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3530634710,
#   'summonerName': 'flawuwuwu',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3530634710,
#   'summonerName': '쇼군 오로치',
#   'championId': 91,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3531123504,
#   'summonerName': 'Ruthless Kun',
#   'championId': 121,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3531123504,
#   'summonerName': '묵언수행234',
#   'championId': 43,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3531123504,
#   'summonerName': 'leondicaprio',
#   'championId': 13,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3531123504,
#   'summonerName': '임무뱀',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3531123504,
#   'summonerName': 'B0S0H',
#   'championId': 14,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3531123504,
#   'summonerName': '황 상 빈',
#   'championId': 22,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3531123504,
#   'summonerName': '탑갱좀와정글차이',
#   'championId': 6,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3531123504,
#   'summonerName': '니달리 장인 유저',
#   'championId': 76,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3531123504,
#   'summonerName': 'Lafrenze',
#   'championId': 9,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3531123504,
#   'summonerName': '교영내꺼',
#   'championId': 157,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3537901158,
#   'summonerName': '여자냄새킁카킁카',
#   'championId': 51,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3537901158,
#   'summonerName': '191212행복하자',
#   'championId': 41,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3537901158,
#   'summonerName': '걍 처해라',
#   'championId': 53,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3537901158,
#   'summonerName': 'Nosmaim',
#   'championId': 75,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3537901158,
#   'summonerName': '월클인지기',
#   'championId': 115,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3537901158,
#   'summonerName': 'l정l신l병l자l',
#   'championId': 43,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3537901158,
#   'summonerName': '마이쮸 마시쪄',
#   'championId': 104,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3537901158,
#   'summonerName': 'fiddlestick PCK',
#   'championId': 9,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3537901158,
#   'summonerName': 'NESTS',
#   'championId': 6,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3537901158,
#   'summonerName': '곰마꼬번학91',
#   'championId': 18,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3537972516,
#   'summonerName': '마이쮸 마시쪄',
#   'championId': 126,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3537972516,
#   'summonerName': 'fiddlestick PCK',
#   'championId': 9,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3537972516,
#   'summonerName': '감자토스트13',
#   'championId': 67,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3537972516,
#   'summonerName': 'min첼',
#   'championId': 113,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3537972516,
#   'summonerName': 'T4L0N',
#   'championId': 8,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3537972516,
#   'summonerName': '마렝이',
#   'championId': 30,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3537972516,
#   'summonerName': 'Hyeokey',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3537972516,
#   'summonerName': 'QT Supporter',
#   'championId': 101,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3537972516,
#   'summonerName': '전복맛집',
#   'championId': 245,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3537972516,
#   'summonerName': 'Hide on 박촌',
#   'championId': 75,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3537980588,
#   'summonerName': '마이쮸 마시쪄',
#   'championId': 126,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3537980588,
#   'summonerName': 'fiddlestick PCK',
#   'championId': 9,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3537980588,
#   'summonerName': '설레고싶다',
#   'championId': 203,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3537980588,
#   'summonerName': '잠시만 뼈맞았따',
#   'championId': 141,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3537980588,
#   'summonerName': '용용90',
#   'championId': 56,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3537980588,
#   'summonerName': '알락사르씩비르',
#   'championId': 84,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3537980588,
#   'summonerName': '살좀찜',
#   'championId': 30,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3537980588,
#   'summonerName': '히피펌한 베인',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3537980588,
#   'summonerName': '가르마펌한  진님',
#   'championId': 8,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3537980588,
#   'summonerName': '사실 본캐 마스터',
#   'championId': 92,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3539023314,
#   'summonerName': 'Yunhlz',
#   'championId': 245,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3539023314,
#   'summonerName': '네스타',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3539023314,
#   'summonerName': 'magica1',
#   'championId': 68,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3539023314,
#   'summonerName': 'viperfensi',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3539023314,
#   'summonerName': 'Duorp',
#   'championId': 555,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3539023314,
#   'summonerName': '생존핑찍지마',
#   'championId': 112,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3539023314,
#   'summonerName': '김태민 사생팬',
#   'championId': 56,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3539023314,
#   'summonerName': 'Irelia Carry You',
#   'championId': 126,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3539023314,
#   'summonerName': '수의대가는민수',
#   'championId': 42,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3539023314,
#   'summonerName': '임현도',
#   'championId': 79,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3539484736,
#   'summonerName': 'TYPE crazy',
#   'championId': 122,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3539484736,
#   'summonerName': '김팡민',
#   'championId': 203,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3539484736,
#   'summonerName': '서응가',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3539484736,
#   'summonerName': '손만잡기싫어',
#   'championId': 54,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3539484736,
#   'summonerName': '마이쮸 마시쪄',
#   'championId': 157,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3539484736,
#   'summonerName': '버스타길원해요',
#   'championId': 420,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3539484736,
#   'summonerName': '조탈론',
#   'championId': 91,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3539484736,
#   'summonerName': 'Busan  Lee sin',
#   'championId': 67,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3539484736,
#   'summonerName': 'dat ur in love',
#   'championId': 412,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3539484736,
#   'summonerName': '슨상표',
#   'championId': 30,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3539513820,
#   'summonerName': '민이전사',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3539513820,
#   'summonerName': '섹시영구',
#   'championId': 79,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3539513820,
#   'summonerName': '손만잡기싫어',
#   'championId': 99,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3539513820,
#   'summonerName': '마이쮸 마시쪄',
#   'championId': 126,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3539513820,
#   'summonerName': '잡기술의 븃씬',
#   'championId': 26,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3539513820,
#   'summonerName': 'yanghotti',
#   'championId': 8,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3539513820,
#   'summonerName': '조씨를 믿읍시다',
#   'championId': 35,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3539513820,
#   'summonerName': 'CatoU',
#   'championId': 61,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3539513820,
#   'summonerName': '쉬엄쉬엄안해요',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3539513820,
#   'summonerName': '응 닉네임 안쓸거',
#   'championId': 89,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3543664505,
#   'summonerName': 'want to beloved',
#   'championId': 89,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3543664505,
#   'summonerName': 'coco2211',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3543664505,
#   'summonerName': 'why die',
#   'championId': 41,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3543664505,
#   'summonerName': '거품들아빠져라',
#   'championId': 60,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3543664505,
#   'summonerName': 'La Fussel',
#   'championId': 39,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3543664505,
#   'summonerName': 'traverd',
#   'championId': 121,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3543664505,
#   'summonerName': 'AKa 단타',
#   'championId': 114,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3543664505,
#   'summonerName': '말걸면물림',
#   'championId': 111,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3543664505,
#   'summonerName': '3월의 요정',
#   'championId': 163,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3543664505,
#   'summonerName': '사나연',
#   'championId': 67,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3544275889,
#   'summonerName': 'AD user K',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3544275889,
#   'summonerName': '민둥 OR 뻐꺼머리',
#   'championId': 34,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3544275889,
#   'summonerName': '마이쮸 마시쪄',
#   'championId': 157,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3544275889,
#   'summonerName': 'fiddlestick PCK',
#   'championId': 9,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3544275889,
#   'summonerName': 'The God Riven',
#   'championId': 33,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3544275889,
#   'summonerName': '효겸s베인',
#   'championId': 11,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3544275889,
#   'summonerName': '챙두듣',
#   'championId': 55,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3544275889,
#   'summonerName': '86Xavi',
#   'championId': 113,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3544275889,
#   'summonerName': '픽통령yo',
#   'championId': 26,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3544275889,
#   'summonerName': 'MoH',
#   'championId': 236,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3546353910,
#   'summonerName': '조희상',
#   'championId': 78,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3546353910,
#   'summonerName': '데 엡',
#   'championId': 111,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3546353910,
#   'summonerName': '구축하겠어',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3546353910,
#   'summonerName': '바위게새끼야',
#   'championId': 113,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3546353910,
#   'summonerName': 'leondicaprio',
#   'championId': 13,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3546353910,
#   'summonerName': 'ililIiiIlijlilii',
#   'championId': 16,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3546353910,
#   'summonerName': '블로노 부첼라티',
#   'championId': 68,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3546353910,
#   'summonerName': '히히먕우',
#   'championId': 5,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3546353910,
#   'summonerName': '아 저게 끌리네',
#   'championId': 142,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3546353910,
#   'summonerName': '모찌의 노리개',
#   'championId': 67,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3547924593,
#   'summonerName': '웬만해서채팅안침',
#   'championId': 38,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3547924593,
#   'summonerName': '칭찬받으면못해짐',
#   'championId': 53,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3547924593,
#   'summonerName': '총은 내가 쏠게',
#   'championId': 236,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3547924593,
#   'summonerName': '밀 루',
#   'championId': 5,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3547924593,
#   'summonerName': '체리쪼꿈끼요밍',
#   'championId': 61,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3547924593,
#   'summonerName': '정치안하는남자',
#   'championId': 21,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3547924593,
#   'summonerName': '덕 호 쨔응',
#   'championId': 28,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3547924593,
#   'summonerName': '새루 유튜브 구독',
#   'championId': 8,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3547924593,
#   'summonerName': '자 네',
#   'championId': 412,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3547924593,
#   'summonerName': '자 넹',
#   'championId': 92,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3548456558,
#   'summonerName': '김태민 사생팬',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3548456558,
#   'summonerName': '성대글경14원철',
#   'championId': 517,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3548456558,
#   'summonerName': '쉔과나의연결고리',
#   'championId': 98,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3548456558,
#   'summonerName': '아무고토모타똥',
#   'championId': 7,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3548456558,
#   'summonerName': '똥쟁이베인충',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3548456558,
#   'summonerName': '정말 영혼이 없다',
#   'championId': 142,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3548456558,
#   'summonerName': '예민해진사람',
# ...
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3591433803,
#   'summonerName': '7시간자는사람',
#   'championId': 517,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3591433803,
#   'summonerName': 'A P V',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3591433803,
#   'summonerName': '에이스견제그만',
#   'championId': 15,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3591433803,
#   'summonerName': '채팅꺼라',
#   'championId': 8,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3591433803,
#   'summonerName': '미역국수국',
#   'championId': 91,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3591433803,
#   'summonerName': '717호 서포터',
#   'championId': 53,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3591433803,
#   'summonerName': '임 명',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3591433803,
#   'summonerName': 'asdqweqcasdopclm',
#   'championId': 60,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3591442795,
#   'summonerName': '쁘농이',
#   'championId': 143,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3591442795,
#   'summonerName': '너의 모든것',
#   'championId': 9,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3591442795,
#   'summonerName': '넌확실히강해졌다',
#   'championId': 58,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3591442795,
#   'summonerName': 'BJ서준석사생팬',
#   'championId': 105,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3591442795,
#   'summonerName': 'lllIIIIllIIlIlI',
#   'championId': 61,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3591442795,
#   'summonerName': 'Ps Meeeeeeeeeeee',
#   'championId': 202,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3591442795,
#   'summonerName': 'Coffee Daddy',
#   'championId': 92,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3591442795,
#   'summonerName': '세체룰',
#   'championId': 117,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3591442795,
#   'summonerName': 'BroCColi 1999',
#   'championId': 421,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3591442795,
#   'summonerName': '킹존 케리아',
#   'championId': 13,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3591451606,
#   'summonerName': 'qwer9999',
#   'championId': 161,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3591451606,
#   'summonerName': 'asdqweqcasdopclm',
#   'championId': 60,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3591451606,
#   'summonerName': '채팅꺼라',
#   'championId': 8,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3591451606,
#   'summonerName': '신천욕받이',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3591451606,
#   'summonerName': '바위게못간다니깐',
#   'championId': 91,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3591451606,
#   'summonerName': 'VV O N T E D ',
#   'championId': 131,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3591451606,
#   'summonerName': '대령 정비병',
#   'championId': 23,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3591451606,
#   'summonerName': 'Paimon',
#   'championId': 56,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3591451606,
#   'summonerName': '봉봉씌',
#   'championId': 432,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3591451606,
#   'summonerName': 'AD ending',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3591921731,
#   'summonerName': 'why die',
#   'championId': 30,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591921731,
#   'summonerName': '방갈로르',
#   'championId': 67,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591921731,
#   'summonerName': 'douyu885511',
#   'championId': 432,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591921731,
#   'summonerName': 'DouyuTVxiaoxi',
#   'championId': 76,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591921731,
#   'summonerName': 'M1kuya',
#   'championId': 126,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591921731,
#   'summonerName': 'BBBaby',
#   'championId': 64,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591921731,
#   'summonerName': '이보통령',
#   'championId': 39,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591921731,
#   'summonerName': 'Can trust me',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591921731,
#   'summonerName': '성창현 짱귀요미',
#   'championId': 98,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591921731,
#   'summonerName': '난 위로받고싶어',
#   'championId': 8,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591983566,
#   'summonerName': '좋다고 말해요',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591983566,
#   'summonerName': 'sup1234789',
#   'championId': 555,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591983566,
#   'summonerName': '한화생명2스포츠',
#   'championId': 56,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591983566,
#   'summonerName': '홍코노',
#   'championId': 67,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591983566,
#   'summonerName': '아창란 식물',
#   'championId': 134,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3591983566,
#   'summonerName': 'Valkyrie2',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591983566,
#   'summonerName': 'why die',
#   'championId': 120,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591983566,
#   'summonerName': '달성서씨서예성',
#   'championId': 98,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591983566,
#   'summonerName': '흥사실너가좋은걸',
#   'championId': 107,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3591983566,
#   'summonerName': 'DWG ShowMaker',
#   'championId': 127,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3592964768,
#   'summonerName': 'SANDBOX OnFleek',
#   'championId': 5,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3592964768,
#   'summonerName': '     Zhe     Yi ',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3592964768,
#   'summonerName': '미니맵안보는사람',
#   'championId': 61,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3592964768,
#   'summonerName': '잠잘때코고는사람',
#   'championId': 3,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3592964768,
#   'summonerName': '허세다',
#   'championId': 122,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3592964768,
#   'summonerName': 'why die',
#   'championId': 41,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3592964768,
#   'summonerName': 'Eine KIeine',
#   'championId': 76,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3592964768,
#   'summonerName': 'Bait04',
#   'championId': 67,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3592964768,
#   'summonerName': 'VSG Minit',
#   'championId': 201,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3592964768,
#   'summonerName': 'LeeJungMin',
#   'championId': 91,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3593003002,
#   'summonerName': 'Bluecat',
#   'championId': 18,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3593003002,
#   'summonerName': '서 포 터   태 경',
#   'championId': 9,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3593003002,
#   'summonerName': 'only si jun',
#   'championId': 104,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3593003002,
#   'summonerName': 'zhaoQQ1106943735',
#   'championId': 7,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3593003002,
#   'summonerName': 'why die',
#   'championId': 43,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3593003002,
#   'summonerName': 'arolf9',
#   'championId': 60,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3593003002,
#   'summonerName': '007obu',
#   'championId': 39,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3593003002,
#   'summonerName': 'Eine KIeine',
#   'championId': 145,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3593003002,
#   'summonerName': '멧돌돼지',
#   'championId': 117,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3593003002,
#   'summonerName': '가재맨',
#   'championId': 133,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3593038437,
#   'summonerName': 'zhiqiang   HuYa',
#   'championId': 91,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3593038437,
#   'summonerName': 'burrningg',
#   'championId': 25,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3593038437,
#   'summonerName': 'hoshinoi',
#   'championId': 30,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3593038437,
#   'summonerName': 'Strongest 1024',
#   'championId': 6,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3593038437,
#   'summonerName': 'Jump Jump h',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': False},
#  {'gameId': 3593038437,
#   'summonerName': 'iu의 작은 푸딩',
#   'championId': 3,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3593038437,
#   'summonerName': '가재맨',
#   'championId': 163,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3593038437,
#   'summonerName': 'why die',
#   'championId': 120,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3593038437,
#   'summonerName': 'Eine KIeine',
#   'championId': 76,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3593038437,
#   'summonerName': 'PAKA fans',
#   'championId': 67,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE',
#   'win': True},
#  {'gameId': 3593475433,
#   'summonerName': '칼퇴근하는사람',
#   'championId': 39,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3593475433,
#   'summonerName': '박세중',
#   'championId': 53,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3593475433,
#   'summonerName': '잭카림',
#   'championId': 86,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3593475433,
#   'summonerName': '임신마을치즈피자',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3593475433,
#   'summonerName': '짱짱헤드',
#   'championId': 54,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3593475433,
#   'summonerName': '채팅꺼라',
#   'championId': 112,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3593475433,
#   'summonerName': '콩먹쿵',
#   'championId': 245,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3593475433,
#   'summonerName': '혜지모드온',
#   'championId': 64,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3593475433,
#   'summonerName': 'Topnotch Haaaaap',
#   'championId': 236,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3593475433,
#   'summonerName': '즐겁기위해겜함',
#   'championId': 63,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3593563650,
#   'summonerName': 'Savannah cat',
#   'championId': 421,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3593563650,
#   'summonerName': 'Jiang Chen',
#   'championId': 99,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3593563650,
#   'summonerName': '육개장먹방',
#   'championId': 16,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3593563650,
#   'summonerName': 'Cheukuya',
#   'championId': 81,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3593563650,
#   'summonerName': '채팅꺼라',
#   'championId': 8,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3593563650,
#   'summonerName': 'Miro HyeG',
#   'championId': 39,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3593563650,
#   'summonerName': '고원딜',
#   'championId': 59,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3593563650,
#   'summonerName': '관등티어',
#   'championId': 51,
#   'teamId': 200,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3593563650,
#   'summonerName': '즐겜위주유저',
#   'championId': 53,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': True},
#  {'gameId': 3593563650,
#   'summonerName': '히토리 봇찌',
#   'championId': 517,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3594028032,
#   'summonerName': '요릭왕',
#   'championId': 64,
#   'teamId': 100,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': False},
#  {'gameId': 3594028032,
#   'summonerName': '문윤영',
#   'championId': 497,
#   'teamId': 100,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3594028032,
#   'summonerName': '볼빨간사춘기',
#   'championId': 105,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': False},
#  {'gameId': 3594028032,
#   'summonerName': '에기몬',
#   'championId': 10,
#   'teamId': 100,
#   'role': 'SOLO',
#   'lane': 'TOP',
#   'win': False},
#  {'gameId': 3594028032,
#   'summonerName': '갓 뱀',
#   'championId': 145,
#   'teamId': 100,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM',
#   'win': False},
#  {'gameId': 3594028032,
#   'summonerName': 'TaNSaL',
#   'championId': 134,
#   'teamId': 200,
#   'role': 'SOLO',
#   'lane': 'MIDDLE',
#   'win': True},
#  {'gameId': 3594028032,
#   'summonerName': '레드스틸잼',
#   'championId': 81,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3594028032,
#   'summonerName': '빈센트콤파니',
#   'championId': 56,
#   'teamId': 200,
#   'role': 'NONE',
#   'lane': 'JUNGLE',
#   'win': True},
#  {'gameId': 3594028032,
#   'summonerName': '채팅꺼라',
#   'championId': 107,
#   'teamId': 200,
#   'role': 'DUO',
#   'lane': 'TOP',
#   'win': True},
#  {'gameId': 3594028032,
#   'summonerName': '바텀은항상이겨',
#   'championId': 99,
#   'teamId': 200,
#   'role': 'DUO_SUPPORT',
#   'lane': 'TOP',
#   'win': True},
#  ...]

# %%
import pickle

# %%
with open('champion_id_and_name_list.pickle','rb') as f1:
    data1=pickle.load(f1)
data1
# Out:
# {266: 'Aatrox',
#  103: 'Ahri',
#  84: 'Akali',
#  12: 'Alistar',
#  32: 'Amumu',
#  34: 'Anivia',
#  1: 'Annie',
#  523: 'Aphelios',
#  22: 'Ashe',
#  136: 'Aurelion Sol',
#  268: 'Azir',
#  432: 'Bard',
#  53: 'Blitzcrank',
#  63: 'Brand',
#  201: 'Braum',
#  51: 'Caitlyn',
#  164: 'Camille',
#  69: 'Cassiopeia',
#  31: "Cho'Gath",
#  42: 'Corki',
#  122: 'Darius',
#  131: 'Diana',
#  119: 'Draven',
#  36: 'Dr. Mundo',
#  245: 'Ekko',
#  60: 'Elise',
#  28: 'Evelynn',
#  81: 'Ezreal',
#  9: 'Fiddlesticks',
#  114: 'Fiora',
#  105: 'Fizz',
#  3: 'Galio',
#  41: 'Gangplank',
#  86: 'Garen',
#  150: 'Gnar',
#  79: 'Gragas',
#  104: 'Graves',
#  120: 'Hecarim',
#  74: 'Heimerdinger',
#  420: 'Illaoi',
#  39: 'Irelia',
#  427: 'Ivern',
#  40: 'Janna',
#  59: 'Jarvan IV',
#  24: 'Jax',
#  126: 'Jayce',
#  202: 'Jhin',
#  222: 'Jinx',
#  145: "Kai'Sa",
#  429: 'Kalista',
#  43: 'Karma',
#  30: 'Karthus',
#  38: 'Kassadin',
#  55: 'Katarina',
#  10: 'Kayle',
#  141: 'Kayn',
#  85: 'Kennen',
#  121: "Kha'Zix",
#  203: 'Kindred',
#  240: 'Kled',
#  96: "Kog'Maw",
#  7: 'LeBlanc',
#  64: 'Lee Sin',
#  89: 'Leona',
#  876: 'Lillia',
#  127: 'Lissandra',
#  236: 'Lucian',
#  117: 'Lulu',
#  99: 'Lux',
#  54: 'Malphite',
#  90: 'Malzahar',
#  57: 'Maokai',
#  11: 'Master Yi',
#  21: 'Miss Fortune',
#  62: 'Wukong',
#  82: 'Mordekaiser',
#  25: 'Morgana',
#  267: 'Nami',
#  75: 'Nasus',
#  111: 'Nautilus',
#  518: 'Neeko',
#  76: 'Nidalee',
#  56: 'Nocturne',
#  20: 'Nunu & Willump',
#  2: 'Olaf',
#  61: 'Orianna',
#  516: 'Ornn',
#  80: 'Pantheon',
#  78: 'Poppy',
#  555: 'Pyke',
#  246: 'Qiyana',
#  133: 'Quinn',
#  497: 'Rakan',
#  33: 'Rammus',
#  421: "Rek'Sai",
#  58: 'Renekton',
#  107: 'Rengar',
#  92: 'Riven',
#  68: 'Rumble',
#  13: 'Ryze',
#  360: 'Samira',
#  113: 'Sejuani',
#  235: 'Senna',
#  147: 'Seraphine',
#  875: 'Sett',
#  35: 'Shaco',
#  98: 'Shen',
#  102: 'Shyvana',
#  27: 'Singed',
#  14: 'Sion',
#  15: 'Sivir',
#  72: 'Skarner',
#  37: 'Sona',
#  16: 'Soraka',
#  50: 'Swain',
#  517: 'Sylas',
#  134: 'Syndra',
#  223: 'Tahm Kench',
#  163: 'Taliyah',
#  91: 'Talon',
#  44: 'Taric',
#  17: 'Teemo',
#  412: 'Thresh',
#  18: 'Tristana',
#  48: 'Trundle',
#  23: 'Tryndamere',
#  4: 'Twisted Fate',
#  29: 'Twitch',
#  77: 'Udyr',
#  6: 'Urgot',
#  110: 'Varus',
#  67: 'Vayne',
#  45: 'Veigar',
#  161: "Vel'Koz",
#  254: 'Vi',
#  112: 'Viktor',
#  8: 'Vladimir',
#  106: 'Volibear',
#  19: 'Warwick',
#  498: 'Xayah',
#  101: 'Xerath',
#  5: 'Xin Zhao',
#  157: 'Yasuo',
#  777: 'Yone',
#  83: 'Yorick',
#  350: 'Yuumi',
#  154: 'Zac',
#  238: 'Zed',
#  115: 'Ziggs',
#  26: 'Zilean',
#  142: 'Zoe',
#  143: 'Zyra'}

# %%
with open('participant_data.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
len(data)
# Out:
# 919200

# %%
driver = webdriver.Chrome('./chromedriver.exe')

# %%
from tqdm import tqdm

# %%
User=list()
for i in tqdm(data[:10]):
    ID=i['summonerName']
    champ =  data1[i['championId']]
    try:
        driver.get(f'https://www.op.gg/summoner/userName={ID}')
        driver.find_element_by_xpath('//*[@id="right_gametype_soloranked"]').click()
        x=driver.find_element_by_xpath('//*[@id="GameAverageStatsBox-matches"]/div[1]/table/tbody/tr[2]/td[2]/div[2]')
        spans=x.find_elements_by_xpath('./span')
        recentKDA= float(spans[0].text.split(':')[0])
        recentW_R= int(spans[1].find_element_by_xpath('./span').text[:-1])
        totalW_R=int(driver.find_element_by_xpath('//*[@id="SummonerLayoutContent"]/div[2]/div[1]/div[1]/div/div[2]/div[3]/span[2]/span[3]').text.split()[-1][:-1])
        driver.find_element_by_xpath('//*[@id="left_champion"]/a').click()
        table = driver.find_element_by_xpath('//*[@id="SummonerLayoutContent"]/div[3]/div/div/div[2]/div[1]/table/tbody')
        trs=table.find_elements_by_xpath('./tr')
        #픽 champion의 시즌 승률 검색 만약 데이터가 없으면 최근승률로 대체
        chamW_R=0
        chamKDA=0
        for tr in trs:
            tds = tr.find_elements_by_xpath('./td')
            if tds[2].get_attribute('data-value')==champ:
                chamW_R=int(tds[3].find_element_by_xpath('.//span').text[:-1])
                chamKDA=float(tds[4].get_attribute("data-value"))
                break
            chamW_R=recentW_R
            chamKDA=recentKDA
            
    except:
        continue
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:14<00:00,  7.43s/it]

# %%
driver.find_element_by_xpath('//*[@id="right_gametype_soloranked"]').click()

# %%
x=driver.find_element_by_xpath('//*[@id="GameAverageStatsBox-matches"]/div[1]/table/tbody/tr[2]/td[2]/div[2]')

# %%
spans=x.find_elements_by_xpath('./span')

# %%
recentKDA= float(spans[0].text.split(':')[0])

# %%
recentW_R= int(spans[1].find_element_by_xpath('./span').text[:-1])

# %%
totalW_R=int(driver.find_element_by_xpath('//*[@id="SummonerLayoutContent"]/div[2]/div[1]/div[1]/div/div[2]/div[3]/span[2]/span[3]').text.split()[-1][:-1])

# %%
driver.find_element_by_xpath('//*[@id="left_champion"]/a').click()

# %%
table = driver.find_element_by_xpath('//*[@id="SummonerLayoutContent"]/div[3]/div/div/div[2]/div[1]/table/tbody')
trs=table.find_elements_by_xpath('./tr')

# %%
#픽 champion의 시즌 승률 검색 만약 데이터가 없으면 최근승률로 대체
chamW_R=0
chamKDA=0
for tr in trs:
    tds = tr.find_elements_by_xpath('./td')
    if tds[2].get_attribute('data-value')==champ:
        chamW_R=int(tds[3].find_element_by_xpath('.//span').text[:-1])
        chamKDA=float(tds[4].get_attribute("data-value"))
        break
    chamW_R=recentW_R
    chamKDA=recentKDA
chamKDA
# Out:
# 3.45

# %%
for i in data:
    ID=i['summonerName']
    champ =  data1[i['championId']]
    x=driver.find_element_by_xpath('/html/body/div[2]/div[2]/form/input')
    x.send_keys(ID)

# %%
with open('op_gg_valid_game_1.pickle','rb') as f1:
    data2=pickle.load(f1)
data1
