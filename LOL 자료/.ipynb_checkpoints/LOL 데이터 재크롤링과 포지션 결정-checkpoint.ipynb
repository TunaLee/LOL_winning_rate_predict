# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib as mpl
import matplotlib.pyplot as plt
import pickle, json
from urllib import request, parse
from bs4 import BeautifulSoup
from tqdm import tqdm
from selenium import webdriver
import requests
from time import sleep
import time, timeit
from selenium.webdriver.common.keys import Keys
# 포지션 
from skimage import io # 미니맵 처리
from sklearn.preprocessing import MinMaxScaler #스케일 재조정.

# %%
#챔피언 id/이름 목록 파일 불러오기
with open('champion_id_and_name_list.pickle','rb') as f1:
    champ_id_dict=pickle.load(f1)

# %%
def parse_tup(summonerName, champion, recent=False, champW=False): #동원님 스크립트를 이용해서 함수 재조합.
    global driver, champ_id_dict
    name_parsed = parse.quote_plus(summonerName)
    if str(champion).isnumeric():
        champ = champ_id_dict[champion] #id -챔피언명 정보 딕셔너리로 불러와주세요. 딕셔너리 이름 다르게 했으면 이 이름으로 하셔야 합니다. 
    else: #영어면 
        champ = champion
    driver.get(f'https://www.op.gg/summoner/userName={name_parsed}') #url 오류
    if not(recent):
        try:
            
            driver.find_element_by_xpath('//*[@id="right_gametype_soloranked"]/a').click()
            sleep(2)
            try:
                recentW_R = int(driver.find_element_by_css_selector('div.WinRatioGraph>div.Text').get_attribute('innerText').replace('%',""))
            except:
                recentW_R = -1
            try:
                recentKDA= float(driver.find_element_by_css_selector('span.KDARatio').get_attribute('innerText').split(':')[0])
            except:
                recentKDA = -1
            try:
                totalW_R=int(driver.find_element_by_css_selector('span.winratio').get_attribute('innerText').split()[-1][:-1])
            except:
                totalW_R = -1
        except:
            recentW_R = 0
            recentKDA = 0
            totalW_R = 0
    else: #recent 데이터가 있으면
        recentW_R = recent[0]
        recentKDA = recent[1]
        totalW_R = recent[2]
    sleep(2)
    
    sleep(2)
    driver.find_element_by_xpath('//*[@id="left_champion"]/a').click()
    sleep(3)
    driver.find_element_by_xpath('//*[@id="champion_season"]/li[2]/a').click()
    sleep(5)
    tables = driver.find_elements_by_tag_name('table')
    trs=tables[-1].find_elements_by_xpath('./tbody/tr')
    #픽 champion의 시즌 승률 검색 만약 데이터가 없으면 최근승률로 대체
    if not(champW):
        for tr in trs:
            tds = tr.find_elements_by_xpath('./td')
            if tds[2].get_attribute('data-value')==champ:
                try:
                    chamW_R=round(float(tds[3].get_attribute('data-value')))
                except:
                    chamW_R = -1
                try:
                    chamKDA=float(tds[4].get_attribute("data-value"))
                except:
                    chamKDA = -1
                try:
                    try:
                        matchCNT1=int(tds[3].find_element_by_css_selector('div.Text.Left').get_attribute('innerText')[:-1])
                    except:
                        matchCNT1 = 0
                    try:
                        matchCNT2 = int(tds[3].find_element_by_css_selector('div.Text.Right').get_attribute('innerText')[:-1])
                    except:
                        matchCNT2 = 0
                    matchCNT = matchCNT1 + matchCNT2
                except: #안 되면 Xpath 방식으로 긁어와보자.
                    try:
                        matchCNT1 = int(tds[3].find_element_by_xpath(',/div/div/div[2]').get_attribute('innerText')[:-1])
                        try:
                            matchCNT2 = int(tds[3].find_element_by_xpath(',/div/div/div[4]').get_attribute('innerText')[:-1])
                        except:
                            matchCNT2 = 0
                        matchCNT = matchCNT1 + matchCNT2
                    except:
                        matchCNT = -1
                break
        else:
            chamW_R=recentW_R
            chamKDA=recentKDA
            matchCNT = 0
        sleep(2)
    else:
        chamW_R = champW[0]
        chamKDA = champW[1]
        matchCNT = champW[2]
        

    return [summonerName,champ,chamW_R,chamKDA,recentW_R,recentKDA, totalW_R ,matchCNT]

# %%
#잘 작동하는 지 확인하기
driver= webdriver.Chrome() #이번엔 옵션 없애기...
driver.get('https://op.gg/')
driver.find_element_by_xpath('/html/body/div[2]/header/div[2]/div/div/div/div/div/button').click()
sleep(2)
lang_list = driver.find_elements_by_class_name('setting-list__item')
for lang in lang_list:
    if "English" in lang.text:
        lang.click()
sleep(2)
driver.find_elements_by_class_name('setting__button')[0].click()
sleep(2)

print(parse_tup('이즈아펠케틀애쉬', 'Aphelios', False, False))
driver.quit()
# Out:
# ['이즈아펠케틀애쉬', 'Aphelios', 53, 2.63, 45, 2.37, 50, 284]

# %%
dat_result = [] #GameInfo with user 파일 호출
with open('Gameinfo_with_user_48336_to_60000_all.pickle', 'rb') as f:
    dat_result += pickle.load(f)

# %%
driver= webdriver.Chrome() #우선 영어로 지정.
driver.get('https://op.gg/')
driver.find_element_by_xpath('/html/body/div[2]/header/div[2]/div/div/div/div/div/button').click()
sleep(2)
lang_list = driver.find_elements_by_class_name('setting-list__item')
for lang in lang_list:
    if "English" in lang.text:
        lang.click()
sleep(2)
driver.find_elements_by_class_name('setting__button')[0].click()
sleep(2)

#gameinfo with user의 데이터 중 chamW_R, chamKDA, totalNUm 보강
for dat in dat_result:
    sleep(2)
    participants = dat['participants'] # participant data 가져오기
    for j in range(len(participants)): #길이가 
        part_data = participants[j]
        print(part_data)
        if part_data[-1] == 0:
            champW = False
        else:
            champW = part_data[-6:-4]+part_data[-1:]
        if champW == False:
            try: #없을 수도 있으니 
                part_data = parse_tup(part_data[0], part_data[1], part_data[-4:-1], champW)
                participants[j] = part_data
            except:
                continue
        sleep(1)
    dat['participants'] = participants
    print(participants)

driver.quit()
# Out:
# ['뱅 배준식', 'Camille', 50, 1.95, 57, 2.52, 51, 12]
# ['짜 룽', 'Lee Sin', 51, 3.56, 57, 2.5, 51, 632]
# ['happy   game ', 'Yone', 48, 1.34, 48, 1.34, 52, 0]
# ['잠 이 덜 깨다', 'Caitlyn', 44, 2.2, 44, 2.2, 51, 0]
# ['ha1 m1an bao bao', 'Taric', 61, 3.95, 50, 1.72, 54, 341]
# [['뱅 배준식', 'Camille', 50, 1.95, 57, 2.52, 51, 12], ['짜 룽', 'Lee Sin', 51, 3.56, 57, 2.5, 51, 632], ['happy   game ', 'Yone', 40, 1.62, 48, 1.34, 52, 10], ['잠 이 덜 깨다', 'Caitlyn', 57, 2.4, 44, 2.2, 51, 93], ['ha1 m1an bao bao', 'Taric', 61, 3.95, 50, 1.72, 54, 341]]
# ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52]
# ['라인양보좀부캐임', 'Lee Sin', 25, 2.26, 44, 2.09, 52, 12]
# ['향 유', 'Wukong', 54, 2.24, 48, 2.53, 50, 24]
# ['날씨요정 정현', 'Ashe', 51, 2.79, 52, 3.16, 51, 59]
# ['Navy SEAL 이근', 'Pantheon', 75, 2.92, 44, 1.85, 53, 40]
# [['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52], ['라인양보좀부캐임', 'Lee Sin', 25, 2.26, 44, 2.09, 52, 12], ['향 유', 'Wukong', 54, 2.24, 48, 2.53, 50, 24], ['날씨요정 정현', 'Ashe', 51, 2.79, 52, 3.16, 51, 59], ['Navy SEAL 이근', 'Pantheon', 75, 2.92, 44, 1.85, 53, 40]]
# ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52]
# ['후루꾸우루꾸', 'Shen', 57, 2.58, 53, 2.35, 52, 523]
# ['Zl존Jungle러', 'Graves', 45, 2.67, 52, 3.08, 50, 55]
# ['심심하면놀러와', 'Lulu', 57, 4.13, 57, 4.13, 57, 0]
# ['이즈아펠케틀애쉬', 'Aphelios', 49, 2.63, 49, 2.63, 50, 0]
# [['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52], ['후루꾸우루꾸', 'Shen', 57, 2.58, 53, 2.35, 52, 523], ['Zl존Jungle러', 'Graves', 45, 2.67, 52, 3.08, 50, 55], ['심심하면놀러와', 'Lulu', 57, 4.13, 57, 4.13, 57, 0], ['이즈아펠케틀애쉬', 'Aphelios', 53, 2.63, 49, 2.63, 50, 284]]
# ['wjwnqkedmsrPwjd', 'Olaf', 57, 2.9, 57, 2.9, 54, 0]
# ['Sangdy OwO', 'Cassiopeia', 48, 3.59, 48, 3.59, 57, 0]
# ['Lagoon Lounge', 'Lulu', 52, 2.71, 55, 2.28, 50, 1041]
# ['모이치리', 'Renekton', 46, 1.61, 46, 1.61, 52, 0]
# ['스케리', 'Ezreal', 52, 3.04, 48, 2.8, 51, 1074]
# [['wjwnqkedmsrPwjd', 'Olaf', 59, 2.44, 57, 2.9, 54, 29], ['Sangdy OwO', 'Cassiopeia', 67, 2.73, 48, 3.59, 57, 30], ['Lagoon Lounge', 'Lulu', 52, 2.71, 55, 2.28, 50, 1041], ['모이치리', 'Renekton', 58, 2.05, 46, 1.61, 52, 153], ['스케리', 'Ezreal', 52, 3.04, 48, 2.8, 51, 1074]]
# ['IiI tracy', 'Lillia', 54, 3.17, 55, 3.01, 53, 111]
# ['밀레니엄베이베', 'Camille', 57, 2.0, 46, 2.02, 57, 7]
# ['으악새다 으악', 'Jhin', 52, 3.2, 48, 3.05, 50, 54]
# ['lacoy', 'Sett', 56, 2.65, 53, 3.18, 53, 18]
# ['wo1fchi1d', 'Talon', 50, 2.83, 47, 2.67, 52, 221]
# [['IiI tracy', 'Lillia', 54, 3.17, 55, 3.01, 53, 111], ['밀레니엄베이베', 'Camille', 57, 2.0, 46, 2.02, 57, 7], ['으악새다 으악', 'Jhin', 52, 3.2, 48, 3.05, 50, 54], ['lacoy', 'Sett', 56, 2.65, 53, 3.18, 53, 18], ['wo1fchi1d', 'Talon', 50, 2.83, 47, 2.67, 52, 221]]
# ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52]
# ['3렙갱안감', 'Nidalee', 60, 3.68, 55, 2.59, 59, 105]
# ['피카츄라이츄파이리꼬북이', 'Aphelios', 50, 2.69, 50, 2.69, 52, 0]
# ['the night alight', 'Jax', 70, 2.48, 43, 2.3, 55, 30]
# ['미사카 미코토', 'Lulu', 43, 3.47, 50, 4.23, 52, 69]
# [['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52], ['3렙갱안감', 'Nidalee', 60, 3.68, 55, 2.59, 59, 105], ['피카츄라이츄파이리꼬북이', 'Aphelios', 52, 2.31, 50, 2.69, 52, 44], ['the night alight', 'Jax', 70, 2.48, 43, 2.3, 55, 30], ['미사카 미코토', 'Lulu', 43, 3.47, 50, 4.23, 52, 69]]
# ['Love IU Forever', 'Sylas', 54, 2.31, 38, 1.45, 53, 57]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['춥 화 춥 스', 'Jhin', 62, 3.53, 58, 2.85, 53, 21]
# ['규용띠용', 'Bard', 53, 2.52, 56, 4.74, 50, 96]
# ['Klxg', 'Graves', 40, 4.07, 58, 2.79, 48, 5]
# [['Love IU Forever', 'Sylas', 54, 2.31, 38, 1.45, 53, 57], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['춥 화 춥 스', 'Jhin', 62, 3.53, 58, 2.85, 53, 21], ['규용띠용', 'Bard', 53, 2.52, 56, 4.74, 50, 96], ['Klxg', 'Graves', 40, 4.07, 58, 2.79, 48, 5]]
# ['인간말종망한인생', 'Jhin', 50, 3.13, 50, 3.13, 52, 0]
# ['내 인생이 다딱이', 'Gangplank', 25, 1.92, 40, 1.63, 54, 12]
# ['햄토리는자유에요', 'Leona', 46, 2.36, 46, 2.36, 52, 0]
# ['오로치먀루', 'Cassiopeia', 59, 2.62, 48, 3.82, 52, 429]
# ['DickSpicy', 'Skarner', 57, 3.19, 49, 2.15, 53, 188]
# [['인간말종망한인생', 'Jhin', 62, 3.24, 50, 3.13, 52, 42], ['내 인생이 다딱이', 'Gangplank', 25, 1.92, 40, 1.63, 54, 12], ['햄토리는자유에요', 'Leona', 53, 2.35, 46, 2.36, 52, 95], ['오로치먀루', 'Cassiopeia', 59, 2.62, 48, 3.82, 52, 429], ['DickSpicy', 'Skarner', 57, 3.19, 49, 2.15, 53, 188]]
# ['아싸라비요콩떡', 'Xayah', 33, 2.25, 49, 2.05, 52, 9]
# ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52]
# ['  빈 빈', 'Rakan', 52, 3.51, 55, 2.89, 52, 645]
# ['Moon 45', 'Taliyah', 71, 4.09, 55, 3.22, 67, 79]
# ['김치참치갈치', 'Yasuo', 56, 1.98, 42, 1.92, 54, 817]
# [['아싸라비요콩떡', 'Xayah', 33, 2.25, 49, 2.05, 52, 9], ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52], ['  빈 빈', 'Rakan', 52, 3.51, 55, 2.89, 52, 645], ['Moon 45', 'Taliyah', 71, 4.09, 55, 3.22, 67, 79], ['김치참치갈치', 'Yasuo', 56, 1.98, 42, 1.92, 54, 817]]
# ['Ar259x', 'Graves', 55, 3.1, 55, 3.1, 50, 220]
# ['강형진', 'Ezreal', 50, 2.67, 46, 2.0, 53, 12]
# ['말 안해도 알자나', 'Thresh', 50, 2.91, 55, 3.78, 52, 117]
# ['nij gnues', 'Lucian', 43, 2.63, 43, 2.63, 53, 0]
# ['운명따위부숴주지', 'Twisted Fate', 51, 3.04, 43, 2.62, 50, 192]
# [['Ar259x', 'Graves', 55, 3.1, 55, 3.1, 50, 220], ['강형진', 'Ezreal', 50, 2.67, 46, 2.0, 53, 12], ['말 안해도 알자나', 'Thresh', 50, 2.91, 55, 3.78, 52, 117], ['nij gnues', 'Lucian', 43, 2.63, 43, 2.63, 53, 0], ['운명따위부숴주지', 'Twisted Fate', 51, 3.04, 43, 2.62, 50, 192]]
# ['휘재인데', 'Twisted Fate', 57, 4.74, 54, 3.12, 55, 84]
# ['여 보 는', 'Jayce', 36, 1.69, 36, 1.69, 59, 0]
# ['안희동', 'Vi', 57, 2.47, 52, 4.47, 58, 42]
# ['chick', 'Ezreal', 53, 2.7, 57, 4.71, 50, 260]
# ['바미새', 'Bard', 53, 4.25, 59, 3.59, 51, 352]
# [['휘재인데', 'Twisted Fate', 57, 4.74, 54, 3.12, 55, 84], ['여 보 는', 'Jayce', 60, 1.79, 36, 1.69, 59, 5], ['안희동', 'Vi', 57, 2.47, 52, 4.47, 58, 42], ['chick', 'Ezreal', 53, 2.7, 57, 4.71, 50, 260], ['바미새', 'Bard', 53, 4.25, 59, 3.59, 51, 352]]
# ['택마왕', "Kai'Sa", 40, 2.77, 39, 2.49, 49, 45]
# ['keycxh', 'Rakan', 62, 2.95, 58, 2.4, 56, 280]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['제1홍', 'Lee Sin', 58, 3.96, 64, 4.23, 55, 307]
# ['D점멸텔들면F점멸', 'Zoe', 50, 2.19, 50, 2.19, 51, 0]
# [['택마왕', "Kai'Sa", 40, 2.77, 39, 2.49, 49, 45], ['keycxh', 'Rakan', 62, 2.95, 58, 2.4, 56, 280], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['제1홍', 'Lee Sin', 58, 3.96, 64, 4.23, 55, 307], ['D점멸텔들면F점멸', 'Zoe', 61, 3.34, 50, 2.19, 51, 36]]
# ['최함몰', 'Irelia', 57, 1.54, 41, 2.76, 57, 37]
# ['더 강해지고싶다', 'Thresh', 37, 3.19, 53, 2.74, 56, 27]
# ['평범한 숟가락', "Kai'Sa", 51, 2.54, 51, 2.54, 53, 0]
# ['난콘푸라이트', 'Hecarim', 53, 3.44, 60, 4.2, 54, 285]
# ['쇼메만날때까지', 'Orianna', 70, 4.4, 46, 2.37, 59, 33]
# [['최함몰', 'Irelia', 57, 1.54, 41, 2.76, 57, 37], ['더 강해지고싶다', 'Thresh', 37, 3.19, 53, 2.74, 56, 27], ['평범한 숟가락', "Kai'Sa", 53, 2.17, 51, 2.54, 53, 93], ['난콘푸라이트', 'Hecarim', 53, 3.44, 60, 4.2, 54, 285], ['쇼메만날때까지', 'Orianna', 70, 4.4, 46, 2.37, 59, 33]]
# ['Akaps', 'Jayce', 56, 1.81, 48, 2.45, 51, 84]
# ['BardK1ng', 'Karma', 67, 4.01, 51, 2.43, 57, 33]
# ['와드할줄알아요', 'Ezreal', 62, 3.78, 53, 2.59, 58, 34]
# ['DWG Ravine', "Rek'Sai", 71, 4.27, 58, 4.95, 79, 7]
# ['illiiliiliilli', 'Yasuo', 61, 2.95, 53, 5.84, 57, 206]
# [['Akaps', 'Jayce', 56, 1.81, 48, 2.45, 51, 84], ['BardK1ng', 'Karma', 67, 4.01, 51, 2.43, 57, 33], ['와드할줄알아요', 'Ezreal', 62, 3.78, 53, 2.59, 58, 34], ['DWG Ravine', "Rek'Sai", 71, 4.27, 58, 4.95, 79, 7], ['illiiliiliilli', 'Yasuo', 61, 2.95, 53, 5.84, 57, 206]]
# ['깨우친 자 전지용', 'Volibear', 56, 2.56, 48, 3.15, 51, 231]
# ['Xeyz', 'Lucian', 50, 2.21, 45, 2.72, 52, 24]
# ['오늘만을기다렸다', 'Lee Sin', 69, 3.73, 56, 3.4, 54, 32]
# ['숟가락 도구', 'Sett', 59, 3.96, 59, 3.96, 52, 0]
# ['cheerup thx', 'Azir', 53, 3.9, 53, 3.9, 50, 0]
# [['깨우친 자 전지용', 'Volibear', 56, 2.56, 48, 3.15, 51, 231], ['Xeyz', 'Lucian', 50, 2.21, 45, 2.72, 52, 24], ['오늘만을기다렸다', 'Lee Sin', 69, 3.73, 56, 3.4, 54, 32], ['숟가락 도구', 'Sett', 22, 1.97, 59, 3.96, 52, 9], ['cheerup thx', 'Azir', 44, 2.5, 53, 3.9, 50, 168]]
# ['해삐 언해피', 'Karma', 57, 3.28, 58, 3.12, 51, 90]
# ['극레어', 'Nunu & Willump', 65, 4.04, 56, 3.84, 56, 266]
# ['dlrlrhtlvdjdy', 'Sett', 39, 2.05, 39, 2.05, 46, 0]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['죽기위해사는사람', 'Jhin', 56, 4.05, 47, 2.75, 52, 82]
# [['해삐 언해피', 'Karma', 57, 3.28, 58, 3.12, 51, 90], ['극레어', 'Nunu & Willump', 65, 4.04, 56, 3.84, 56, 266], ['dlrlrhtlvdjdy', 'Sett', 69, 2.39, 39, 2.05, 46, 16], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['죽기위해사는사람', 'Jhin', 56, 4.05, 47, 2.75, 52, 82]]
# ['넌너무감정적이야', 'Orianna', 53, 3.13, 41, 2.43, 50, 66]
# ['최함몰', 'Sylas', 63, 2.51, 41, 2.76, 57, 51]
# ['토리초리', 'Kayn', 65, 3.47, 53, 2.7, 52, 23]
# ['bot no', 'Lucian', 47, 2.71, 50, 3.95, 51, 91]
# ['작은꼬마여우', 'Thresh', 58, 3.1, 59, 3.99, 53, 113]
# [['넌너무감정적이야', 'Orianna', 53, 3.13, 41, 2.43, 50, 66], ['최함몰', 'Sylas', 63, 2.51, 41, 2.76, 57, 51], ['토리초리', 'Kayn', 65, 3.47, 53, 2.7, 52, 23], ['bot no', 'Lucian', 47, 2.71, 50, 3.95, 51, 91], ['작은꼬마여우', 'Thresh', 58, 3.1, 59, 3.99, 53, 113]]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['토이 콤플렉스', 'Pyke', 50, 2.77, 53, 3.21, 51, 175]
# ['김해 마이', 'Master Yi', 54, 2.76, 45, 2.11, 51, 677]
# ['종 서', 'Jhin', 54, 2.6, 46, 1.43, 52, 50]
# ['Loneliest Girl', 'Sylas', 38, 1.49, 34, 1.73, 51, 108]
# [['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['토이 콤플렉스', 'Pyke', 50, 2.77, 53, 3.21, 51, 175], ['김해 마이', 'Master Yi', 54, 2.76, 45, 2.11, 51, 677], ['종 서', 'Jhin', 54, 2.6, 46, 1.43, 52, 50], ['Loneliest Girl', 'Sylas', 38, 1.49, 34, 1.73, 51, 108]]
# ['Alphabet N', 'Gangplank', 55, 2.87, 42, 1.74, 49, 163]
# ['adad00ad', 'Orianna', 47, 3.26, 47, 3.26, 50, 0]
# ['jungukb', 'Lee Sin', 34, 2.1, 56, 1.87, 49, 86]
# ['택마왕', 'Samira', 36, 1.5, 39, 2.49, 49, 11]
# ['캡틴승연', 'Bard', 51, 3.47, 54, 3.48, 54, 223]
# [['Alphabet N', 'Gangplank', 55, 2.87, 42, 1.74, 49, 163], ['adad00ad', 'Orianna', 47, 3.26, 47, 3.26, 50, 0], ['jungukb', 'Lee Sin', 34, 2.1, 56, 1.87, 49, 86], ['택마왕', 'Samira', 36, 1.5, 39, 2.49, 49, 11], ['캡틴승연', 'Bard', 51, 3.47, 54, 3.48, 54, 223]]
# ['하늘별자리', 'Annie', 54, 3.16, 52, 3.51, 51, 393]
# ['느금만수르', 'Lillia', 43, 3.27, 60, 3.67, 52, 21]
# ['Alphabet N', 'Gangplank', 55, 2.87, 42, 1.74, 49, 163]
# ['adad00ad', "Kai'Sa", 47, 3.26, 47, 3.26, 50, 0]
# ['sup한 복 수련 호', 'Janna', 56, 2.04, 56, 2.04, 57, 0]
# [['하늘별자리', 'Annie', 54, 3.16, 52, 3.51, 51, 393], ['느금만수르', 'Lillia', 43, 3.27, 60, 3.67, 52, 21], ['Alphabet N', 'Gangplank', 55, 2.87, 42, 1.74, 49, 163], ['adad00ad', "Kai'Sa", 47, 3.26, 47, 3.26, 50, 0], ['sup한 복 수련 호', 'Janna', 60, 3.48, 56, 2.04, 57, 92]]
# ['1927', 'Lee Sin', 53, 3.41, 65, 3.15, 54, 253]
# ['십년째다딱이', "Kai'Sa", 52, 2.98, 49, 2.85, 50, 192]
# ['닥쳐 씹련아', 'Leona', 58, 2.39, 47, 2.05, 54, 171]
# ['푸식이', 'Rengar', 52, 2.25, 36, 1.58, 51, 1055]
# ['용용이의하루', 'Zoe', 61, 2.64, 44, 2.05, 54, 62]
# [['1927', 'Lee Sin', 53, 3.41, 65, 3.15, 54, 253], ['십년째다딱이', "Kai'Sa", 52, 2.98, 49, 2.85, 50, 192], ['닥쳐 씹련아', 'Leona', 58, 2.39, 47, 2.05, 54, 171], ['푸식이', 'Rengar', 52, 2.25, 36, 1.58, 51, 1055], ['용용이의하루', 'Zoe', 61, 2.64, 44, 2.05, 54, 62]]
# ['Ddushiman', 'Poppy', 60, 3.32, 52, 2.99, 51, 72]
# ['11 08 2003', 'Zac', 40, 1.62, 40, 1.62, 51, 0]
# ['캡틴 카셀 ', 'Ziggs', 51, 3.28, 53, 2.8, 53, 47]
# ['최함몰', 'Sett', 53, 1.7, 41, 2.76, 57, 40]
# ['ad7777777', 'Ezreal', 55, 2.88, 44, 2.59, 52, 390]
# [['Ddushiman', 'Poppy', 60, 3.32, 52, 2.99, 51, 72], ['11 08 2003', 'Zac', 50, 2.43, 40, 1.62, 51, 28], ['캡틴 카셀 ', 'Ziggs', 51, 3.28, 53, 2.8, 53, 47], ['최함몰', 'Sett', 53, 1.7, 41, 2.76, 57, 40], ['ad7777777', 'Ezreal', 55, 2.88, 44, 2.59, 52, 390]]
# ['인내의결정체 1', 'Elise', 65, 3.08, 54, 2.97, 61, 20]
# ['롤카페 네임드', 'Yuumi', 85, 7.98, 52, 3.47, 59, 55]
# ['나 아퍼', 'Tristana', 72, 3.94, 53, 4.1, 59, 79]
# ['모세모세모세모세', 'Volibear', 20, 1.14, 36, 2.76, 49, 5]
# ['Moontoong', 'Zed', 55, 2.67, 54, 2.34, 51, 230]
# [['인내의결정체 1', 'Elise', 65, 3.08, 54, 2.97, 61, 20], ['롤카페 네임드', 'Yuumi', 85, 7.98, 52, 3.47, 59, 55], ['나 아퍼', 'Tristana', 72, 3.94, 53, 4.1, 59, 79], ['모세모세모세모세', 'Volibear', 20, 1.14, 36, 2.76, 49, 5], ['Moontoong', 'Zed', 55, 2.67, 54, 2.34, 51, 230]]
# ['카서스정글로마스터가려하는박민준', 'Karthus', 65, 3.09, 53, 2.24, 53, 420]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['십년째다딱이', 'Ashe', 52, 3.0, 49, 2.85, 50, 314]
# ['Lai kuan lin fan', 'Thresh', 50, 2.21, 51, 1.69, 52, 14]
# ['천안애니', 'Annie', 53, 2.79, 57, 2.46, 50, 652]
# [['카서스정글로마스터가려하는박민준', 'Karthus', 65, 3.09, 53, 2.24, 53, 420], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['십년째다딱이', 'Ashe', 52, 3.0, 49, 2.85, 50, 314], ['Lai kuan lin fan', 'Thresh', 50, 2.21, 51, 1.69, 52, 14], ['천안애니', 'Annie', 53, 2.79, 57, 2.46, 50, 652]]
# ['너는 잘수없다', 'Xin Zhao', 43, 5.09, 54, 4.16, 59, 7]
# ['국가의 창', 'Senna', 70, 3.32, 49, 3.08, 57, 23]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['망망따라', 'Ekko', 67, 3.05, 43, 1.72, 54, 51]
# ['미드가망하면', 'Rakan', 48, 3.95, 60, 5.27, 54, 33]
# [['너는 잘수없다', 'Xin Zhao', 43, 5.09, 54, 4.16, 59, 7], ['국가의 창', 'Senna', 70, 3.32, 49, 3.08, 57, 23], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['망망따라', 'Ekko', 67, 3.05, 43, 1.72, 54, 51], ['미드가망하면', 'Rakan', 48, 3.95, 60, 5.27, 54, 33]]
# ['장래희망김민준', "Kai'Sa", 48, 3.16, 48, 3.16, 49, 0]
# ['깜산이', 'Hecarim', 66, 3.02, 60, 3.15, 58, 109]
# ['최함몰', 'Maokai', 20, 0.89, 41, 2.76, 57, 5]
# ['승냥이누나이쁘다', 'Ekko', 55, 2.77, 43, 2.29, 50, 285]
# ['단일 챔피언', 'Pyke', 44, 2.8, 50, 2.04, 49, 114]
# [['장래희망김민준', "Kai'Sa", 49, 2.84, 48, 3.16, 49, 49], ['깜산이', 'Hecarim', 66, 3.02, 60, 3.15, 58, 109], ['최함몰', 'Maokai', 20, 0.89, 41, 2.76, 57, 5], ['승냥이누나이쁘다', 'Ekko', 55, 2.77, 43, 2.29, 50, 285], ['단일 챔피언', 'Pyke', 44, 2.8, 50, 2.04, 49, 114]]
# ['최함몰', 'Sett', 53, 1.7, 41, 2.76, 57, 40]
# ['IiI tracy', 'Lillia', 54, 3.17, 55, 3.01, 53, 111]
# ['탄산라임', 'Pyke', 45, 1.82, 45, 1.82, 51, 0]
# ['시간 o 3 2O o', 'Ashe', 54, 2.93, 51, 2.77, 50, 48]
# ['수우능', 'Heimerdinger', 58, 2.39, 40, 1.72, 55, 388]
# [['최함몰', 'Sett', 53, 1.7, 41, 2.76, 57, 40], ['IiI tracy', 'Lillia', 54, 3.17, 55, 3.01, 53, 111], ['탄산라임', 'Pyke', 52, 2.24, 45, 1.82, 51, 166], ['시간 o 3 2O o', 'Ashe', 54, 2.93, 51, 2.77, 50, 48], ['수우능', 'Heimerdinger', 58, 2.39, 40, 1.72, 55, 388]]
# ['방황하는뽀삐', 'Poppy', 54, 2.6, 45, 1.72, 54, 816]
# ['김좌불1', 'Lillia', 54, 3.25, 54, 3.25, 52, 0]
# ['김김진진효효', 'Lulu', 61, 3.91, 61, 3.91, 51, 0]
# ['최강원딜박두식', 'Ashe', 48, 3.19, 48, 3.19, 52, 0]
# ['승냥이누나이쁘다', 'Ekko', 55, 2.77, 43, 2.29, 50, 285]
# [['방황하는뽀삐', 'Poppy', 54, 2.6, 45, 1.72, 54, 816], ['김좌불1', 'Lillia', 47, 3.29, 54, 3.25, 52, 91], ['김김진진효효', 'Lulu', 44, 2.67, 61, 3.91, 51, 36], ['최강원딜박두식', 'Ashe', 55, 2.35, 48, 3.19, 52, 130], ['승냥이누나이쁘다', 'Ekko', 55, 2.77, 43, 2.29, 50, 285]]
# ['불꽃주먹추성훈', 'Akali', 60, 3.05, 42, 2.3, 60, 276]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['당 신', 'Lucian', 64, 2.64, 47, 1.94, 51, 11]
# ['Medication', 'Thresh', 54, 3.83, 59, 2.47, 50, 477]
# ['롤잘알', 'Elise', 58, 2.53, 52, 1.88, 52, 594]
# [['불꽃주먹추성훈', 'Akali', 60, 3.05, 42, 2.3, 60, 276], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['당 신', 'Lucian', 64, 2.64, 47, 1.94, 51, 11], ['Medication', 'Thresh', 54, 3.83, 59, 2.47, 50, 477], ['롤잘알', 'Elise', 58, 2.53, 52, 1.88, 52, 594]]
# ['정글류저', 'Kayn', 49, 1.85, 52, 2.45, 50, 123]
# ['Eureka', 'Heimerdinger', 57, 1.78, 54, 2.42, 50, 1404]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['두달만', 'Morgana', 56, 2.7, 50, 2.66, 54, 331]
# ['곰돌이푸우찡', 'Caitlyn', 62, 2.72, 52, 2.94, 50, 21]
# [['정글류저', 'Kayn', 49, 1.85, 52, 2.45, 50, 123], ['Eureka', 'Heimerdinger', 57, 1.78, 54, 2.42, 50, 1404], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['두달만', 'Morgana', 56, 2.7, 50, 2.66, 54, 331], ['곰돌이푸우찡', 'Caitlyn', 62, 2.72, 52, 2.94, 50, 21]]
# ['애용인데용', 'Twisted Fate', 54, 3.06, 50, 2.17, 51, 352]
# ['I1II1I1II1I', 'Rakan', 56, 3.72, 44, 2.56, 50, 160]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['그러면뭐할까', 'Lillia', 51, 3.12, 47, 2.43, 51, 199]
# ['나진 소드', 'Ashe', 57, 2.95, 48, 1.96, 50, 42]
# [['애용인데용', 'Twisted Fate', 54, 3.06, 50, 2.17, 51, 352], ['I1II1I1II1I', 'Rakan', 56, 3.72, 44, 2.56, 50, 160], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['그러면뭐할까', 'Lillia', 51, 3.12, 47, 2.43, 51, 199], ['나진 소드', 'Ashe', 57, 2.95, 48, 1.96, 50, 42]]
# ['토리초리', 'Lee Sin', 54, 2.73, 53, 2.7, 52, 356]
# ['상체게임킹텀뽑기', 'Jhin', 67, 3.66, 53, 5.02, 58, 9]
# ['일베잡는 정예은', 'Taliyah', 45, 2.31, 53, 1.61, 55, 56]
# ['Oo SG', 'Pantheon', 44, 2.51, 44, 2.51, 50, 0]
# ['최함몰', 'Mordekaiser', 46, 1.55, 41, 2.76, 57, 24]
# [['토리초리', 'Lee Sin', 54, 2.73, 53, 2.7, 52, 356], ['상체게임킹텀뽑기', 'Jhin', 67, 3.66, 53, 5.02, 58, 9], ['일베잡는 정예은', 'Taliyah', 45, 2.31, 53, 1.61, 55, 56], ['Oo SG', 'Pantheon', 60, 2.19, 44, 2.51, 50, 48], ['최함몰', 'Mordekaiser', 46, 1.55, 41, 2.76, 57, 24]]
# ['콜라마실거야', 'Lee Sin', 45, 2.66, 45, 2.66, 51, 0]
# ['suvccc', "Kai'Sa", 35, 2.45, 50, 2.7, 51, 23]
# ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52]
# ['화이팅X파이팅O', 'Wukong', 55, 2.85, 45, 2.31, 54, 33]
# ['닉변은생각해봄', 'Karma', 58, 2.92, 59, 2.52, 56, 12]
# [['콜라마실거야', 'Lee Sin', 45, 2.66, 45, 2.66, 51, 0], ['suvccc', "Kai'Sa", 35, 2.45, 50, 2.7, 51, 23], ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52], ['화이팅X파이팅O', 'Wukong', 55, 2.85, 45, 2.31, 54, 33], ['닉변은생각해봄', 'Karma', 58, 2.92, 59, 2.52, 56, 12]]
# ['Loneliest Girl', 'Jax', 58, 2.24, 34, 1.73, 51, 1490]
# ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40]
# ['청순한 주황버섯', 'Lux', 59, 3.61, 55, 2.86, 52, 54]
# ['Nigror', 'Lillia', 54, 3.52, 60, 2.59, 50, 74]
# ['Traho', 'Caitlyn', 58, 3.33, 52, 3.75, 51, 113]
# [['Loneliest Girl', 'Jax', 58, 2.24, 34, 1.73, 51, 1490], ['최함몰', 'Renekton', 60, 1.79, 41, 2.76, 57, 40], ['청순한 주황버섯', 'Lux', 59, 3.61, 55, 2.86, 52, 54], ['Nigror', 'Lillia', 54, 3.52, 60, 2.59, 50, 74], ['Traho', 'Caitlyn', 58, 3.33, 52, 3.75, 51, 113]]
# ['yuyuseong', 'Morgana', 62, 4.29, 62, 4.29, 51, 0]
# ['Lv 1 세구리', 'Camille', 50, 2.14, 47, 2.83, 54, 74]
# ['원딜이죽지않아', 'Twisted Fate', 45, 3.21, 45, 3.21, 51, 0]
# ['정신병있는베인', 'Vayne', 54, 1.89, 39, 2.38, 54, 231]
# ['god호신', 'Nidalee', 35, 3.11, 59, 2.32, 55, 17]
# [['yuyuseong', 'Morgana', 49, 2.36, 62, 4.29, 51, 274], ['Lv 1 세구리', 'Camille', 50, 2.14, 47, 2.83, 54, 74], ['원딜이죽지않아', 'Twisted Fate', 33, 3.75, 45, 3.21, 51, 3], ['정신병있는베인', 'Vayne', 54, 1.89, 39, 2.38, 54, 231], ['god호신', 'Nidalee', 35, 3.11, 59, 2.32, 55, 17]]
# ['카이팅잘하는석이', 'Ezreal', 52, 2.64, 44, 2.05, 51, 140]
# ['넌나의Lollipop', 'Kindred', 53, 2.35, 56, 2.01, 49, 32]
# ['Look at me1', 'Orianna', 41, 2.53, 43, 2.22, 50, 37]
# ['잘생긴주승', 'Hecarim', 35, 1.78, 35, 1.78, 52, 0]
# ['23 James', 'Thresh', 50, 2.29, 47, 2.89, 52, 12]
# [['카이팅잘하는석이', 'Ezreal', 52, 2.64, 44, 2.05, 51, 140], ['넌나의Lollipop', 'Kindred', 53, 2.35, 56, 2.01, 49, 32], ['Look at me1', 'Orianna', 41, 2.53, 43, 2.22, 50, 37], ['잘생긴주승', 'Hecarim', 56, 2.86, 35, 1.78, 52, 743], ['23 James', 'Thresh', 50, 2.29, 47, 2.89, 52, 12]]
# ['날씨요정 정현', 'Jhin', 66, 4.51, 52, 3.16, 51, 58]
# ['미드GAP 딱 대 ', 'Talon', 58, 2.87, 48, 2.69, 54, 620]
# ['Iwalks1sklawI', 'Sylas', 58, 2.32, 43, 2.17, 52, 118]
# ['Darkstar', 'Nidalee', 61, 2.9, 54, 1.92, 50, 28]
# ['손박차', 'Pantheon', 55, 2.6, 48, 1.95, 49, 20]
# [['날씨요정 정현', 'Jhin', 66, 4.51, 52, 3.16, 51, 58], ['미드GAP 딱 대 ', 'Talon', 58, 2.87, 48, 2.69, 54, 620], ['Iwalks1sklawI', 'Sylas', 58, 2.32, 43, 2.17, 52, 118], ['Darkstar', 'Nidalee', 61, 2.9, 54, 1.92, 50, 28], ['손박차', 'Pantheon', 55, 2.6, 48, 1.95, 49, 20]]
# ['진청색', 'Pantheon', 51, 2.34, 52, 2.55, 56, 93]
# ['핑그ri', 'Ezreal', 50, 2.72, 54, 3.91, 55, 50]
# ['김좌불1', 'Lillia', 54, 3.25, 54, 3.25, 52, 0]
# ['최함몰', 'Sett', 53, 1.7, 41, 2.76, 57, 40]
# ['겨드랑왕자', 'Ahri', 59, 3.77, 59, 3.31, 52, 246]
# [['진청색', 'Pantheon', 51, 2.34, 52, 2.55, 56, 93], ['핑그ri', 'Ezreal', 50, 2.72, 54, 3.91, 55, 50], ['김좌불1', 'Lillia', 47, 3.29, 54, 3.25, 52, 91], ['최함몰', 'Sett', 53, 1.7, 41, 2.76, 57, 40], ['겨드랑왕자', 'Ahri', 59, 3.77, 59, 3.31, 52, 246]]
# ['최일수', 'Riven', 38, 1.71, 38, 1.71, 51, 0]
# ['모모88', 'Jhin', 47, 3.24, 56, 2.57, 52, 90]
# ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52]
# ['와드먹어요', 'Thresh', 59, 3.45, 49, 3.5, 50, 215]
# ['곧없어질 아디', 'Nidalee', 59, 3.64, 51, 1.87, 49, 176]
# [['최일수', 'Riven', 56, 1.93, 38, 1.71, 51, 304], ['모모88', 'Jhin', 47, 3.24, 56, 2.57, 52, 90], ['최함몰', 'Galio', 69, 3.19, 41, 2.76, 57, 52], ['와드먹어요', 'Thresh', 59, 3.45, 49, 3.5, 50, 215], ['곧없어질 아디', 'Nidalee', 59, 3.64, 51, 1.87, 49, 176]]
# ['Gara4Dae', 'Kennen', 46, 2.1, 37, 2.02, 50, 81]
# ['Korean Center', 'Talon', 54, 2.3, 46, 2.14, 50, 100]
# ['뇽은이', 'Braum', 48, 2.04, 48, 2.04, 58, 0]
# ['김다현 보고싶다', 'Aphelios', 56, 1.65, 45, 2.01, 48, 9]
# ['Pedeo', 'Nidalee', 57, 2.77, 56, 2.32, 51, 299]
# [['Gara4Dae', 'Kennen', 46, 2.1, 37, 2.02, 50, 81], ['Korean Center', 'Talon', 54, 2.3, 46, 2.14, 50, 100], ['뇽은이', 'Braum', 53, 2.71, 48, 2.04, 58, 17], ['김다현 보고싶다', 'Aphelios', 56, 1.65, 45, 2.01, 48, 9], ['Pedeo', 'Nidalee', 57, 2.77, 56, 2.32, 51, 299]]
# ['요도새', 'Braum', 57, 3.17, 51, 2.44, 52, 7]
# ['여기말고아무대나', 'Twisted Fate', 33, 2.17, 47, 2.13, 51, 12]
# ['Be freee', 'Ashe', 46, 2.87, 46, 2.87, 51, 0]
# ['eiir', 'Nidalee', 51, 3.0, 38, 1.51, 49, 55]
# ['Incognitus', 'Jax', 50, 1.72, 35, 1.34, 51, 349]
# [['요도새', 'Braum', 57, 3.17, 51, 2.44, 52, 7], ['여기말고아무대나', 'Twisted Fate', 33, 2.17, 47, 2.13, 51, 12], ['Be freee', 'Ashe', 44, 2.59, 46, 2.87, 51, 73], ['eiir', 'Nidalee', 51, 3.0, 38, 1.51, 49, 55], ['Incognitus', 'Jax', 50, 1.72, 35, 1.34, 51, 349]]
# ['최함몰', 'Sylas', 63, 2.51, 41, 2.76, 57, 51]
# ['점수포기 남탓x', 'Ekko', 39, 1.86, 39, 1.86, 51, 0]
# ['겨울초', 'Aatrox', 50, 2.25, 50, 4.93, 50, 42]
# ['가온서비', 'Leona', 53, 2.16, 48, 2.33, 52, 752]
# ['덕정귀요미', 'Ezreal', 55, 2.94, 49, 3.1, 53, 96]
# [['최함몰', 'Sylas', 63, 2.51, 41, 2.76, 57, 51], ['점수포기 남탓x', 'Ekko', 71, 3.82, 39, 1.86, 51, 21], ['겨울초', 'Aatrox', 50, 2.25, 50, 4.93, 50, 42], ['가온서비', 'Leona', 53, 2.16, 48, 2.33, 52, 752], ['덕정귀요미', 'Ezreal', 55, 2.94, 49, 3.1, 53, 96]]
# ['웃을 수 없어요', 'Jhin', 62, 3.48, 44, 2.19, 51, 26]
# ['어릴땐 잘했어', 'Elise', 55, 2.78, 53, 2.09, 53, 42]
# ['D점멸씀', 'Galio', 64, 3.88, 39, 2.53, 50, 59]
# ['CHPuth ', 'Camille', 55, 2.26, 43, 1.89, 52, 230]
# ['ALLlinerrr', 'Pantheon', 62, 2.27, 50, 2.06, 55, 181]
# [['웃을 수 없어요', 'Jhin', 62, 3.48, 44, 2.19, 51, 26], ['어릴땐 잘했어', 'Elise', 55, 2.78, 53, 2.09, 53, 42], ['D점멸씀', 'Galio', 64, 3.88, 39, 2.53, 50, 59], ['CHPuth ', 'Camille', 55, 2.26, 43, 1.89, 52, 230], ['ALLlinerrr', 'Pantheon', 62, 2.27, 50, 2.06, 55, 181]]
# ['호텔 배리나', 'Akali', 59, 2.59, 42, 2.5, 59, 68]
# ['재두기', 'Graves', 48, 2.92, 59, 2.66, 57, 21]
# ['베 2', 'Veigar', 56, 2.14, 49, 1.83, 54, 285]
# ['노시안', 'Pyke', 44, 1.95, 52, 3.37, 51, 25]
# ['최함몰', 'Aatrox', 53, 1.9, 41, 2.76, 57, 45]
# [['호텔 배리나', 'Akali', 59, 2.59, 42, 2.5, 59, 68], ['재두기', 'Graves', 48, 2.92, 59, 2.66, 57, 21], ['베 2', 'Veigar', 56, 2.14, 49, 1.83, 54, 285], ['노시안', 'Pyke', 44, 1.95, 52, 3.37, 51, 25], ['최함몰', 'Aatrox', 53, 1.9, 41, 2.76, 57, 45]]
# ['기분따라딸침', 'Sett', 63, 2.69, 41, 3.47, 55, 43]
# ['찹쌀 꿀 약과', 'Akali', 49, 2.88, 49, 2.88, 56, 0]
# ['히히오오', 'Kayn', 67, 2.74, 49, 2.04, 42, 6]
# ['총맞고뱅뱅', 'Alistar', 50, 1.91, 45, 2.28, 51, 2]
# ['그랜드 노리야끼', 'Samira', 50, 2.71, 56, 3.32, 55, 2]
# [['기분따라딸침', 'Sett', 63, 2.69, 41, 3.47, 55, 43], ['찹쌀 꿀 약과', 'Akali', 41, 1.76, 49, 2.88, 56, 29], ['히히오오', 'Kayn', 67, 2.74, 49, 2.04, 42, 6], ['총맞고뱅뱅', 'Alistar', 50, 1.91, 45, 2.28, 51, 2], ['그랜드 노리야끼', 'Samira', 50, 2.71, 56, 3.32, 55, 2]]
# ['LAKAN', 'Ashe', 57, 2.59, 49, 2.59, 54, 118]
# ['TOP IRONMAN', 'Lux', 43, 1.13, 41, 2.84, 54, 7]
# ['진눈깨비 주작', 'Skarner', 50, 2.92, 43, 1.94, 48, 6]
# ['트롤왕과트롤짱', 'Illaoi', 50, 2.17, 37, 1.09, 27, 2]
# ['기작은고양이', 'Blitzcrank', 70, 2.22, 46, 1.67, 54, 10]
# [['LAKAN', 'Ashe', 57, 2.59, 49, 2.59, 54, 118], ['TOP IRONMAN', 'Lux', 43, 1.13, 41, 2.84, 54, 7], ['진눈깨비 주작', 'Skarner', 50, 2.92, 43, 1.94, 48, 6], ['트롤왕과트롤짱', 'Illaoi', 50, 2.17, 37, 1.09, 27, 2], ['기작은고양이', 'Blitzcrank', 70, 2.22, 46, 1.67, 54, 10]]
# ['Zendiue', 'Ezreal', 54, 2.16, 47, 2.11, 48, 59]
# ['또 오해영', 'Syndra', 63, 2.97, 54, 2.32, 59, 8]
# ['최유정의 발닦개', 'Aatrox', 50, 3.21, 55, 3.0, 50, 4]
# ['효 린', 'Sett', 70, 3.52, 52, 2.38, 50, 20]
# ['김치공주', 'Lillia', 36, 1.62, 36, 1.62, 48, 0]
# [['Zendiue', 'Ezreal', 54, 2.16, 47, 2.11, 48, 59], ['또 오해영', 'Syndra', 63, 2.97, 54, 2.32, 59, 8], ['최유정의 발닦개', 'Aatrox', 50, 3.21, 55, 3.0, 50, 4], ['효 린', 'Sett', 70, 3.52, 52, 2.38, 50, 20], ['김치공주', 'Lillia', 53, 2.31, 36, 1.62, 48, 43]]
# ['Stark is alive', 'Jinx', 60, 3.13, 55, 2.19, 50, 10]
# ['bigddakha', 'Lucian', 48, 1.92, 50, 2.03, 53, 33]
# ['MaiBeck98', 'Master Yi', 43, 1.83, 50, 2.24, 50, 142]
# ['Ka Chi Ma', 'Blitzcrank', 50, 2.62, 55, 2.33, 49, 2]
# ['Shape Of Youuu', 'Twisted Fate', 51, 2.52, 51, 2.52, 53, 0]
# [['Stark is alive', 'Jinx', 60, 3.13, 55, 2.19, 50, 10], ['bigddakha', 'Lucian', 48, 1.92, 50, 2.03, 53, 33], ['MaiBeck98', 'Master Yi', 43, 1.83, 50, 2.24, 50, 142], ['Ka Chi Ma', 'Blitzcrank', 50, 2.62, 55, 2.33, 49, 2], ['Shape Of Youuu', 'Twisted Fate', 43, 1.56, 51, 2.52, 53, 7]]
# ['정치하면 돌덩이', 'Lee Sin', 44, 2.21, 44, 2.21, 18, 0]
# ['ZZCXZ', 'Fizz', 68, 4.17, 44, 3.07, 52, 22]
# ['초보자준준씌', 'Mordekaiser', 43, 1.81, 45, 2.4, 54, 7]
# ['찹쌀 꿀 약과', 'Sett', 49, 2.88, 49, 2.88, 56, 0]
# ['뇌지컬을키우자', 'Aphelios', 25, 1.35, 27, 1.74, 50, 4]
# [['정치하면 돌덩이', 'Lee Sin', 44, 2.21, 44, 2.21, 18, 0], ['ZZCXZ', 'Fizz', 68, 4.17, 44, 3.07, 52, 22], ['초보자준준씌', 'Mordekaiser', 43, 1.81, 45, 2.4, 54, 7], ['찹쌀 꿀 약과', 'Sett', 78, 3.18, 49, 2.88, 56, 9], ['뇌지컬을키우자', 'Aphelios', 25, 1.35, 27, 1.74, 50, 4]]
# ['숨결을 만지던 밤', 'Akali', 68, 2.34, 46, 1.8, 61, 22]
# ['섹시한 핫세', 'Irelia', 52, 1.74, 54, 3.91, 50, 33]
# ['룰루 바드 잔나', 'Elise', 45, 1.99, 45, 1.99, 49, 0]
# ['에밀리 다이어', 'Seraphine', 60, 2.33, 50, 2.95, 50, 5]
# ['DRX 080', 'Jhin', 44, 2.01, 44, 2.01, 62, 0]
# [['숨결을 만지던 밤', 'Akali', 68, 2.34, 46, 1.8, 61, 22], ['섹시한 핫세', 'Irelia', 52, 1.74, 54, 3.91, 50, 33], ['룰루 바드 잔나', 'Elise', 67, 2.15, 45, 1.99, 49, 3], ['에밀리 다이어', 'Seraphine', 60, 2.33, 50, 2.95, 50, 5], ['DRX 080', 'Jhin', 44, 2.01, 44, 2.01, 62, 0]]
# ['ADout CarRy', 'Lucian', 43, 2.43, 43, 2.43, 49, 0]
# ['단검이 어디있지', 'Camille', 44, 2.46, 44, 2.46, 52, 0]
# ['안전밸트꼭매라', 'Rammus', 52, 2.34, 52, 2.34, 51, 0]
# ['메라병 그랩', 'Nami', 53, 4.26, 53, 4.26, 70, 0]
# ['하은이 미드', 'Anivia', 49, 2.21, 49, 2.21, 52, 0]
# [['ADout CarRy', 'Lucian', 40, 1.98, 43, 2.43, 49, 30], ['단검이 어디있지', 'Camille', 44, 2.46, 44, 2.46, 52, 0], ['안전밸트꼭매라', 'Rammus', 52, 2.34, 52, 2.34, 51, 0], ['메라병 그랩', 'Nami', 53, 4.26, 53, 4.26, 70, 0], ['하은이 미드', 'Anivia', 49, 2.21, 49, 2.21, 52, 0]]
# ['AfreecaTV 이인수', 'LeBlanc', 67, 2.62, 51, 2.53, 52, 9]
# ['살려주시오제발', 'Kindred', 50, 3.08, 53, 3.66, 55, 2]
# ['우한폐렴인데요', 'Ashe', 50, 2.16, 45, 1.82, 50, 4]
# ['전략적버러지', 'Seraphine', 50, 4.15, 50, 4.15, 60, 0]
# ['서수현귀엽다', 'Pantheon', 49, 1.8, 49, 1.8, 29, 0]
# [['AfreecaTV 이인수', 'LeBlanc', 67, 2.62, 51, 2.53, 52, 9], ['살려주시오제발', 'Kindred', 50, 3.08, 53, 3.66, 55, 2], ['우한폐렴인데요', 'Ashe', 50, 2.16, 45, 1.82, 50, 4], ['전략적버러지', 'Seraphine', 50, 4.15, 50, 4.15, 60, 0], ['서수현귀엽다', 'Pantheon', 0, 0.6, 49, 1.8, 29, 1]]
# ['clean man', 'Akali', 60, 2.16, 39, 1.54, 52, 20]
# ['동동이소환사', "Kai'Sa", 50, 1.89, 45, 1.63, 41, 8]
# ['버려진 희재', 'Zed', 50, 2.0, 43, 2.31, 52, 4]
# ['XXGXX', 'Kindred', 48, 2.21, 48, 2.21, 57, 0]
# ['Uahera Ahri', 'Yuumi', 46, 4.6, 49, 2.22, 49, 37]
# [['clean man', 'Akali', 60, 2.16, 39, 1.54, 52, 20], ['동동이소환사', "Kai'Sa", 50, 1.89, 45, 1.63, 41, 8], ['버려진 희재', 'Zed', 50, 2.0, 43, 2.31, 52, 4], ['XXGXX', 'Kindred', 48, 2.21, 48, 2.21, 57, 0], ['Uahera Ahri', 'Yuumi', 46, 4.6, 49, 2.22, 49, 37]]
# ['Bugeunga', 'Syndra', 43, 2.78, 43, 2.78, 50, 0]
# ['Resonating', 'Lucian', 33, 1.81, 49, 2.01, 53, 9]
# ['멀루니', 'Lee Sin', 56, 2.85, 53, 2.4, 49, 54]
# ['야채가제일좋아', 'Lux', 63, 4.59, 54, 3.43, 51, 158]
# ['시립대제닉스', 'Ezreal', 50, 2.25, 41, 1.97, 56, 16]
# [['Bugeunga', 'Syndra', 75, 2.37, 43, 2.78, 50, 4], ['Resonating', 'Lucian', 33, 1.81, 49, 2.01, 53, 9], ['멀루니', 'Lee Sin', 56, 2.85, 53, 2.4, 49, 54], ['야채가제일좋아', 'Lux', 63, 4.59, 54, 3.43, 51, 158], ['시립대제닉스', 'Ezreal', 50, 2.25, 41, 1.97, 56, 16]]
# ['유동성있는플레이', 'Sett', 50, 1.78, 46, 2.82, 63, 6]
# ['Wolf4', 'Nasus', 70, 3.75, 49, 2.69, 67, 23]
# ['현철랭', 'Malzahar', 57, 2.2, 51, 3.56, 49, 30]
# ['DSMC Garack', 'Senna', 58, 2.79, 55, 2.56, 51, 125]
# ['으캬캬컁컁', 'Hecarim', 61, 3.92, 52, 3.29, 67, 84]
# [['유동성있는플레이', 'Sett', 50, 1.78, 46, 2.82, 63, 6], ['Wolf4', 'Nasus', 70, 3.75, 49, 2.69, 67, 23], ['현철랭', 'Malzahar', 57, 2.2, 51, 3.56, 49, 30], ['DSMC Garack', 'Senna', 58, 2.79, 55, 2.56, 51, 125], ['으캬캬컁컁', 'Hecarim', 61, 3.92, 52, 3.29, 67, 84]]
# ['일단 진정해', 'Elise', 54, 2.26, 49, 2.19, 58, 13]
# ['wu yoo', 'Akali', 80, 5.81, 55, 4.06, 61, 5]
# ['소환사승기', 'Samira', 43, 2.61, 43, 2.61, 49, 0]
# ['호잇호잇하면 킬', 'Seraphine', 49, 2.93, 49, 2.93, 44, 0]
# ['Manikin ', 'Yone', 36, 1.49, 46, 1.91, 51, 11]
# [['일단 진정해', 'Elise', 54, 2.26, 49, 2.19, 58, 13], ['wu yoo', 'Akali', 80, 5.81, 55, 4.06, 61, 5], ['소환사승기', 'Samira', 43, 2.61, 43, 2.61, 49, 0], ['호잇호잇하면 킬', 'Seraphine', 49, 2.93, 49, 2.93, 44, 0], ['Manikin ', 'Yone', 36, 1.49, 46, 1.91, 51, 11]]
# ['809전경대', "Kai'Sa", 48, 2.0, 46, 2.04, 51, 31]
# ['규 석', 'Urgot', 59, 2.44, 41, 2.75, 51, 238]
# ['빨리먹기', 'Blitzcrank', 47, 2.7, 47, 2.7, 51, 0]
# ['섹끈한힐러', 'Karthus', 76, 3.52, 60, 3.39, 60, 38]
# ['wu yoo', 'Irelia', 50, 3.83, 55, 4.06, 61, 2]
# [['809전경대', "Kai'Sa", 48, 2.0, 46, 2.04, 51, 31], ['규 석', 'Urgot', 59, 2.44, 41, 2.75, 51, 238], ['빨리먹기', 'Blitzcrank', 60, 1.45, 47, 2.7, 51, 5], ['섹끈한힐러', 'Karthus', 76, 3.52, 60, 3.39, 60, 38], ['wu yoo', 'Irelia', 50, 3.83, 55, 4.06, 61, 2]]
# ['청산대장', 'Kayn', 50, 2.28, 46, 1.87, 57, 8]
# ['유후봐아앙', 'Vayne', 61, 2.24, 42, 1.83, 49, 28]
# ['오류동 냐옹이', 'Nunu & Willump', 43, 3.42, 43, 3.42, 59, 0]
# ['0당느0', 'Soraka', 80, 2.0, 48, 2.08, 56, 5]
# ['갈 까', 'Fiora', 38, 1.3, 52, 1.82, 54, 8]
# [['청산대장', 'Kayn', 50, 2.28, 46, 1.87, 57, 8], ['유후봐아앙', 'Vayne', 61, 2.24, 42, 1.83, 49, 28], ['오류동 냐옹이', 'Nunu & Willump', 50, 1.93, 43, 3.42, 59, 6], ['0당느0', 'Soraka', 80, 2.0, 48, 2.08, 56, 5], ['갈 까', 'Fiora', 38, 1.3, 52, 1.82, 54, 8]]
# ['809전경대', 'Jhin', 46, 2.29, 46, 2.04, 51, 56]
# ['규 석', 'Urgot', 59, 2.44, 41, 2.75, 51, 238]
# ['빨리먹기', 'Yuumi', 47, 2.7, 47, 2.7, 51, 0]
# ['섹끈한힐러', 'Anivia', 33, 2.42, 60, 3.39, 60, 9]
# ['wu yoo', 'Lee Sin', 50, 14.75, 54, 3.97, 61, 2]
# [['809전경대', 'Jhin', 46, 2.29, 46, 2.04, 51, 56], ['규 석', 'Urgot', 59, 2.44, 41, 2.75, 51, 238], ['빨리먹기', 'Yuumi', 68, 5.83, 47, 2.7, 51, 37], ['섹끈한힐러', 'Anivia', 33, 2.42, 60, 3.39, 60, 9], ['wu yoo', 'Lee Sin', 50, 14.75, 54, 3.97, 61, 2]]
# ['0 호', 'Blitzcrank', 29, 2.24, 60, 3.0, 34, 14]
# ['Mr갱플', 'Elise', 42, 3.08, 57, 3.55, 36, 24]
# ['고 멜', 'Cassiopeia', 29, 1.5, 43, 2.36, 50, 7]
# ['사장님 행쇼', 'Maokai', 52, 2.99, 45, 1.86, 50, 23]
# ['봉구상구', 'Ashe', 48, 2.96, 53, 3.16, 50, 23]
# [['0 호', 'Blitzcrank', 29, 2.24, 60, 3.0, 34, 14], ['Mr갱플', 'Elise', 42, 3.08, 57, 3.55, 36, 24], ['고 멜', 'Cassiopeia', 29, 1.5, 43, 2.36, 50, 7], ['사장님 행쇼', 'Maokai', 52, 2.99, 45, 1.86, 50, 23], ['봉구상구', 'Ashe', 48, 2.96, 53, 3.16, 50, 23]]
# ['809전경대', 'Sivir', 58, 2.54, 46, 2.04, 51, 31]
# ['규 석', 'Urgot', 59, 2.44, 41, 2.75, 51, 238]
# ['빨리먹기', 'Yuumi', 47, 2.7, 47, 2.7, 51, 0]
# ['섹끈한힐러', 'Karthus', 76, 3.52, 60, 3.39, 60, 38]
# ['wu yoo', 'Akali', 80, 5.81, 54, 3.97, 61, 5]
# [['809전경대', 'Sivir', 58, 2.54, 46, 2.04, 51, 31], ['규 석', 'Urgot', 59, 2.44, 41, 2.75, 51, 238], ['빨리먹기', 'Yuumi', 68, 5.83, 47, 2.7, 51, 37], ['섹끈한힐러', 'Karthus', 76, 3.52, 60, 3.39, 60, 38], ['wu yoo', 'Akali', 80, 5.81, 54, 3.97, 61, 5]]
# ['809전경대', 'Caitlyn', 47, 2.2, 46, 2.04, 51, 192]
# ['규 석', 'Urgot', 59, 2.44, 41, 2.75, 51, 238]
# ['빨리먹기', 'Lux', 47, 2.7, 47, 2.7, 51, 0]
# ['섹끈한힐러', 'Karthus', 76, 3.52, 60, 3.39, 60, 38]
# ['wu yoo', 'Akali', 80, 5.81, 54, 3.97, 61, 5]
# [['809전경대', 'Caitlyn', 47, 2.2, 46, 2.04, 51, 192], ['규 석', 'Urgot', 59, 2.44, 41, 2.75, 51, 238], ['빨리먹기', 'Lux', 20, 2.05, 47, 2.7, 51, 5], ['섹끈한힐러', 'Karthus', 76, 3.52, 60, 3.39, 60, 38], ['wu yoo', 'Akali', 80, 5.81, 54, 3.97, 61, 5]]
# ['두굥두굥', 'Lee Sin', 56, 2.7, 50, 3.31, 52, 96]
# ['DRX Ohria', 'Viktor', 44, 2.23, 44, 2.23, 50, 0]
# ['나좀봐주면안되냐', "Kai'Sa", 54, 3.84, 42, 2.45, 59, 37]
# ['진쮸진쮸', 'Fiora', 52, 2.42, 52, 2.42, 52, 0]
# ['캉테일', 'Galio', 80, 2.79, 48, 2.42, 46, 5]
# [['두굥두굥', 'Lee Sin', 56, 2.7, 50, 3.31, 52, 96], ['DRX Ohria', 'Viktor', 44, 2.23, 44, 2.23, 50, 0], ['나좀봐주면안되냐', "Kai'Sa", 54, 3.84, 42, 2.45, 59, 37], ['진쮸진쮸', 'Fiora', 52, 2.42, 52, 2.42, 52, 0], ['캉테일', 'Galio', 80, 2.79, 48, 2.42, 46, 5]]
# ['단발여신 비니', 'Nautilus', 55, 2.66, 54, 3.58, 50, 51]
# ['나는니달리가밉다', "Rek'Sai", 48, 3.32, 48, 3.32, 58, 0]
# ['415불법선거', 'Shen', 68, 3.59, 56, 1.9, 54, 40]
# ['리븐 타임', 'Malphite', 51, 2.54, 41, 2.4, 55, 150]
# ['너얼드', 'Jinx', 54, 2.75, 40, 2.34, 50, 879]
# [['단발여신 비니', 'Nautilus', 55, 2.66, 54, 3.58, 50, 51], ['나는니달리가밉다', "Rek'Sai", 33, 2.27, 48, 3.32, 58, 6], ['415불법선거', 'Shen', 68, 3.59, 56, 1.9, 54, 40], ['리븐 타임', 'Malphite', 51, 2.54, 41, 2.4, 55, 150], ['너얼드', 'Jinx', 54, 2.75, 40, 2.34, 50, 879]]
# ['항상느낌있는사람', 'Ryze', 55, 2.4, 50, 2.93, 55, 11]
# ['lebraca', 'Lucian', 56, 2.98, 43, 1.86, 53, 50]
# ['와드박기싫어', 'Pantheon', 52, 2.33, 50, 2.17, 51, 27]
# ['저도직업있어요', 'Shaco', 55, 3.82, 58, 4.11, 52, 640]
# ['huya dahaibao', 'Jax', 53, 1.47, 34, 1.35, 50, 664]
# [['항상느낌있는사람', 'Ryze', 55, 2.4, 50, 2.93, 55, 11], ['lebraca', 'Lucian', 56, 2.98, 43, 1.86, 53, 50], ['와드박기싫어', 'Pantheon', 52, 2.33, 50, 2.17, 51, 27], ['저도직업있어요', 'Shaco', 55, 3.82, 58, 4.11, 52, 640], ['huya dahaibao', 'Jax', 53, 1.47, 34, 1.35, 50, 664]]
# ['귀여운물개', 'Lee Sin', 51, 2.69, 61, 3.27, 49, 215]
# ['wumingzhibei7', 'Miss Fortune', 55, 3.42, 49, 2.8, 53, 481]
# ['wu yoo', 'Pantheon', 64, 3.03, 54, 3.97, 61, 64]
# ['유튜브 철이럼블', 'Rumble', 50, 2.65, 50, 3.05, 50, 1696]
# ['del5877828500', 'Tryndamere', 55, 1.75, 38, 1.69, 52, 835]
# [['귀여운물개', 'Lee Sin', 51, 2.69, 61, 3.27, 49, 215], ['wumingzhibei7', 'Miss Fortune', 55, 3.42, 49, 2.8, 53, 481], ['wu yoo', 'Pantheon', 64, 3.03, 54, 3.97, 61, 64], ['유튜브 철이럼블', 'Rumble', 50, 2.65, 50, 3.05, 50, 1696], ['del5877828500', 'Tryndamere', 55, 1.75, 38, 1.69, 52, 835]]
# ['더샤이3', 'Sylas', 36, 2.0, 45, 2.29, 35, 11]
# ['v와드싸개v', 'Senna', 55, 3.13, 46, 2.0, 45, 22]
# ['철신지옥의이꾸', 'Amumu', 50, 1.92, 50, 1.92, 43, 0]
# ['코칼리', 'Aphelios', 43, 2.14, 57, 2.91, 52, 14]
# ['빠가라', 'Garen', 50, 3.2, 50, 3.2, 52, 0]
# [['더샤이3', 'Sylas', 36, 2.0, 45, 2.29, 35, 11], ['v와드싸개v', 'Senna', 55, 3.13, 46, 2.0, 45, 22], ['철신지옥의이꾸', 'Amumu', 50, 1.92, 50, 1.92, 43, 0], ['코칼리', 'Aphelios', 43, 2.14, 57, 2.91, 52, 14], ['빠가라', 'Garen', 58, 3.56, 50, 3.2, 52, 52]]
# ['adventure hunter', 'Kindred', 57, 2.6, 52, 2.1, 54, 556]
# ['엄딩이 조아', 'Volibear', 25, 1.4, 48, 3.06, 56, 12]
# ['한계일때 한개 더', 'Zoe', 57, 3.67, 46, 2.06, 52, 49]
# ['Sniper Gun', 'Pantheon', 20, 1.83, 43, 1.97, 52, 5]
# ['Ptolemaeos', 'Jhin', 51, 2.39, 52, 2.23, 51, 84]
# [['adventure hunter', 'Kindred', 57, 2.6, 52, 2.1, 54, 556], ['엄딩이 조아', 'Volibear', 25, 1.4, 48, 3.06, 56, 12], ['한계일때 한개 더', 'Zoe', 57, 3.67, 46, 2.06, 52, 49], ['Sniper Gun', 'Pantheon', 20, 1.83, 43, 1.97, 52, 5], ['Ptolemaeos', 'Jhin', 51, 2.39, 52, 2.23, 51, 84]]
# ['우성현1', 'Ezreal', 33, 1.5, 51, 3.7, 51, 9]
# ['신념 있는 사람', 'Kassadin', 50, 2.57, 33, 1.19, 54, 377]
# ['14 warriors', 'Nunu & Willump', 43, 1.57, 43, 1.57, 51, 0]
# ['카스가장임', 'Blitzcrank', 52, 2.92, 62, 3.99, 52, 528]
# ['이익성', 'Trundle', 47, 3.58, 56, 3.11, 51, 240]
# [['우성현1', 'Ezreal', 33, 1.5, 51, 3.7, 51, 9], ['신념 있는 사람', 'Kassadin', 50, 2.57, 33, 1.19, 54, 377], ['14 warriors', 'Nunu & Willump', 0, 1.06, 43, 1.57, 51, 2], ['카스가장임', 'Blitzcrank', 52, 2.92, 62, 3.99, 52, 528], ['이익성', 'Trundle', 47, 3.58, 56, 3.11, 51, 240]]
# ['ilovechicken1', 'Ashe', 76, 2.78, 56, 3.04, 64, 25]
# ['T1 Cameo', 'Sylas', 50, 3.77, 50, 3.77, 57, 0]
# ['현주서폿가요', 'Maokai', 40, 2.36, 41, 1.93, 58, 10]
# ['강점프 선수', 'Jayce', 72, 3.59, 45, 1.63, 66, 36]
# ['해바라기맛', 'Zilean', 62, 3.08, 37, 1.43, 55, 77]
# [['ilovechicken1', 'Ashe', 76, 2.78, 56, 3.04, 64, 25], ['T1 Cameo', 'Sylas', 65, 3.84, 50, 3.77, 57, 63], ['현주서폿가요', 'Maokai', 40, 2.36, 41, 1.93, 58, 10], ['강점프 선수', 'Jayce', 72, 3.59, 45, 1.63, 66, 36], ['해바라기맛', 'Zilean', 62, 3.08, 37, 1.43, 55, 77]]
# ['라면은물붓고3분', 'Camille', 56, 2.19, 43, 2.53, 49, 59]
# ['hUYaTv wssf', 'Ezreal', 39, 2.72, 39, 2.72, 62, 0]
# ['PengZai', 'Nidalee', 71, 3.16, 50, 2.14, 48, 7]
# ['Kill the one', 'Galio', 44, 3.45, 44, 3.45, 51, 0]
# ['카스가장임', 'Blitzcrank', 52, 2.92, 62, 3.99, 52, 528]
# [['라면은물붓고3분', 'Camille', 56, 2.19, 43, 2.53, 49, 59], ['hUYaTv wssf', 'Ezreal', 70, 3.69, 39, 2.72, 62, 53], ['PengZai', 'Nidalee', 71, 3.16, 50, 2.14, 48, 7], ['Kill the one', 'Galio', 44, 3.45, 44, 3.45, 51, 0], ['카스가장임', 'Blitzcrank', 52, 2.92, 62, 3.99, 52, 528]]
# ['GzJinmao', 'Galio', 61, 3.81, 41, 1.8, 60, 18]
# ['응봉산토깽이', "Kai'Sa", 52, 2.15, 52, 2.15, 49, 0]
# ['Pisces ADC', 'Thresh', 67, 2.9, 50, 2.54, 59, 3]
# ['Marginal', 'Kindred', 54, 3.14, 52, 3.52, 50, 13]
# ['개멋지게유턴을헤', 'Aatrox', 48, 2.17, 36, 1.55, 53, 225]
# [['GzJinmao', 'Galio', 61, 3.81, 41, 1.8, 60, 18], ['응봉산토깽이', "Kai'Sa", 38, 2.63, 52, 2.15, 49, 37], ['Pisces ADC', 'Thresh', 67, 2.9, 50, 2.54, 59, 3], ['Marginal', 'Kindred', 54, 3.14, 52, 3.52, 50, 13], ['개멋지게유턴을헤', 'Aatrox', 48, 2.17, 36, 1.55, 53, 225]]
# ['Apollos', "Kai'Sa", 54, 2.7, 55, 2.43, 51, 37]
# ['코빙턴1', 'Master Yi', 62, 3.29, 52, 2.36, 61, 229]
# ['그립던 우리의 낮', 'Taric', 63, 3.51, 71, 2.94, 55, 545]
# ['망걍파', 'Garen', 63, 3.71, 47, 3.33, 63, 64]
# ['불김치123', 'Zilean', 54, 3.12, 59, 3.12, 51, 1200]
# [['Apollos', "Kai'Sa", 54, 2.7, 55, 2.43, 51, 37], ['코빙턴1', 'Master Yi', 62, 3.29, 52, 2.36, 61, 229], ['그립던 우리의 낮', 'Taric', 63, 3.51, 71, 2.94, 55, 545], ['망걍파', 'Garen', 63, 3.71, 47, 3.33, 63, 64], ['불김치123', 'Zilean', 54, 3.12, 59, 3.12, 51, 1200]]
# ['행운행운 의', 'Jax', 56, 1.6, 33, 1.08, 54, 321]
# ['쌔엥 쌔엥', 'Thresh', 55, 3.06, 51, 2.46, 53, 75]
# ['오 년', 'Draven', 52, 2.54, 51, 2.38, 51, 77]
# ['20220508', 'Ahri', 54, 3.22, 53, 4.19, 50, 695]
# ['Kalpe', "Rek'Sai", 64, 4.1, 58, 3.11, 56, 36]
# [['행운행운 의', 'Jax', 56, 1.6, 33, 1.08, 54, 321], ['쌔엥 쌔엥', 'Thresh', 55, 3.06, 51, 2.46, 53, 75], ['오 년', 'Draven', 52, 2.54, 51, 2.38, 51, 77], ['20220508', 'Ahri', 54, 3.22, 53, 4.19, 50, 695], ['Kalpe', "Rek'Sai", 64, 4.1, 58, 3.11, 56, 36]]
# ['달 구', 'Caitlyn', 66, 3.18, 52, 2.31, 50, 61]
# ['더운날이야', 'Elise', 67, 2.99, 61, 2.54, 65, 15]
# ['엄마는강하다', 'Maokai', 57, 2.79, 43, 2.57, 53, 483]
# ['울부짖는쇼메이커', 'Irelia', 57, 1.98, 30, 1.46, 53, 293]
# ['미드 보거스', 'Qiyana', 45, 3.01, 45, 3.01, 49, 0]
# [['달 구', 'Caitlyn', 66, 3.18, 52, 2.31, 50, 61], ['더운날이야', 'Elise', 67, 2.99, 61, 2.54, 65, 15], ['엄마는강하다', 'Maokai', 57, 2.79, 43, 2.57, 53, 483], ['울부짖는쇼메이커', 'Irelia', 57, 1.98, 30, 1.46, 53, 293], ['미드 보거스', 'Qiyana', 53, 2.72, 45, 3.01, 49, 211]]
# ['운으로 딜', 'Tryndamere', 59, 3.2, 36, 2.35, 57, 429]
# ['catdaumoiaoi', 'Sylas', 51, 2.67, 47, 1.98, 55, 59]
# ['wu yoo', 'Thresh', 72, 5.43, 53, 3.73, 61, 18]
# ['cho san si wa ', 'Nidalee', 55, 2.48, 55, 2.48, 49, 0]
# ['반복의반복', 'Ezreal', 53, 2.25, 38, 1.86, 54, 60]
# [['운으로 딜', 'Tryndamere', 59, 3.2, 36, 2.35, 57, 429], ['catdaumoiaoi', 'Sylas', 51, 2.67, 47, 1.98, 55, 59], ['wu yoo', 'Thresh', 72, 5.43, 53, 3.73, 61, 18], ['cho san si wa ', 'Nidalee', 43, 2.53, 55, 2.48, 49, 203], ['반복의반복', 'Ezreal', 53, 2.25, 38, 1.86, 54, 60]]
# ['Herres', 'Nidalee', 57, 2.77, 57, 2.77, 50, 0]
# ['04년생 호랭이', 'Irelia', 48, 1.62, 48, 1.62, 53, 0]
# ['돈이댐비냐', 'Ashe', 52, 3.07, 44, 2.74, 50, 105]
# ['해삐 어네삐', 'Seraphine', 61, 3.24, 61, 3.24, 50, 0]
# ['근 두', 'Wukong', 53, 2.34, 45, 2.46, 51, 1269]
# [['Herres', 'Nidalee', 54, 3.52, 57, 2.77, 50, 123], ['04년생 호랭이', 'Irelia', 48, 1.62, 48, 1.62, 53, 0], ['돈이댐비냐', 'Ashe', 52, 3.07, 44, 2.74, 50, 105], ['해삐 어네삐', 'Seraphine', 61, 3.24, 61, 3.24, 50, 0], ['근 두', 'Wukong', 53, 2.34, 45, 2.46, 51, 1269]]
# ['너무 아쉬워요', 'Ezreal', 44, 2.07, 48, 2.28, 51, 25]
# ['Rumea', 'Riven', 55, 1.94, 43, 2.25, 54, 356]
# ['love fiona', 'Pyke', 57, 3.79, 53, 3.72, 49, 14]
# ['Mikasa2', 'Ekko', 54, 3.4, 50, 2.27, 50, 82]
# ['해삐 어네삐', 'Seraphine', 61, 3.24, 61, 3.24, 50, 0]
# [['너무 아쉬워요', 'Ezreal', 44, 2.07, 48, 2.28, 51, 25], ['Rumea', 'Riven', 55, 1.94, 43, 2.25, 54, 356], ['love fiona', 'Pyke', 57, 3.79, 53, 3.72, 49, 14], ['Mikasa2', 'Ekko', 54, 3.4, 50, 2.27, 50, 82], ['해삐 어네삐', 'Seraphine', 61, 3.24, 61, 3.24, 50, 0]]
# ['해삐 어네삐', 'Leona', 61, 3.24, 61, 3.24, 50, 0]
# ['깡통공주', 'Jhin', 54, 3.01, 54, 3.01, 50, 0]
# ['IIlIllllIIIlIIII', 'Orianna', 45, 2.66, 53, 3.7, 49, 11]
# ['비도 오고 그래서', 'Lillia', 54, 2.41, 54, 2.41, 50, 0]
# ['가자한국', 'Lucian', 48, 2.51, 48, 2.51, 51, 0]
# [['해삐 어네삐', 'Leona', 100, 2.43, 61, 3.24, 50, 1], ['깡통공주', 'Jhin', 46, 3.32, 54, 3.01, 50, 135], ['IIlIllllIIIlIIII', 'Orianna', 45, 2.66, 53, 3.7, 49, 11], ['비도 오고 그래서', 'Lillia', 0, 2.33, 54, 2.41, 50, 1], ['가자한국', 'Lucian', 43, 2.3, 48, 2.51, 51, 28]]
# ['해삐 어네삐', 'Bard', 61, 3.24, 61, 3.24, 50, 0]
# ['묵언수행 스님1', 'Sivir', 39, 1.6, 39, 1.6, 50, 0]
# ['Normal  JG', 'Lulu', 58, 3.33, 58, 3.33, 60, 0]
# ['익산누누', 'Graves', 48, 2.67, 55, 4.3, 53, 23]
# ['파이크선픽스왑o', 'Sett', 40, 1.74, 40, 1.74, 40, 0]
# [['해삐 어네삐', 'Bard', 86, 10.18, 61, 3.24, 50, 7], ['묵언수행 스님1', 'Sivir', 39, 1.6, 39, 1.6, 50, 0], ['Normal  JG', 'Lulu', 58, 3.33, 58, 3.33, 60, 0], ['익산누누', 'Graves', 48, 2.67, 55, 4.3, 53, 23], ['파이크선픽스왑o', 'Sett', 40, 1.74, 40, 1.74, 40, 0]]
# ['Isnt this a bug', 'Yone', 71, 3.82, 47, 2.0, 58, 41]
# ['llliilililiiill', 'Rengar', 47, 2.11, 41, 2.57, 53, 58]
# ['이별하러 가는 길', 'Elise', 59, 3.28, 51, 2.76, 50, 597]
# ['TESzhaoAD961109', 'Jhin', 70, 4.71, 58, 5.33, 72, 20]
# ['나 둬', 'Thresh', 57, 3.17, 59, 3.6, 54, 242]
# [['Isnt this a bug', 'Yone', 71, 3.82, 47, 2.0, 58, 41], ['llliilililiiill', 'Rengar', 47, 2.11, 41, 2.57, 53, 58], ['이별하러 가는 길', 'Elise', 59, 3.28, 51, 2.76, 50, 597], ['TESzhaoAD961109', 'Jhin', 70, 4.71, 58, 5.33, 72, 20], ['나 둬', 'Thresh', 57, 3.17, 59, 3.6, 54, 242]]
# ['조 C', 'Janna', 62, 3.66, 57, 3.08, 57, 213]
# ['crOss 벤', 'Lucian', 57, 2.8, 57, 2.8, 66, 0]
# ['lissandraa', 'Lissandra', 55, 3.08, 54, 2.71, 52, 193]
# ['Ent is happy', 'Hecarim', 56, 2.81, 64, 3.03, 51, 966]
# ['하음이', 'Shen', 85, 5.32, 53, 2.81, 67, 54]
# [['조 C', 'Janna', 62, 3.66, 57, 3.08, 57, 213], ['crOss 벤', 'Lucian', 69, 3.9, 57, 2.8, 66, 64], ['lissandraa', 'Lissandra', 55, 3.08, 54, 2.71, 52, 193], ['Ent is happy', 'Hecarim', 56, 2.81, 64, 3.03, 51, 966], ['하음이', 'Shen', 85, 5.32, 53, 2.81, 67, 54]]
# ['조 C', 'Janna', 62, 3.66, 57, 3.08, 57, 213]
# ['crOss 벤', 'Miss Fortune', 57, 2.8, 57, 2.8, 66, 0]
# ['lissandraa', 'Lissandra', 55, 3.08, 54, 2.71, 52, 193]
# ['Ent is happy', 'Hecarim', 56, 2.81, 64, 3.03, 51, 966]
# ['하음이', 'Rumble', 66, 3.39, 53, 2.81, 67, 410]
# [['조 C', 'Janna', 62, 3.66, 57, 3.08, 57, 213], ['crOss 벤', 'Miss Fortune', 60, 4.05, 57, 2.8, 66, 30], ['lissandraa', 'Lissandra', 55, 3.08, 54, 2.71, 52, 193], ['Ent is happy', 'Hecarim', 56, 2.81, 64, 3.03, 51, 966], ['하음이', 'Rumble', 66, 3.39, 53, 2.81, 67, 410]]
# ['조 C', 'Janna', 62, 3.66, 57, 3.08, 57, 213]
# ['crOss 벤', 'Lucian', 57, 2.8, 57, 2.8, 66, 0]
# ['lissandraa', 'Lissandra', 55, 3.08, 54, 2.71, 52, 193]
# ['Ent is happy', 'Hecarim', 56, 2.81, 64, 3.03, 51, 966]
# ['하음이', 'Rumble', 66, 3.39, 53, 2.81, 67, 410]
# [['조 C', 'Janna', 62, 3.66, 57, 3.08, 57, 213], ['crOss 벤', 'Lucian', 69, 3.9, 57, 2.8, 66, 64], ['lissandraa', 'Lissandra', 55, 3.08, 54, 2.71, 52, 193], ['Ent is happy', 'Hecarim', 56, 2.81, 64, 3.03, 51, 966], ['하음이', 'Rumble', 66, 3.39, 53, 2.81, 67, 410]]
# ['Set it Off', 'Jhin', 31, 3.13, 46, 3.04, 51, 26]
# ['폭군 정수민', 'Maokai', 40, 1.86, 40, 1.86, 58, 0]
# ['HUYATV Burning', 'Annie', 51, 2.62, 51, 2.62, 50, 0]
# ['질주하는자', 'Galio', 44, 3.29, 53, 3.62, 52, 61]
# ['Ent is happy', 'Hecarim', 56, 2.81, 64, 3.03, 51, 966]
# [['Set it Off', 'Jhin', 31, 3.13, 46, 3.04, 51, 26], ['폭군 정수민', 'Maokai', 55, 1.76, 40, 1.86, 58, 33], ['HUYATV Burning', 'Annie', 100, 14.0, 51, 2.62, 50, 1], ['질주하는자', 'Galio', 44, 3.29, 53, 3.62, 52, 61], ['Ent is happy', 'Hecarim', 56, 2.81, 64, 3.03, 51, 966]]
# ['숫왕벌', 'Neeko', 57, 2.05, 49, 2.39, 50, 270]
# ['SDG Sophia', 'Shen', 50, 2.68, 49, 2.59, 50, 330]
# ['버스커버스탐', 'Vayne', 59, 2.69, 45, 1.38, 54, 90]
# ['김해 마이', 'Master Yi', 54, 2.76, 45, 2.11, 51, 677]
# ['올챙이국 발정력', "Rek'Sai", 27, 2.23, 44, 1.88, 53, 48]
# [['숫왕벌', 'Neeko', 57, 2.05, 49, 2.39, 50, 270], ['SDG Sophia', 'Shen', 50, 2.68, 49, 2.59, 50, 330], ['버스커버스탐', 'Vayne', 59, 2.69, 45, 1.38, 54, 90], ['김해 마이', 'Master Yi', 54, 2.76, 45, 2.11, 51, 677], ['올챙이국 발정력', "Rek'Sai", 27, 2.23, 44, 1.88, 53, 48]]
# ['나만의도파민', 'Orianna', 63, 3.61, 42, 2.25, 57, 356]
# ['느그갱1', 'Irelia', 65, 2.39, 57, 3.42, 60, 49]
# ['BENL1DA', 'Ezreal', 51, 2.64, 57, 3.1, 55, 71]
# ['crOss 타릭', 'Nidalee', 50, 3.0, 50, 3.0, 54, 0]
# ['나만의엔돌핀', 'Yuumi', 50, 3.66, 47, 2.29, 50, 228]
# [['나만의도파민', 'Orianna', 63, 3.61, 42, 2.25, 57, 356], ['느그갱1', 'Irelia', 65, 2.39, 57, 3.42, 60, 49], ['BENL1DA', 'Ezreal', 51, 2.64, 57, 3.1, 55, 71], ['crOss 타릭', 'Nidalee', 42, 2.48, 50, 3.0, 54, 12], ['나만의엔돌핀', 'Yuumi', 50, 3.66, 47, 2.29, 50, 228]]
# ['땡겨볼까', 'Sion', 53, 2.68, 42, 2.05, 51, 816]
# ['oioiyoutoo', 'Lulu', 83, 3.65, 51, 2.37, 61, 12]
# ['지긋지긋하다구요', 'Nidalee', 56, 3.53, 59, 4.07, 76, 9]
# ['쏘What', 'Orianna', 64, 3.22, 45, 2.84, 51, 22]
# ['악튜브구독좋아요', 'Vayne', 67, 2.7, 54, 2.2, 63, 12]
# [['땡겨볼까', 'Sion', 53, 2.68, 42, 2.05, 51, 816], ['oioiyoutoo', 'Lulu', 83, 3.65, 51, 2.37, 61, 12], ['지긋지긋하다구요', 'Nidalee', 56, 3.53, 59, 4.07, 76, 9], ['쏘What', 'Orianna', 64, 3.22, 45, 2.84, 51, 22], ['악튜브구독좋아요', 'Vayne', 67, 2.7, 54, 2.2, 63, 12]]
# ['절망맨', 'Maokai', 56, 3.64, 38, 1.71, 51, 334]
# ['안녕 정원', 'Shyvana', 57, 4.68, 51, 2.95, 50, 23]
# ['에 렌', 'Miss Fortune', 58, 3.11, 52, 1.99, 52, 80]
# ['ha1 m1an bao bao', 'Senna', 42, 2.25, 50, 1.72, 54, 26]
# ['쏘What', 'Yone', 50, 1.72, 45, 2.84, 51, 42]
# [['절망맨', 'Maokai', 56, 3.64, 38, 1.71, 51, 334], ['안녕 정원', 'Shyvana', 57, 4.68, 51, 2.95, 50, 23], ['에 렌', 'Miss Fortune', 58, 3.11, 52, 1.99, 52, 80], ['ha1 m1an bao bao', 'Senna', 42, 2.25, 50, 1.72, 54, 26], ['쏘What', 'Yone', 50, 1.72, 45, 2.84, 51, 42]]
# ['H0rix', 'Karthus', 65, 2.83, 51, 2.43, 52, 52]
# ['김동규2', 'Kalista', 40, 2.84, 40, 2.84, 64, 0]
# ['LlMFO', 'Orianna', 53, 3.74, 42, 2.94, 51, 195]
# ['Sinmu', 'Pantheon', 57, 1.94, 47, 1.58, 50, 140]
# ['MadNightMare', 'Shaco', 51, 2.46, 52, 2.18, 49, 1987]
# [['H0rix', 'Karthus', 65, 2.83, 51, 2.43, 52, 52], ['김동규2', 'Kalista', 40, 2.84, 40, 2.84, 64, 0], ['LlMFO', 'Orianna', 53, 3.74, 42, 2.94, 51, 195], ['Sinmu', 'Pantheon', 57, 1.94, 47, 1.58, 50, 140], ['MadNightMare', 'Shaco', 51, 2.46, 52, 2.18, 49, 1987]]
# ['쏘What', 'Lucian', 46, 1.86, 45, 2.84, 51, 117]
# ['제패각은 죽었다', 'Blitzcrank', 50, 2.79, 53, 3.94, 50, 127]
# ['멘탈좋은트라이', 'Ashe', 47, 2.85, 46, 2.56, 50, 30]
# ['현민이응꼬', 'Nidalee', 54, 3.34, 59, 4.18, 53, 143]
# ['안녕 나는 곰이당', 'Volibear', 46, 2.18, 46, 2.18, 51, 0]
# [['쏘What', 'Lucian', 46, 1.86, 45, 2.84, 51, 117], ['제패각은 죽었다', 'Blitzcrank', 50, 2.79, 53, 3.94, 50, 127], ['멘탈좋은트라이', 'Ashe', 47, 2.85, 46, 2.56, 50, 30], ['현민이응꼬', 'Nidalee', 54, 3.34, 59, 4.18, 53, 143], ['안녕 나는 곰이당', 'Volibear', 48, 2.57, 46, 2.18, 51, 95]]
# ['고집불통 강희원', 'Alistar', 40, 3.08, 40, 3.08, 50, 0]
# ['lebraca', 'Jhin', 58, 4.14, 43, 1.86, 53, 26]
# ['TOTACHU', 'Qiyana', 63, 2.81, 39, 2.51, 51, 127]
# ['zyyto3o', 'Nidalee', 56, 3.28, 55, 2.56, 53, 302]
# ['식이냐', 'Kled', 43, 2.33, 43, 2.33, 54, 0]
# [['고집불통 강희원', 'Alistar', 53, 3.16, 40, 3.08, 50, 32], ['lebraca', 'Jhin', 58, 4.14, 43, 1.86, 53, 26], ['TOTACHU', 'Qiyana', 63, 2.81, 39, 2.51, 51, 127], ['zyyto3o', 'Nidalee', 56, 3.28, 55, 2.56, 53, 302], ['식이냐', 'Kled', 59, 3.08, 43, 2.33, 54, 232]]
# ['쏘What', 'Sylas', 52, 2.22, 45, 2.84, 51, 162]
# ['안녕 정원', 'Lillia', 53, 3.12, 51, 2.95, 50, 68]
# ['Liver', 'Ezreal', 54, 3.44, 47, 4.19, 53, 48]
# ['그럼우짤낀데', 'Sett', 55, 2.37, 48, 3.19, 50, 92]
# ['66668888', 'Yuumi', 44, 1.47, 44, 1.47, 49, 0]
# [['쏘What', 'Sylas', 52, 2.22, 45, 2.84, 51, 162], ['안녕 정원', 'Lillia', 53, 3.12, 51, 2.95, 50, 68], ['Liver', 'Ezreal', 54, 3.44, 47, 4.19, 53, 48], ['그럼우짤낀데', 'Sett', 55, 2.37, 48, 3.19, 50, 92], ['66668888', 'Yuumi', 44, 1.47, 44, 1.47, 49, 0]]
# ['쏘What', 'Yone', 50, 1.72, 45, 2.84, 51, 42]
# ['베이빙', 'Caitlyn', 50, 2.7, 53, 3.71, 55, 62]
# ['심플한원딜', 'Janna', 63, 4.38, 44, 2.46, 50, 16]
# ['SKT T1 BabyFaker', 'Lucian', 50, 2.45, 50, 2.45, 62, 0]
# ['엔마노팬티', 'Ekko', 51, 2.39, 48, 2.34, 49, 69]
# [['쏘What', 'Yone', 50, 1.72, 45, 2.84, 51, 42], ['베이빙', 'Caitlyn', 50, 2.7, 53, 3.71, 55, 62], ['심플한원딜', 'Janna', 63, 4.38, 44, 2.46, 50, 16], ['SKT T1 BabyFaker', 'Lucian', 67, 1.46, 50, 2.45, 62, 3], ['엔마노팬티', 'Ekko', 51, 2.39, 48, 2.34, 49, 69]]
# ['분노의 솔랭', 'Zed', 52, 2.79, 47, 2.74, 50, 616]
# ['crazy피지컬', 'Lee Sin', 43, 2.57, 60, 2.32, 51, 37]
# ['성백인', 'Irelia', 56, 1.75, 42, 1.91, 51, 90]
# ['챌가고싶어요', 'Xayah', 75, 3.55, 48, 2.3, 56, 12]
# ['keair', 'Rakan', 46, 2.5, 46, 2.5, 51, 0]
# [['분노의 솔랭', 'Zed', 52, 2.79, 47, 2.74, 50, 616], ['crazy피지컬', 'Lee Sin', 43, 2.57, 60, 2.32, 51, 37], ['성백인', 'Irelia', 56, 1.75, 42, 1.91, 51, 90], ['챌가고싶어요', 'Xayah', 75, 3.55, 48, 2.3, 56, 12], ['keair', 'Rakan', 67, 2.56, 46, 2.5, 51, 6]]
# ['       감 찾는중', 'Renekton', 45, 3.39, 45, 3.39, 52, 0]
# ['쏘What', 'Sylas', 52, 2.22, 45, 2.84, 51, 162]
# ['배부른거싫어요', 'Nidalee', 64, 4.45, 64, 3.05, 59, 14]
# ['baby sweet', 'Yuumi', 41, 1.89, 41, 1.89, 50, 0]
# ['RNG782754655', 'Ezreal', 54, 2.39, 52, 1.98, 49, 237]
# ...
# ['에이스 동생', 'Camille', 53, 3.26, 53, 3.26, 51, 0]
# ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0]
# ['쁘띠챌', 'Jhin', 47, 2.57, 47, 2.57, 61, 0]
# ['비류스카이', 'Twisted Fate', 59, 3.94, 47, 2.86, 52, 34]
# ['렝가프로지망생', 'Nidalee', 48, 2.58, 48, 2.58, 51, 0]
# [['에이스 동생', 'Camille', 53, 3.26, 53, 3.26, 51, 0], ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0], ['쁘띠챌', 'Jhin', 47, 2.57, 47, 2.57, 61, 0], ['비류스카이', 'Twisted Fate', 59, 3.94, 47, 2.86, 52, 34], ['렝가프로지망생', 'Nidalee', 48, 2.58, 48, 2.58, 51, 0]]
# ['에이스 동생', 'Kayn', 53, 3.26, 53, 3.26, 51, 0]
# ['쁘 띠', 'Soraka', 57, 3.88, 56, 4.71, 60, 7]
# ['쁘띠챌', 'Ezreal', 56, 2.64, 47, 2.57, 61, 55]
# ['농약을좋아하는일', 'Malphite', 51, 7.14, 51, 7.14, 83, 0]
# ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]
# [['에이스 동생', 'Kayn', 53, 3.26, 53, 3.26, 51, 0], ['쁘 띠', 'Soraka', 57, 3.88, 56, 4.71, 60, 7], ['쁘띠챌', 'Ezreal', 56, 2.64, 47, 2.57, 61, 55], ['농약을좋아하는일', 'Malphite', 51, 7.14, 51, 7.14, 83, 0], ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]]
# ['에이스 동생', 'Shyvana', 53, 3.26, 53, 3.26, 51, 0]
# ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0]
# ['쁘띠챌', 'Vayne', 61, 2.59, 47, 2.57, 61, 18]
# ['농약을좋아하는일', 'Qiyana', 51, 7.14, 51, 7.14, 83, 0]
# ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]
# [['에이스 동생', 'Shyvana', 53, 3.26, 53, 3.26, 51, 0], ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0], ['쁘띠챌', 'Vayne', 61, 2.59, 47, 2.57, 61, 18], ['농약을좋아하는일', 'Qiyana', 51, 7.14, 51, 7.14, 83, 0], ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]]
# ['에이스 동생', 'Jarvan IV', 50, 3.98, 53, 3.26, 51, 16]
# ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0]
# ['쁘띠챌', 'Yasuo', 50, 2.8, 47, 2.57, 61, 2]
# ['농약을좋아하는일', 'Diana', 51, 7.14, 51, 7.14, 83, 0]
# ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]
# [['에이스 동생', 'Jarvan IV', 50, 3.98, 53, 3.26, 51, 16], ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0], ['쁘띠챌', 'Yasuo', 50, 2.8, 47, 2.57, 61, 2], ['농약을좋아하는일', 'Diana', 82, 3.73, 51, 7.14, 83, 11], ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]]
# ['에이스 동생', 'Sylas', 26, 2.08, 53, 3.26, 51, 27]
# ['쁘 띠', 'Yuumi', 60, 5.99, 56, 4.71, 60, 186]
# ['쁘띠챌', "Kai'Sa", 70, 3.34, 47, 2.57, 61, 53]
# ['농약을좋아하는일', 'Lucian', 51, 7.14, 51, 7.14, 83, 0]
# ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]
# [['에이스 동생', 'Sylas', 26, 2.08, 53, 3.26, 51, 27], ['쁘 띠', 'Yuumi', 60, 5.99, 56, 4.71, 60, 186], ['쁘띠챌', "Kai'Sa", 70, 3.34, 47, 2.57, 61, 53], ['농약을좋아하는일', 'Lucian', 80, 3.38, 51, 7.14, 83, 5], ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]]
# ['윤장학', 'Lucian', 46, 4.0, 46, 4.0, 63, 0]
# ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0]
# ['쁘띠챌', 'Ashe', 67, 3.5, 47, 2.57, 61, 3]
# ['다4그들만의리그', 'Lissandra', 57, 3.64, 46, 2.13, 50, 122]
# ['잡아줘', 'Sylas', 45, 1.72, 45, 1.72, 54, 0]
# [['윤장학', 'Lucian', 46, 4.0, 46, 4.0, 63, 0], ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0], ['쁘띠챌', 'Ashe', 67, 3.5, 47, 2.57, 61, 3], ['다4그들만의리그', 'Lissandra', 57, 3.64, 46, 2.13, 50, 122], ['잡아줘', 'Sylas', 33, 2.3, 45, 1.72, 54, 6]]
# ['빛 설', 'Varus', 59, 2.79, 59, 2.79, 66, 0]
# ['반 몽', 'Ekko', 53, 2.67, 53, 2.67, 51, 0]
# ['운명의 SO용돌이', 'Bard', 49, 3.54, 49, 3.54, 55, 0]
# ['BVSide', 'Seraphine', 47, 2.77, 47, 2.77, 57, 0]
# ['In Error', 'Lulu', 49, 2.55, 49, 2.55, 64, 0]
# [['빛 설', 'Varus', 59, 2.79, 59, 2.79, 66, 0], ['반 몽', 'Ekko', 53, 2.67, 53, 2.67, 51, 0], ['운명의 SO용돌이', 'Bard', 49, 3.54, 49, 3.54, 55, 0], ['BVSide', 'Seraphine', 33, 2.82, 47, 2.77, 57, 3], ['In Error', 'Lulu', 49, 2.55, 49, 2.55, 64, 0]]
# ['씹덕혜지', 'Shyvana', 48, 2.67, 48, 2.67, 56, 0]
# ['We R Number one', 'Master Yi', 61, 2.9, 53, 2.81, 62, 57]
# ['쁘 띠', 'Soraka', 57, 3.88, 56, 4.71, 60, 7]
# ['쁘띠챌', 'Vayne', 61, 2.59, 47, 2.57, 61, 18]
# ['렝가프로지망생', 'Malphite', 48, 2.58, 48, 2.58, 51, 0]
# [['씹덕혜지', 'Shyvana', 48, 2.67, 48, 2.67, 56, 0], ['We R Number one', 'Master Yi', 61, 2.9, 53, 2.81, 62, 57], ['쁘 띠', 'Soraka', 57, 3.88, 56, 4.71, 60, 7], ['쁘띠챌', 'Vayne', 61, 2.59, 47, 2.57, 61, 18], ['렝가프로지망생', 'Malphite', 48, 2.58, 48, 2.58, 51, 0]]
# ['Axao', 'Akali', 62, 5.37, 62, 5.37, 58, 0]
# ['밥오데이', 'Lillia', 41, 2.49, 41, 2.49, 49, 0]
# ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0]
# ['쁘띠챌', 'Ezreal', 56, 2.64, 47, 2.57, 61, 55]
# ['렝가프로지망생', "Kai'Sa", 48, 2.58, 48, 2.58, 51, 0]
# [['Axao', 'Akali', 62, 5.37, 62, 5.37, 58, 0], ['밥오데이', 'Lillia', 41, 2.49, 41, 2.49, 49, 0], ['쁘 띠', 'Seraphine', 56, 4.71, 56, 4.71, 60, 0], ['쁘띠챌', 'Ezreal', 56, 2.64, 47, 2.57, 61, 55], ['렝가프로지망생', "Kai'Sa", 48, 2.58, 48, 2.58, 51, 0]]
# ['쁘 띠', 'Yuumi', 60, 5.99, 56, 4.71, 60, 186]
# ['쁘띠챌', 'Ezreal', 56, 2.64, 47, 2.57, 61, 55]
# ['aksrl', 'Fiddlesticks', 43, 6.17, 43, 6.17, 88, 0]
# ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0]
# ['mv point', 'Yone', 48, 2.7, 48, 2.7, 52, 0]
# [['쁘 띠', 'Yuumi', 60, 5.99, 56, 4.71, 60, 186], ['쁘띠챌', 'Ezreal', 56, 2.64, 47, 2.57, 61, 55], ['aksrl', 'Fiddlesticks', 43, 6.17, 43, 6.17, 88, 0], ['렝가프로지망생', 'Rengar', 48, 2.58, 48, 2.58, 51, 0], ['mv point', 'Yone', 57, 2.29, 48, 2.7, 52, 54]]
# ['널 사랑하지 않아', 'Twitch', 80, 3.45, 56, 3.49, 59, 15]
# ['다이아2 20포인트', 'Taliyah', 50, 2.87, 50, 2.87, 53, 0]
# ['루나어린이', 'Lulu', 56, 3.3, 57, 3.59, 52, 55]
# ['PERFUM2', 'Camille', 53, 2.24, 44, 2.75, 53, 134]
# ['LNG JUG', 'Karthus', 56, 3.52, 56, 3.52, 55, 0]
# [['널 사랑하지 않아', 'Twitch', 80, 3.45, 56, 3.49, 59, 15], ['다이아2 20포인트', 'Taliyah', 75, 2.43, 50, 2.87, 53, 8], ['루나어린이', 'Lulu', 56, 3.3, 57, 3.59, 52, 55], ['PERFUM2', 'Camille', 53, 2.24, 44, 2.75, 53, 134], ['LNG JUG', 'Karthus', 50, 1.63, 56, 3.52, 55, 2]]
# ['muzke', 'Elise', 79, 11.25, 79, 11.25, 53, 0]
# ['샤샥샤샤샥', 'Twisted Fate', 62, 3.7, 62, 3.7, 56, 0]
# ['욕설은안좋아요', 'Camille', 50, 2.97, 50, 2.97, 52, 0]
# ['이니시개잘엽니다', 'Xayah', 38, 1.43, 38, 1.43, 44, 0]
# ['변태라곰', 'Lux', 46, 1.64, 46, 1.64, 39, 0]
# [['muzke', 'Elise', 33, 1.65, 79, 11.25, 53, 3], ['샤샥샤샤샥', 'Twisted Fate', 62, 3.7, 62, 3.7, 56, 0], ['욕설은안좋아요', 'Camille', 50, 2.97, 50, 2.97, 52, 0], ['이니시개잘엽니다', 'Xayah', 40, 2.28, 38, 1.43, 44, 5], ['변태라곰', 'Lux', 83, 3.55, 46, 1.64, 39, 12]]
# ['수목휴먼빌', 'Teemo', 43, 2.64, 43, 2.64, 50, 0]
# ['T1 BIank', 'Caitlyn', 50, 2.14, 50, 2.34, 44, 2]
# ['종쳤다 시작하자', 'Ekko', 48, 2.71, 48, 2.71, 50, 0]
# ['아 그걸 들어가네', 'Graves', 51, 2.36, 51, 2.36, 52, 0]
# ['황동임', 'Blitzcrank', 67, 2.05, 45, 1.6, 48, 3]
# [['수목휴먼빌', 'Teemo', 53, 1.85, 43, 2.64, 50, 245], ['T1 BIank', 'Caitlyn', 50, 2.14, 50, 2.34, 44, 2], ['종쳤다 시작하자', 'Ekko', 47, 2.75, 48, 2.71, 50, 19], ['아 그걸 들어가네', 'Graves', 75, 1.96, 51, 2.36, 52, 4], ['황동임', 'Blitzcrank', 67, 2.05, 45, 1.6, 48, 3]]
# ['수목휴먼빌', 'Master Yi', 43, 2.64, 43, 2.64, 50, 0]
# ['T1 BIank', 'Varus', 25, 2.17, 50, 2.34, 44, 4]
# ['종쳤다 시작하자', 'Fiora', 48, 2.71, 48, 2.71, 50, 0]
# ['아 그걸 들어가네', 'Graves', 51, 2.36, 51, 2.36, 52, 0]
# ['황동임', 'Lux', 53, 2.38, 45, 1.6, 48, 15]
# [['수목휴먼빌', 'Master Yi', 50, 1.97, 43, 2.64, 50, 32], ['T1 BIank', 'Varus', 25, 2.17, 50, 2.34, 44, 4], ['종쳤다 시작하자', 'Fiora', 38, 1.22, 48, 2.71, 50, 13], ['아 그걸 들어가네', 'Graves', 75, 1.96, 51, 2.36, 52, 4], ['황동임', 'Lux', 53, 2.38, 45, 1.6, 48, 15]]
# ['준 민 랄', 'Rengar', 50, 1.85, 47, 1.94, 55, 6]
# ['뽀얌이', 'Seraphine', 56, 5.17, 56, 5.17, 52, 0]
# ['E2R1', 'Akali', 86, 2.9, 59, 4.05, 49, 7]
# ['별 짱크스', 'Ashe', 40, 2.05, 52, 3.25, 48, 20]
# ['땃쥐콩', 'Fiora', 57, 2.67, 57, 3.51, 49, 7]
# [['준 민 랄', 'Rengar', 50, 1.85, 47, 1.94, 55, 6], ['뽀얌이', 'Seraphine', 56, 5.17, 56, 5.17, 52, 0], ['E2R1', 'Akali', 86, 2.9, 59, 4.05, 49, 7], ['별 짱크스', 'Ashe', 40, 2.05, 52, 3.25, 48, 20], ['땃쥐콩', 'Fiora', 57, 2.67, 57, 3.51, 49, 7]]
# ['pvman', 'Jarvan IV', 44, 2.18, 44, 2.18, 50, 0]
# ['chorong2', 'Sylas', 55, 2.64, 39, 2.24, 53, 84]
# ['Gragaz', 'Ornn', 39, 1.83, 39, 1.83, 50, 0]
# ['청희야', "Kog'Maw", 55, 1.81, 55, 1.81, 59, 0]
# ['룰루게임', 'Lulu', 58, 2.57, 58, 2.57, 59, 0]
# [['pvman', 'Jarvan IV', 58, 2.99, 44, 2.18, 50, 31], ['chorong2', 'Sylas', 55, 2.64, 39, 2.24, 53, 84], ['Gragaz', 'Ornn', 43, 2.24, 39, 1.83, 50, 116], ['청희야', "Kog'Maw", 60, 2.55, 55, 1.81, 59, 370], ['룰루게임', 'Lulu', 61, 4.31, 58, 2.57, 59, 242]]
# ['ll이노리ll', 'Camille', 54, 2.89, 54, 2.89, 50, 0]
# ['청희야', "Kog'Maw", 55, 1.81, 55, 1.81, 59, 0]
# ['룰루게임', 'Braum', 58, 2.57, 58, 2.57, 59, 0]
# ['Sober 신', 'Ekko', 47, 1.7, 47, 1.7, 53, 0]
# ['cute sy', 'Talon', 50, 2.32, 50, 2.32, 57, 0]
# [['ll이노리ll', 'Camille', 55, 2.25, 54, 2.89, 50, 85], ['청희야', "Kog'Maw", 60, 2.55, 55, 1.81, 59, 370], ['룰루게임', 'Braum', 60, 3.34, 58, 2.57, 59, 35], ['Sober 신', 'Ekko', 62, 2.98, 47, 1.7, 53, 307], ['cute sy', 'Talon', 60, 3.15, 50, 2.32, 57, 260]]
# ['슨 리', 'Ahri', 58, 3.7, 47, 2.63, 55, 397]
# ['청희야', "Kog'Maw", 55, 1.81, 55, 1.81, 59, 0]
# ['룰루게임', 'Braum', 58, 2.57, 58, 2.57, 59, 0]
# ['Iucky2', 'Camille', 58, 2.86, 45, 2.1, 59, 26]
# ['아름다운 경치 ', 'Ivern', 62, 5.58, 60, 3.32, 58, 337]
# [['슨 리', 'Ahri', 58, 3.7, 47, 2.63, 55, 397], ['청희야', "Kog'Maw", 60, 2.55, 55, 1.81, 59, 370], ['룰루게임', 'Braum', 60, 3.34, 58, 2.57, 59, 35], ['Iucky2', 'Camille', 58, 2.86, 45, 2.1, 59, 26], ['아름다운 경치 ', 'Ivern', 62, 5.58, 60, 3.32, 58, 337]]
# ['           혼 줌', 'Ekko', 57, 3.71, 47, 2.21, 53, 61]
# ['아리뜰', 'Karthus', 51, 2.44, 51, 2.44, 53, 0]
# ['해바라기 서폿', 'Leona', 52, 2.67, 53, 2.13, 46, 207]
# ['에픽 수염', 'Mordekaiser', 45, 1.78, 44, 2.67, 51, 20]
# ['ad7777777', 'Jhin', 52, 3.79, 44, 2.59, 52, 87]
# [['           혼 줌', 'Ekko', 57, 3.71, 47, 2.21, 53, 61], ['아리뜰', 'Karthus', 63, 2.51, 51, 2.44, 53, 27], ['해바라기 서폿', 'Leona', 52, 2.67, 53, 2.13, 46, 207], ['에픽 수염', 'Mordekaiser', 45, 1.78, 44, 2.67, 51, 20], ['ad7777777', 'Jhin', 52, 3.79, 44, 2.59, 52, 87]]
# ['에픽 수염', 'Twisted Fate', 40, 1.67, 44, 2.67, 51, 5]
# ['냄새조심', 'Thresh', 42, 2.42, 42, 2.42, 54, 0]
# ['채까오', 'Lee Sin', 59, 3.32, 59, 3.32, 52, 0]
# ['Omy gg', 'Jinx', 46, 2.32, 46, 2.32, 49, 0]
# ['빛의법사민석', 'Wukong', 57, 2.68, 45, 2.81, 53, 283]
# [['에픽 수염', 'Twisted Fate', 40, 1.67, 44, 2.67, 51, 5], ['냄새조심', 'Thresh', 62, 2.57, 42, 2.42, 54, 40], ['채까오', 'Lee Sin', 57, 3.95, 59, 3.32, 52, 196], ['Omy gg', 'Jinx', 55, 3.0, 46, 2.32, 49, 64], ['빛의법사민석', 'Wukong', 57, 2.68, 45, 2.81, 53, 283]]
# ['lv ren', 'Zilean', 44, 3.58, 50, 3.02, 53, 45]
# ['이후에 우리', 'Karma', 58, 3.44, 51, 3.17, 56, 33]
# ['에픽 수염', 'Malphite', 50, 2.17, 44, 2.67, 51, 10]
# ['Locatdaumoi', "Rek'Sai", 25, 2.29, 51, 2.18, 62, 4]
# ['Chu voi con ', 'Ashe', 61, 3.17, 57, 3.88, 62, 28]
# [['lv ren', 'Zilean', 44, 3.58, 50, 3.02, 53, 45], ['이후에 우리', 'Karma', 58, 3.44, 51, 3.17, 56, 33], ['에픽 수염', 'Malphite', 50, 2.17, 44, 2.67, 51, 10], ['Locatdaumoi', "Rek'Sai", 25, 2.29, 51, 2.18, 62, 4], ['Chu voi con ', 'Ashe', 61, 3.17, 57, 3.88, 62, 28]]
# ['One Eyed Peter', 'Jhin', 45, 2.15, 45, 2.15, 50, 0]
# ['laugh now ', 'Graves', 58, 2.36, 58, 2.36, 54, 0]
# ['에픽 수염', 'Malphite', 50, 2.17, 44, 2.67, 51, 10]
# ['행복한 광우', 'Vladimir', 38, 1.48, 38, 1.48, 50, 0]
# ['고결한 황족미드', 'Pyke', 47, 1.66, 47, 1.66, 50, 0]
# [['One Eyed Peter', 'Jhin', 56, 3.79, 45, 2.15, 50, 54], ['laugh now ', 'Graves', 61, 2.86, 58, 2.36, 54, 88], ['에픽 수염', 'Malphite', 50, 2.17, 44, 2.67, 51, 10], ['행복한 광우', 'Vladimir', 50, 2.21, 38, 1.48, 50, 179], ['고결한 황족미드', 'Pyke', 53, 1.61, 47, 1.66, 50, 57]]
# ['붉은눈동자', 'Ezreal', 74, 4.59, 56, 3.45, 63, 35]
# ['이빨까기달인', 'Ekko', 88, 5.14, 55, 4.05, 77, 8]
# ['말잘듣겠습니당', 'Irelia', 41, 1.55, 41, 1.55, 49, 0]
# ['The knight a', 'Pyke', 66, 2.88, 54, 2.97, 60, 121]
# ['jax', 'Lucian', 46, 1.76, 46, 1.76, 55, 0]
# [['붉은눈동자', 'Ezreal', 74, 4.59, 56, 3.45, 63, 35], ['이빨까기달인', 'Ekko', 88, 5.14, 55, 4.05, 77, 8], ['말잘듣겠습니당', 'Irelia', 45, 1.48, 41, 1.55, 49, 20], ['The knight a', 'Pyke', 66, 2.88, 54, 2.97, 60, 121], ['jax', 'Lucian', 44, 1.86, 46, 1.76, 55, 55]]
# ['SANDBOX DooTi', "Kai'Sa", 49, 2.62, 50, 2.39, 50, 114]
# ['The knight a', 'Pyke', 66, 2.88, 54, 2.97, 60, 121]
# ['무너지다', 'Akali', 50, 1.52, 32, 1.42, 52, 6]
# ['오산 돌솥 추어탕', 'Renekton', 38, 2.39, 38, 2.39, 56, 0]
# ['youmom', 'Lee Sin', 46, 3.12, 46, 3.12, 54, 0]
# [['SANDBOX DooTi', "Kai'Sa", 49, 2.62, 50, 2.39, 50, 114], ['The knight a', 'Pyke', 66, 2.88, 54, 2.97, 60, 121], ['무너지다', 'Akali', 50, 1.52, 32, 1.42, 52, 6], ['오산 돌솥 추어탕', 'Renekton', 56, 2.69, 38, 2.39, 56, 190], ['youmom', 'Lee Sin', 46, 3.12, 46, 3.12, 54, 0]]
# ['장지환의 분신', 'Lucian', 54, 3.36, 54, 3.36, 50, 0]
# ['태수부계정', 'LeBlanc', 50, 2.91, 41, 1.14, 57, 4]
# ['망나니이준호', 'Elise', 42, 2.21, 42, 2.21, 51, 0]
# ['Curasao', 'Rengar', 43, 2.57, 48, 3.71, 51, 88]
# ['켑 루', 'Pantheon', 44, 2.03, 44, 2.03, 52, 0]
# [['장지환의 분신', 'Lucian', 51, 3.14, 54, 3.36, 50, 132], ['태수부계정', 'LeBlanc', 50, 2.91, 41, 1.14, 57, 4], ['망나니이준호', 'Elise', 33, 1.94, 42, 2.21, 51, 9], ['Curasao', 'Rengar', 43, 2.57, 48, 3.71, 51, 88], ['켑 루', 'Pantheon', 63, 2.55, 44, 2.03, 52, 161]]
# ['GravesKlng', 'Karthus', 66, 3.53, 66, 3.53, 51, 0]
# ['fewpay', 'Yasuo', 70, 3.25, 50, 3.18, 65, 167]
# ['KILLBURN', 'Fiora', 60, 2.15, 33, 1.38, 58, 144]
# ['치매왕1', 'Ezreal', 62, 2.78, 58, 2.68, 50, 42]
# ['The knight a', 'Rakan', 54, 3.73, 54, 2.97, 60, 13]
# [['GravesKlng', 'Karthus', 75, 3.16, 66, 3.53, 51, 8], ['fewpay', 'Yasuo', 70, 3.25, 50, 3.18, 65, 167], ['KILLBURN', 'Fiora', 60, 2.15, 33, 1.38, 58, 144], ['치매왕1', 'Ezreal', 62, 2.78, 58, 2.68, 50, 42], ['The knight a', 'Rakan', 54, 3.73, 54, 2.97, 60, 13]]
# ['개스이야', 'Ezreal', 66, 3.35, 58, 3.49, 63, 236]
# ['sdifhgisdfdfs', 'Sylas', 52, 2.82, 46, 2.48, 49, 123]
# ['느금만수르', 'Lillia', 43, 3.27, 60, 3.67, 52, 21]
# ['asdsadasdsadasd', 'Jayce', 43, 1.44, 43, 1.44, 50, 0]
# ['The knight a', 'Pyke', 66, 2.88, 54, 2.97, 60, 121]
# [['개스이야', 'Ezreal', 66, 3.35, 58, 3.49, 63, 236], ['sdifhgisdfdfs', 'Sylas', 52, 2.82, 46, 2.48, 49, 123], ['느금만수르', 'Lillia', 43, 3.27, 60, 3.67, 52, 21], ['asdsadasdsadasd', 'Jayce', 53, 1.98, 43, 1.44, 50, 287], ['The knight a', 'Pyke', 66, 2.88, 54, 2.97, 60, 121]]
# ['lv ren', 'Fiora', 50, 1.63, 50, 3.02, 53, 119]
# ['The knight a', 'Lee Sin', 33, 3.33, 54, 2.97, 60, 3]
# ['로빈슨이다', 'Jhin', 56, 4.14, 56, 4.14, 55, 0]
# ['솔랭즐겜아이디', 'Zoe', 46, 1.93, 46, 1.93, 56, 0]
# ['마음착한 아들님', 'Xerath', 55, 4.09, 54, 3.36, 59, 11]
# [['lv ren', 'Fiora', 50, 1.63, 50, 3.02, 53, 119], ['The knight a', 'Lee Sin', 33, 3.33, 54, 2.97, 60, 3], ['로빈슨이다', 'Jhin', 50, 5.14, 56, 4.14, 55, 8], ['솔랭즐겜아이디', 'Zoe', 50, 2.0, 46, 1.93, 56, 2], ['마음착한 아들님', 'Xerath', 55, 4.09, 54, 3.36, 59, 11]]
# ['1대1백과사전', 'Vayne', 51, 2.36, 45, 2.39, 51, 96]
# ['발표문', 'Shen', 50, 2.73, 50, 2.73, 52, 0]
# ['비정규직요원', 'Ekko', 48, 2.42, 48, 2.42, 52, 0]
# ['snu28동', 'Shaco', 52, 2.56, 60, 2.38, 51, 512]
# ['천상 쓰레쉬', 'Morgana', 57, 2.19, 57, 2.19, 49, 0]
# [['1대1백과사전', 'Vayne', 51, 2.36, 45, 2.39, 51, 96], ['발표문', 'Shen', 58, 2.69, 50, 2.73, 52, 451], ['비정규직요원', 'Ekko', 50, 2.11, 48, 2.42, 52, 8], ['snu28동', 'Shaco', 52, 2.56, 60, 2.38, 51, 512], ['천상 쓰레쉬', 'Morgana', 52, 2.84, 57, 2.19, 49, 48]]
# ['정글 버스라인', "Rek'Sai", 63, 3.56, 63, 3.56, 52, 0]
# ['0pal', 'Lucian', 47, 2.44, 45, 2.32, 51, 75]
# ['애들아시끄러워', 'Tahm Kench', 52, 2.71, 52, 2.71, 52, 0]
# ['Icecat', 'Jax', 47, 1.67, 34, 1.52, 50, 17]
# ['전생했더니한남한녀였던건에대하여', 'Lissandra', 52, 2.28, 52, 2.28, 52, 0]
# [['정글 버스라인', "Rek'Sai", 53, 3.4, 63, 3.56, 52, 51], ['0pal', 'Lucian', 47, 2.44, 45, 2.32, 51, 75], ['애들아시끄러워', 'Tahm Kench', 60, 2.64, 52, 2.71, 52, 133], ['Icecat', 'Jax', 47, 1.67, 34, 1.52, 50, 17], ['전생했더니한남한녀였던건에대하여', 'Lissandra', 57, 3.27, 52, 2.28, 52, 125]]
# ['HUYATV Misu', 'Orianna', 51, 2.71, 51, 2.71, 51, 0]
# ['HUYATV Warhend', 'Morgana', 57, 2.73, 57, 2.73, 51, 0]
# ['멍멍짹짹꽥꽥', 'Jax', 54, 1.86, 48, 2.7, 51, 76]
# ['Schwartz', 'Samira', 50, 2.0, 43, 2.55, 49, 4]
# ['송 하 랑', 'Fiddlesticks', 61, 3.07, 58, 2.44, 51, 309]
# [['HUYATV Misu', 'Orianna', 53, 3.03, 51, 2.71, 51, 115], ['HUYATV Warhend', 'Morgana', 53, 3.57, 57, 2.73, 51, 36], ['멍멍짹짹꽥꽥', 'Jax', 54, 1.86, 48, 2.7, 51, 76], ['Schwartz', 'Samira', 50, 2.0, 43, 2.55, 49, 4], ['송 하 랑', 'Fiddlesticks', 61, 3.07, 58, 2.44, 51, 309]]
# ['Lv 1 갑각류', 'Camille', 51, 2.05, 41, 2.83, 52, 94]
# ['KR75', 'Graves', 62, 3.38, 50, 1.99, 65, 50]
# ['Schwartz', "Kai'Sa", 48, 2.7, 43, 2.55, 49, 106]
# ['벌꿀오소리식딜교', 'Sett', 58, 2.5, 58, 2.5, 51, 0]
# ['넝 꿀', 'Katarina', 66, 3.07, 55, 1.92, 62, 194]
# [['Lv 1 갑각류', 'Camille', 51, 2.05, 41, 2.83, 52, 94], ['KR75', 'Graves', 62, 3.38, 50, 1.99, 65, 50], ['Schwartz', "Kai'Sa", 48, 2.7, 43, 2.55, 49, 106], ['벌꿀오소리식딜교', 'Sett', 50, 1.72, 58, 2.5, 51, 2], ['넝 꿀', 'Katarina', 66, 3.07, 55, 1.92, 62, 194]]

# %%
len(dat_result)
# Out:
# 698

# %%
dat_result[0]
# Out:
# {'gameId': 4709111969,
#  'teamId': 200,
#  'win': False,
#  'participants': [['뱅 배준식', 'Camille', 50, 1.95, 57, 2.52, 51, 12],
#   ['짜 룽', 'Lee Sin', 51, 3.56, 57, 2.5, 51, 632],
#   ['happy   game ', 'Yone', 40, 1.62, 48, 1.34, 52, 10],
#   ['잠 이 덜 깨다', 'Caitlyn', 57, 2.4, 44, 2.2, 51, 93],
#   ['ha1 m1an bao bao', 'Taric', 61, 3.95, 50, 1.72, 54, 341]]}

# %%
non_list = []
for k in range(len(dat_result)):
    for j in dat['participants']:
        if j[-1] ==0:
            non_list.append(k)
            break
print(non_list)
# Out:
# []

# %%
with open('Gameinfo_with_user_48336_to_60000_all_new.pickle', 'wb') as g:
    pickle.dump(dat_result, g)

# %%
dat_result_perfect = []
for k in range(len(dat_result)):
    if k not in non_list:
        dat_result_perfect.append(dat_result[k])
print(len(dat_result_perfect))
# Out:
# 1181

# %%
with open('Gameinfo_with_user_70000_to_110000_new.pickle', 'wb') as f:
    pickle.dump(dat_result_perfect, f) #우선 완벽히 있는 애들울 넣고
    pickle.dump(dat_result, f) #그 다음에 결함 있는 애들을 넣자.

# %%
with open('Gameinfo_with_user_70000_to_110000_new.pickle', 'rb') as f:
    dat_result_perfect = pickle.load(f) #우선 완벽히 있는 애들울 넣고
    dat_result = pickle.load(f) #그 다음에 결함 있는 애들을 넣자.

# %%
match_timeline_list = [] #타임라인 데이터프레임을 모은 리스트
game_id_list = [] #게임ID 모은 리스트

# %%
#MAPDATA를 gameID에서 추출함.
for ind in tqdm(range(len(dat_result))): # 각 게임 아이디마다 요청
    game_id = dat_result[ind]['gameId']
    game_id_list.append(game_id)
    api_url = f'https://kr.api.riotgames.com/lol/match/v4/timelines/by-match/{game_id}?api_key={api_key}'
    r = requests.get(api_url)
    while r.status_code!=200: # 요청 제한 또는 오류로 인해 정상적으로 받아오지 않는 상태라면, 3초 간 시간을 지연
        time.sleep(3)
        r = requests.get(api_url)
    temp_match = pd.DataFrame(list(r.json().values())[0]) # 전체 데이터 저장 (데이터 값에 딕셔너리 형태로 필요한 정보가 저장)
    temp_timeline = pd.DataFrame()
    len_timeline = temp_match.shape[0]
    for i in range(len_timeline): # 각 게임의 타임라인이 모두 다르기 때문 (1분 가량마다 타임라인이 찍힌다)
        temp_current_timeline = pd.DataFrame(temp_match['participantFrames'].iloc[i]).T
        if i != (len_timeline-1):
            temp_position = pd.DataFrame(list(temp_current_timeline['position'].values), index=temp_current_timeline.index)
            temp_current_timeline = pd.concat([temp_current_timeline, temp_position], axis=1)
            temp_current_timeline.drop('position', axis=1, inplace=True)
        temp_current_timeline['timestamp'] = temp_match['timestamp'][i]
        temp_timeline = pd.concat([temp_timeline, temp_current_timeline], axis=0, sort=False)
    match_timeline_list.append(temp_timeline)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1676/1676 [33:30<00:00,  1.20s/it]

# %%
#match_timeline_list - 확인 
match_timeline_list[0]
# Out:
#    participantId currentGold totalGold level     xp minionsKilled  \
# 1              3         500       500     1      0             0
# 2              5         500       500     1      0             0
# 3              4         500       500     1      0             0
# 4              1         500       500     1      0             0
# 5              2         500       500     1      0             0
# ..           ...         ...       ...   ...    ...           ...
# 6              9         133     14243    16  15857           215
# 7              7         310     11493    15  13040            53
# 8              6         382     12482    15  13411           181
# 9              8         463     11838    15  14245           171
# 10            10         -93      8132    13  10218            38
#
#    jungleMinionsKilled dominionScore teamScore      x      y  timestamp
# 1                    0             0         0  560.0  581.0          0
# 2                    0             0         0  560.0  361.0          0
# 3                    0             0         0  351.0  293.0          0
# 4                    0             0         0  221.0  471.0          0
# 5                    0             0         0  311.0  649.0          0
# ..                 ...           ...       ...    ...    ...        ...
# 6                   28           NaN       NaN    NaN    NaN    1980560
# 7                  152           NaN       NaN    NaN    NaN    1980560
# 8                    4           NaN       NaN    NaN    NaN    1980560
# 9                    0           NaN       NaN    NaN    NaN    1980560
# 10                   0           NaN       NaN    NaN    NaN    1980560
#
# [340 rows x 12 columns]

# %%
for k in range(len(match_timeline_list)): #인덱스 강제정리
    cur_timeline = match_timeline_list[k]
    cur_timeline.sort_values(by=['timestamp', 'participantId'], axis=0, inplace=True)
    cur_timeline.index = list(range(1,11))*(len(cur_timeline)//10)

# %%
#match_timeline_list - 확인 
match_timeline_list[0]
# Out:
#    participantId currentGold totalGold level     xp minionsKilled  \
# 1              1         500       500     1      0             0
# 2              2         500       500     1      0             0
# 3              3         500       500     1      0             0
# 4              4         500       500     1      0             0
# 5              5         500       500     1      0             0
# ..           ...         ...       ...   ...    ...           ...
# 6              6         382     12482    15  13411           181
# 7              7         310     11493    15  13040            53
# 8              8         463     11838    15  14245           171
# 9              9         133     14243    16  15857           215
# 10            10         -93      8132    13  10218            38
#
#    jungleMinionsKilled dominionScore teamScore      x      y  timestamp
# 1                    0             0         0  221.0  471.0          0
# 2                    0             0         0  311.0  649.0          0
# 3                    0             0         0  560.0  581.0          0
# 4                    0             0         0  351.0  293.0          0
# 5                    0             0         0  560.0  361.0          0
# ..                 ...           ...       ...    ...    ...        ...
# 6                    4           NaN       NaN    NaN    NaN    1980560
# 7                  152           NaN       NaN    NaN    NaN    1980560
# 8                    0           NaN       NaN    NaN    NaN    1980560
# 9                   28           NaN       NaN    NaN    NaN    1980560
# 10                   0           NaN       NaN    NaN    NaN    1980560
#
# [340 rows x 12 columns]

# %%
#스펠 저장용
spell_api = 'http://ddragon.leagueoflegends.com/cdn/10.22.1/data/ko_KR/summoner.json'
r = requests.get(spell_api)
spell_info_df = pd.DataFrame(r.json())
spells = {}
for i in range(len(spell_info_df)):
    cur_spell = spell_info_df['data'].iloc[i]
    if 'CLASSIC' in cur_spell['modes']:
        spells[int(cur_spell['key'])] = cur_spell['name']
spells = sorted(spells.items(), key=lambda t : t[0])

# %%
#맵 좌표 스케일 조정용.

def MapScaler(data, x_range=(-120, 14870), y_range=(-120, 14980)): # x, y의 범위
    x = data['x'].astype('float64').values.reshape(-1, 1)
    y = data['y'].astype('float64').values.reshape(-1, 1)
    x_range = np.array(x_range).astype('float64').reshape(-1, 1)
    y_range = np.array(y_range).astype('float64').reshape(-1, 1)
    scaler = MinMaxScaler(feature_range=(0, 512)) # 0~512로 변환
    scaler.fit(x_range)
    x = scaler.transform(x)
    scaler.fit(y_range)
    y = scaler.transform(y)
    return x, 512 - y

# 이미지는 왼쪽 위가 0인데, 지도는 왼쪽 아래가 0이다.
# 그래서 좌표만 뒤집어서 출력을 시키고 싶었는데, 찾기 힘들어서 임의로 y값을 뒤집었다.

# %%
#위의 매치데이터를 포함하는 게임인포 피클에서 가져옴.
with open('pickle/Gameinfo_70000_to_110000.pickle', 'rb') as f:
    match_df = pickle.load(f)

# %%
# 우선 인덱스 부여
match_df.index = range(len(match_df))

# %%
# 리스트에 있는 애들만 추려낸다. 
match_df0 = pd.DataFrame()
tmp = 0 #임시값
for i in dat_result:
    for j in range(tmp, len(match_df.index)):
        if match_df.iloc[j:j+1, :]['gameId'].values[0] == i['gameId']:  
            match_df0 = pd.concat((match_df0, match_df.iloc[j:j+1,:]))
            tmp = j
            break

# %%
# 길이 확인
len(match_df0), len(match_timeline_list)
# Out:
# (1676, 1676)

# %%
#수정된 방식 - 스마이트 보유자 <2면 단순히 정글미니언 킬수로 판단.

def SupJugPredict1(data, player_spells, i): # 서폿과 정글을 판단하기 위한 함수
    if i==1: # 블루팀
        final_timeline = data.iloc[-10:-5].copy()
        spells = player_spells[:5]
    if i==6: # 레드팀
        final_timeline = data.iloc[-5:].copy()
        spells = player_spells[5:10]
    smite_count = (spells == 11).sum()
    # 각 팀의 스마이트 개수 
    if smite_count <= 1: jungle_index = final_timeline['jungleMinionsKilled'].idxmax()
    elif  smite_count > 1: jungle_index = False
    # else: jungle_index = np.where(spells == 11)[0][0] + i # 강타를 들고있는 플레이어 번호
        
    #final_timeline = final_timeline.drop(index = np.where(spells == 11)[0][0]) #정글 제외
    final_timeline = final_timeline.drop(index=final_timeline['jungleMinionsKilled'].idxmax()) 
    return final_timeline['minionsKilled'].idxmin(), jungle_index # 정글을 제외하고 cs가 가장 적은 사람이 서포터

def LanePredict1(data, support_bool=False, jungle_bool=True):
    lane = {'TOP': 0, 'MID': 0, 'BOT_CARRY': 0, 'JUNGLE':0}
    etc = 0
    for xi, yi in zip(data['x'], data['y']):
        if (xi > 20) & (xi < 60) & (yi > 30) & (yi < 300): lane['TOP'] += 1
        elif (xi > 20) & (xi < 150) & (yi > 20) & (yi < 160) & (1-(xi>90) | 1-(yi>120)): lane['TOP'] += 1
        elif (xi > 30) & (xi < 300) & (yi > 20) & (yi < 60): lane['TOP'] += 1
        elif (xi > 195) & (xi < 265) & (yi > 250) & (yi < 310): lane['MID'] += 1
        elif (xi > 220) & (xi < 295) & (yi > 220) & (yi < 290): lane['MID'] += 1
        elif (xi > 250) & (xi < 320) & (yi > 200) & (yi < 260): lane['MID'] += 1
        elif (xi > 290) & (xi < 350) & (yi > 160) & (yi < 215): lane['MID'] += 1
        elif (xi > 160) & (xi < 220) & (yi > 290) & (yi < 340): lane['MID'] += 1
        elif (xi > 220) & (xi < 460) & (yi > 435) & (yi < 485): lane['BOT_CARRY'] += 1
        elif (xi > 400) & (xi < 490) & (yi > 385) & (yi < 480): lane['BOT_CARRY'] += 1
        elif (xi > 440) & (xi < 490) & (yi > 220) & (yi < 455): lane['BOT_CARRY'] += 1
        elif (xi > 0) & (xi < 170) & (yi > 340) & (yi < 512): etc += 1
        elif (xi > 340) & (xi < 512) & (yi > 0) & (yi < 170): etc += 1
        else: lane['JUNGLE'] += 1
    if jungle_bool:
        #if max(lane, key=lane.get) == 'JUNGLE': return 'JUNGLE', lane #정글이면 확정.
        #elif lane.get('JUNGLE') >4 :  return 'JUNGLE', lane #정글에서 5개 이상 찍히면 확정.
        del lane['JUNGLE']
    # 예측된 서포터 번호가 봇에 가장 오래 있었으면 서포터로 확정, 아니면 라인으로 판단
    if support_bool & any([max(lane, key=lane.get) == 'BOT_CARRY' ]): return 'BOT_SUPPORT', lane
        
    return max(lane, key=lane.get), lane

# %%
# 라인 계산 - 순수 포지션 방식으로 재계산

lane_calculated_new = pd.DataFrame()
lane_smite_1_each_new = pd.DataFrame()
lane_from_data_new = pd.DataFrame()
for k in range(len(match_timeline_list)):
#    if k!=45:
        cur_timeline = match_timeline_list[k].copy()
        cur_timeline['jungleMinionsKilled'] = cur_timeline['jungleMinionsKilled'].astype('float64')
        cur_timeline['minionsKilled'] = cur_timeline['minionsKilled'].astype('float64')
        # 타임스탬프는 op.gg가 나타내는 아이템 타임스탬프와 비교 결과, 타임스탬프 값의 1000 단위가 1초인 것을 파악함
        cur_timeline['timestamp'] = cur_timeline['timestamp'] / (1000*60)  # 타임스탬프 값을 분 단위로 변환
        condition = (cur_timeline['timestamp'] > 2) & (cur_timeline['timestamp'] < min(match_df0.iloc[k, :]['gameDuration']/60 -2, 16) )  # 2분 이하 : 미니언이 라인 도착 전, 시야 확보와 정글 리쉬
                        # 16분 이상 또는 게임 끝나기 2분전... : 라인전을 끝내고 다른 라인으로 이동할 수 있음
        cur_timeline = cur_timeline.loc[condition].copy()
        cur_timeline['x'], cur_timeline['y'] = MapScaler(cur_timeline)
        player_spells = [(data['spell1Id'], data['spell2Id']) for data in match_df0.iloc[k, :]['participants'] ] # 스펠 확인
        player_spells = np.array(player_spells)

        lane = {}
        smite_exception = False # 강타 갯수가 각 팀에 하나씩만 있게 확인
        role_temp = [[],[]]

        lane_data = {}
        for i in range(10): #데이터프레임에서 계산...
            info = match_df0['participants'].iloc[k][i]['timeline']['role'], match_df0['participants'].iloc[k][i]['timeline']['lane']
            lane_data[f'lane{i+1}'] = info
        lane_data['gameId'] = match_df0.iloc[k, :]['gameId']


        for i in range(1, 11, 5):  # 라인 계산
            support_index, jungle_index = SupJugPredict1(cur_timeline, player_spells, i)
            smite_exception = smite_exception or (not(jungle_index))
            #smite_index = np.where(spells == 11)[0][0] + i 

            for j in range(i, i+5):
                if j == jungle_index: # 우선 정글 인덱스가 존재해도 정글에서 있는 시점이 없으면.... 
                    lane[f'lane{j}'] = 'JUNGLE'
                    continue
                cur_player = cur_timeline.loc[j].copy()
                role, dic_lane = LanePredict1(cur_player, support_index==j, jungle_index)
                if role == 'BOT_SUPPORT': 
                    lane[f'lane{j}'] = 'BOT_SUPPORT'
                    role_temp[i//5].append('BOT_SUPPORT')
                elif sorted(dic_lane.values())[-1] - sorted(dic_lane.values())[-2] >2: 
                    lane[f'lane{j}'] = role
                    role_temp[i//5].append(role)
                elif sum(dic_lane.values())-dic_lane[role] <=2 : 
                    lane[f'lane{j}'] = role
                    role_temp[i//5].append(role)
                else: 
                    lane[f'lane{j}'] = dic_lane #분명하지 않으면 조건 조작

        for i in range(1,11,5):
            for j in range(i,i+5):
                if str(type(lane[f'lane{j}'])) == "<class 'dict'>":
                    val = lane[f'lane{j}']
                    role = max(val, key=val.get)
                    if role not in role_temp[i//5]:
                        lane[f'lane{j}'] = role
                    else:
                        lane[f'lane{j}'] = 'UNDECIDED'


        lane['gameId'] = match_df0.iloc[k, :]['gameId']
        lane['smiteException'] = smite_exception
        lane['codeIndex'] =k
        lane_data['smiteException'] = smite_exception
        lane_data['codeIndex'] =k
        lane = pd.Series(lane, name = match_df0.index[k])
        lane_data = pd.Series(lane_data, name = match_df0.index[k])
        if any([(lane.value_counts().get('UNDECIDED', 0)> 4), (lane[0:5].value_counts().max()>2) , (lane[5:10].value_counts().max()>2)]): # 각 팀에 한 라인이 3명 이상이면 계산 착오로 판단하여 데이터 삭제
            print(f"{k}번째 계산이 잘못되었습니다.")
            continue
        if len(lane_calculated_new) == 0:
            lane_calculated_new = pd.concat([lane_calculated_new, lane], axis=1, sort=False)
            lane_smite_1_each_new = pd.concat([lane_smite_1_each_new, lane], axis=1, sort=False)
            lane_from_data_new = pd.concat([lane_from_data_new, lane_data], axis=1, sort=False)
        elif lane['gameId'] not in list(lane_calculated_new.loc['gameId', :]):
            if match_df0.iloc[k, :]['gameDuration']<600: # 플레이타임 10분 이상만 추리기
                print(f'오류 : {k}번째 게임은 짧음.')
            else:
                lane_calculated_new = pd.concat([lane_calculated_new, lane], axis=1, sort=False)
                lane_from_data_new = pd.concat([lane_from_data_new, lane_data], axis=1, sort=False)
                if not lane['smiteException']: 
                    lane_smite_1_each_new = pd.concat([lane_smite_1_each_new, lane], axis=1, sort=False)
# Out:
# 오류 : 27번째 게임은 짧음.
# 490번째 계산이 잘못되었습니다.
# 1305번째 계산이 잘못되었습니다.

# %%
# 수정된 알고리즘으로 계산
lane_calculated_new
# Out:
#                       3            11           25           35     \
# lane1             BOT_CARRY  BOT_SUPPORT  BOT_SUPPORT          TOP
# lane2           BOT_SUPPORT          TOP    BOT_CARRY  BOT_SUPPORT
# lane3                   TOP       JUNGLE       JUNGLE    BOT_CARRY
# lane4                   MID    BOT_CARRY          MID       JUNGLE
# lane5                JUNGLE          MID          TOP          MID
# lane6                   MID    BOT_CARRY    BOT_CARRY          MID
# lane7                JUNGLE  BOT_SUPPORT       JUNGLE    BOT_CARRY
# lane8             BOT_CARRY       JUNGLE          MID       JUNGLE
# lane9                   TOP          TOP  BOT_SUPPORT          TOP
# lane10          BOT_SUPPORT          MID          TOP  BOT_SUPPORT
# gameId           4751789156   4701374661   4742516401   4733057391
# smiteException        False        False        False        False
# codeIndex                 0            1            2            3
#
#                       47           52           65           81     \
# lane1                   MID  BOT_SUPPORT  BOT_SUPPORT          TOP
# lane2             BOT_CARRY          TOP       JUNGLE  BOT_SUPPORT
# lane3           BOT_SUPPORT          MID    BOT_CARRY       JUNGLE
# lane4                JUNGLE       JUNGLE          TOP    BOT_CARRY
# lane5                   TOP    BOT_CARRY          MID          MID
# lane6           BOT_SUPPORT          TOP       JUNGLE       JUNGLE
# lane7                   TOP    BOT_CARRY          MID          TOP
# lane8             BOT_CARRY  BOT_SUPPORT          TOP  BOT_SUPPORT
# lane9                   MID       JUNGLE    BOT_CARRY          MID
# lane10               JUNGLE          MID  BOT_SUPPORT    BOT_CARRY
# gameId           4730254291   4759355066   4760618292   4754149650
# smiteException        False        False        False        False
# codeIndex                 4            5            6            7
#
#                       93           103    ...        22734        22737  \
# lane1                JUNGLE  BOT_SUPPORT  ...  BOT_SUPPORT          MID
# lane2           BOT_SUPPORT       JUNGLE  ...          TOP          TOP
# lane3                   MID    BOT_CARRY  ...          MID       JUNGLE
# lane4                   TOP          MID  ...    BOT_CARRY  BOT_SUPPORT
# lane5             BOT_CARRY          TOP  ...       JUNGLE    BOT_CARRY
# lane6                   TOP          MID  ...    BOT_CARRY       JUNGLE
# lane7           BOT_SUPPORT    BOT_CARRY  ...       JUNGLE          MID
# lane8             BOT_CARRY          TOP  ...          MID          TOP
# lane9                JUNGLE       JUNGLE  ...          TOP    BOT_CARRY
# lane10                  MID  BOT_SUPPORT  ...  BOT_SUPPORT  BOT_SUPPORT
# gameId           4751266416   4747644390  ...   4729968380   4729744723
# smiteException        False        False  ...        False        False
# codeIndex                 8            9  ...         1665         1666
#
#                       22741        22745        22764        22768  \
# lane1             BOT_CARRY  BOT_SUPPORT       JUNGLE  BOT_SUPPORT
# lane2           BOT_SUPPORT    BOT_CARRY  BOT_SUPPORT    BOT_CARRY
# lane3                   TOP          MID    BOT_CARRY          MID
# lane4                   MID       JUNGLE          TOP       JUNGLE
# lane5                JUNGLE          TOP          MID          TOP
# lane6             BOT_CARRY  BOT_SUPPORT  BOT_SUPPORT    BOT_CARRY
# lane7                JUNGLE          TOP       JUNGLE       JUNGLE
# lane8                   MID       JUNGLE          MID          TOP
# lane9           BOT_SUPPORT    BOT_CARRY    BOT_CARRY  BOT_SUPPORT
# lane10                  TOP          MID          TOP          MID
# gameId           4728042687   4725209532   4747596118   4747652468
# smiteException        False        False        False        False
# codeIndex              1667         1668         1669         1670
#
#                       22802        22826        22837        22889
# lane1                   MID          TOP          MID       JUNGLE
# lane2                JUNGLE    BOT_CARRY          TOP          MID
# lane3             BOT_CARRY       JUNGLE    BOT_CARRY    BOT_CARRY
# lane4           BOT_SUPPORT          MID  BOT_SUPPORT  BOT_SUPPORT
# lane5                   TOP  BOT_SUPPORT       JUNGLE          TOP
# lane6                   MID          MID          TOP          MID
# lane7                JUNGLE  BOT_SUPPORT          MID          TOP
# lane8           BOT_SUPPORT    BOT_CARRY    BOT_CARRY       JUNGLE
# lane9             BOT_CARRY       JUNGLE       JUNGLE    BOT_CARRY
# lane10                  TOP          TOP  BOT_SUPPORT  BOT_SUPPORT
# gameId           4758290564   4742601645   4746349640   4761524283
# smiteException        False        False        False        False
# codeIndex              1671         1673         1674         1675
#
# [13 rows x 1625 columns]

# %%
# 수정된 알고리즘으로 계산 - 원 피클에서 추출
lane_from_data_new
# Out:
#                                 3                      11     \
# lane1             (DUO_CARRY, BOTTOM)  (DUO_SUPPORT, BOTTOM)
# lane2           (DUO_SUPPORT, BOTTOM)             (DUO, TOP)
# lane3                   (DUO, MIDDLE)         (NONE, JUNGLE)
# lane4                   (DUO, MIDDLE)    (DUO_CARRY, BOTTOM)
# lane5                  (NONE, JUNGLE)             (DUO, TOP)
# lane6                  (SOLO, MIDDLE)    (DUO_CARRY, BOTTOM)
# lane7              (DUO_SUPPORT, TOP)  (DUO_SUPPORT, BOTTOM)
# lane8             (DUO_CARRY, BOTTOM)         (NONE, JUNGLE)
# lane9                (DUO_CARRY, TOP)            (SOLO, TOP)
# lane10          (DUO_SUPPORT, BOTTOM)         (SOLO, MIDDLE)
# gameId                     4751789156             4701374661
# smiteException                  False                  False
# codeIndex                           0                      1
#
#                               25                     35     \
# lane1           (DUO_SUPPORT, NONE)            (SOLO, TOP)
# lane2           (DUO_SUPPORT, NONE)  (DUO_SUPPORT, BOTTOM)
# lane3           (DUO_SUPPORT, NONE)    (DUO_CARRY, BOTTOM)
# lane4           (DUO_SUPPORT, NONE)         (NONE, JUNGLE)
# lane5           (DUO_SUPPORT, NONE)         (SOLO, MIDDLE)
# lane6           (DUO_SUPPORT, NONE)         (SOLO, MIDDLE)
# lane7           (DUO_SUPPORT, NONE)    (DUO_CARRY, BOTTOM)
# lane8           (DUO_SUPPORT, NONE)         (NONE, JUNGLE)
# lane9           (DUO_SUPPORT, NONE)            (SOLO, TOP)
# lane10                  (DUO, NONE)  (DUO_SUPPORT, BOTTOM)
# gameId                   4742516401             4733057391
# smiteException                False                  False
# codeIndex                         2                      3
#
#                                 47                     52     \
# lane1                  (SOLO, MIDDLE)  (DUO_SUPPORT, BOTTOM)
# lane2             (DUO_CARRY, BOTTOM)            (SOLO, TOP)
# lane3           (DUO_SUPPORT, BOTTOM)         (SOLO, MIDDLE)
# lane4                  (NONE, JUNGLE)         (NONE, JUNGLE)
# lane5                     (SOLO, TOP)    (DUO_CARRY, BOTTOM)
# lane6           (DUO_SUPPORT, BOTTOM)            (SOLO, TOP)
# lane7                     (SOLO, TOP)    (DUO_CARRY, BOTTOM)
# lane8             (DUO_CARRY, BOTTOM)  (DUO_SUPPORT, BOTTOM)
# lane9                  (SOLO, MIDDLE)         (NONE, JUNGLE)
# lane10                 (NONE, JUNGLE)         (SOLO, MIDDLE)
# gameId                     4730254291             4759355066
# smiteException                  False                  False
# codeIndex                           4                      5
#
#                                 65                   81     \
# lane1           (DUO_SUPPORT, BOTTOM)  (DUO_SUPPORT, NONE)
# lane2                  (NONE, JUNGLE)  (DUO_SUPPORT, NONE)
# lane3             (DUO_CARRY, BOTTOM)  (DUO_SUPPORT, NONE)
# lane4                     (SOLO, TOP)  (DUO_SUPPORT, NONE)
# lane5                  (SOLO, MIDDLE)  (DUO_SUPPORT, NONE)
# lane6                  (NONE, JUNGLE)  (DUO_SUPPORT, NONE)
# lane7                  (SOLO, MIDDLE)    (DUO_CARRY, NONE)
# lane8                     (SOLO, TOP)  (DUO_SUPPORT, NONE)
# lane9             (DUO_CARRY, BOTTOM)  (DUO_SUPPORT, NONE)
# lane10          (DUO_SUPPORT, BOTTOM)  (DUO_SUPPORT, NONE)
# gameId                     4760618292           4754149650
# smiteException                  False                False
# codeIndex                           6                    7
#
#                                 93                     103    ...  \
# lane1                  (NONE, JUNGLE)  (DUO_SUPPORT, BOTTOM)  ...
# lane2           (DUO_SUPPORT, BOTTOM)         (NONE, JUNGLE)  ...
# lane3                  (SOLO, MIDDLE)          (DUO, BOTTOM)  ...
# lane4                     (SOLO, TOP)          (DUO, BOTTOM)  ...
# lane5             (DUO_CARRY, BOTTOM)            (SOLO, TOP)  ...
# lane6                     (SOLO, TOP)         (SOLO, MIDDLE)  ...
# lane7           (DUO_SUPPORT, BOTTOM)    (DUO_CARRY, BOTTOM)  ...
# lane8             (DUO_CARRY, BOTTOM)            (SOLO, TOP)  ...
# lane9                  (NONE, JUNGLE)         (NONE, JUNGLE)  ...
# lane10                 (SOLO, MIDDLE)  (DUO_SUPPORT, BOTTOM)  ...
# gameId                     4751266416             4747644390  ...
# smiteException                  False                  False  ...
# codeIndex                           8                      9  ...
#
#                                 22734                  22737  \
# lane1           (DUO_SUPPORT, BOTTOM)          (DUO, MIDDLE)
# lane2                     (SOLO, TOP)          (DUO, MIDDLE)
# lane3                  (SOLO, MIDDLE)         (NONE, JUNGLE)
# lane4             (DUO_CARRY, BOTTOM)  (DUO_SUPPORT, BOTTOM)
# lane5                  (NONE, JUNGLE)    (DUO_CARRY, BOTTOM)
# lane6             (DUO_CARRY, BOTTOM)         (NONE, JUNGLE)
# lane7                  (NONE, JUNGLE)             (DUO, TOP)
# lane8                  (SOLO, MIDDLE)             (DUO, TOP)
# lane9                     (SOLO, TOP)    (DUO_CARRY, BOTTOM)
# lane10          (DUO_SUPPORT, BOTTOM)  (DUO_SUPPORT, BOTTOM)
# gameId                     4729968380             4729744723
# smiteException                  False                  False
# codeIndex                        1665                   1666
#
#                                 22741                  22745  \
# lane1                  (SOLO, BOTTOM)  (DUO_SUPPORT, MIDDLE)
# lane2           (DUO_SUPPORT, MIDDLE)         (SOLO, BOTTOM)
# lane3                     (SOLO, TOP)    (DUO_CARRY, MIDDLE)
# lane4             (DUO_CARRY, MIDDLE)         (NONE, JUNGLE)
# lane5                  (NONE, JUNGLE)            (SOLO, TOP)
# lane6             (DUO_CARRY, BOTTOM)  (DUO_SUPPORT, BOTTOM)
# lane7                  (NONE, JUNGLE)            (SOLO, TOP)
# lane8                  (SOLO, MIDDLE)         (NONE, JUNGLE)
# lane9           (DUO_SUPPORT, BOTTOM)    (DUO_CARRY, BOTTOM)
# lane10                    (SOLO, TOP)         (SOLO, MIDDLE)
# gameId                     4728042687             4725209532
# smiteException                  False                  False
# codeIndex                        1667                   1668
#
#                                 22764                22768  \
# lane1                  (NONE, JUNGLE)  (DUO_SUPPORT, NONE)
# lane2           (DUO_SUPPORT, BOTTOM)  (DUO_SUPPORT, NONE)
# lane3             (DUO_CARRY, BOTTOM)          (DUO, NONE)
# lane4                     (SOLO, TOP)  (DUO_SUPPORT, NONE)
# lane5                  (SOLO, MIDDLE)  (DUO_SUPPORT, NONE)
# lane6           (DUO_SUPPORT, BOTTOM)  (DUO_SUPPORT, NONE)
# lane7                  (NONE, JUNGLE)  (DUO_SUPPORT, NONE)
# lane8                  (SOLO, MIDDLE)          (DUO, NONE)
# lane9             (DUO_CARRY, BOTTOM)  (DUO_SUPPORT, NONE)
# lane10                    (SOLO, TOP)  (DUO_SUPPORT, NONE)
# gameId                     4747596118           4747652468
# smiteException                  False                False
# codeIndex                        1669                 1670
#
#                                 22802                  22826  \
# lane1                      (DUO, TOP)             (DUO, TOP)
# lane2                  (NONE, JUNGLE)    (DUO_CARRY, BOTTOM)
# lane3             (DUO_CARRY, BOTTOM)         (NONE, JUNGLE)
# lane4           (DUO_SUPPORT, BOTTOM)             (DUO, TOP)
# lane5                      (DUO, TOP)  (DUO_SUPPORT, BOTTOM)
# lane6                  (SOLO, MIDDLE)         (SOLO, MIDDLE)
# lane7                  (NONE, JUNGLE)  (DUO_SUPPORT, BOTTOM)
# lane8           (DUO_SUPPORT, BOTTOM)    (DUO_CARRY, BOTTOM)
# lane9             (DUO_CARRY, BOTTOM)         (NONE, JUNGLE)
# lane10                    (SOLO, TOP)            (SOLO, TOP)
# gameId                     4758290564             4742601645
# smiteException                  False                  False
# codeIndex                        1671                   1673
#
#                                 22837                  22889
# lane1                  (SOLO, MIDDLE)         (NONE, JUNGLE)
# lane2                     (SOLO, TOP)             (DUO, TOP)
# lane3             (DUO_CARRY, BOTTOM)    (DUO_CARRY, BOTTOM)
# lane4           (DUO_SUPPORT, BOTTOM)  (DUO_SUPPORT, BOTTOM)
# lane5                  (NONE, JUNGLE)             (DUO, TOP)
# lane6                     (SOLO, TOP)             (DUO, TOP)
# lane7                  (SOLO, MIDDLE)             (DUO, TOP)
# lane8             (DUO_CARRY, BOTTOM)         (NONE, JUNGLE)
# lane9                  (NONE, JUNGLE)    (DUO_CARRY, BOTTOM)
# lane10          (DUO_SUPPORT, BOTTOM)  (DUO_SUPPORT, BOTTOM)
# gameId                     4746349640             4761524283
# smiteException                  False                  False
# codeIndex                        1674                   1675
#
# [13 rows x 1625 columns]

# %%
# 중복 포지션 삭제.
jr_drop_new = []
for jr in lane_calculated_new.columns:
    if any([(lane_calculated_new[jr][0:5].value_counts().max()>1) , (lane_calculated_new[jr][5:10].value_counts().max()>1), (lane_calculated_new[jr].value_counts().get('UNDECIDED'))]):
        jr_drop_new.append(jr)

# %%
len(jr_drop_new)
# Out:
# 49

# %%
lane_calculated_new.loc[:, jr_drop_new] #예외처리용 출력
# Out:
#                       814         1043         1134         1659   \
# lane1             BOT_CARRY         MID    BOT_CARRY    BOT_CARRY
# lane2           BOT_SUPPORT   UNDECIDED          MID          TOP
# lane3                   TOP      JUNGLE  BOT_SUPPORT    UNDECIDED
# lane4                JUNGLE         TOP       JUNGLE          MID
# lane5                   MID         TOP          TOP       JUNGLE
# lane6                JUNGLE         TOP          TOP    BOT_CARRY
# lane7           BOT_SUPPORT   BOT_CARRY          MID          MID
# lane8                   MID   BOT_CARRY    BOT_CARRY       JUNGLE
# lane9                   TOP         TOP       JUNGLE          TOP
# lane10            UNDECIDED      JUNGLE          MID  BOT_SUPPORT
# gameId           4751771522  4704346024   4756020493   4702746489
# smiteException        False       False        False        False
# codeIndex               101         129          139          204
#
#                       1923         1943         2527         2954   \
# lane1             BOT_CARRY          TOP  BOT_SUPPORT          TOP
# lane2                JUNGLE    UNDECIDED          MID       JUNGLE
# lane3                   MID       JUNGLE          TOP          MID
# lane4           BOT_SUPPORT    BOT_CARRY       JUNGLE    UNDECIDED
# lane5                   TOP    BOT_CARRY    BOT_CARRY  BOT_SUPPORT
# lane6             UNDECIDED          MID          TOP       JUNGLE
# lane7             BOT_CARRY    BOT_CARRY    UNDECIDED  BOT_SUPPORT
# lane8                JUNGLE          TOP          MID          TOP
# lane9                   MID  BOT_SUPPORT    BOT_CARRY    BOT_CARRY
# lane10                  TOP       JUNGLE       JUNGLE          MID
# gameId           4718514951   4752500743   4753938544   4745454827
# smiteException        False         True        False        False
# codeIndex               232          234          288          329
#
#                       3784         3914   ...        15321        15467  \
# lane1             BOT_CARRY    UNDECIDED  ...          MID          TOP
# lane2             BOT_CARRY       JUNGLE  ...          TOP          MID
# lane3                   MID    BOT_CARRY  ...       JUNGLE          MID
# lane4                JUNGLE  BOT_SUPPORT  ...    BOT_CARRY    BOT_CARRY
# lane5                   TOP          TOP  ...  BOT_SUPPORT       JUNGLE
# lane6           BOT_SUPPORT    BOT_CARRY  ...          TOP          MID
# lane7             BOT_CARRY  BOT_SUPPORT  ...    BOT_CARRY    BOT_CARRY
# lane8                JUNGLE       JUNGLE  ...       JUNGLE       JUNGLE
# lane9                   TOP          TOP  ...    BOT_CARRY  BOT_SUPPORT
# lane10                  MID          MID  ...          TOP          TOP
# gameId           4722159623   4759501013  ...   4742649131   4733103180
# smiteException        False        False  ...        False        False
# codeIndex               390          402  ...         1220         1223
#
#                       17068        20218        21371        21405  \
# lane1                   MID          MID          MID          MID
# lane2                   TOP       JUNGLE    BOT_CARRY          MID
# lane3             UNDECIDED    BOT_CARRY          TOP       JUNGLE
# lane4             BOT_CARRY  BOT_SUPPORT    BOT_CARRY          TOP
# lane5                JUNGLE          TOP       JUNGLE    BOT_CARRY
# lane6                   TOP       JUNGLE    BOT_CARRY  BOT_SUPPORT
# lane7                JUNGLE          TOP  BOT_SUPPORT          MID
# lane8                   MID          MID          TOP       JUNGLE
# lane9           BOT_SUPPORT  BOT_SUPPORT       JUNGLE    BOT_CARRY
# lane10            BOT_CARRY          TOP          MID          TOP
# gameId           4733085728   4742468250   4691328385   4748008055
# smiteException        False        False        False        False
# codeIndex              1267         1398         1544         1553
#
#                       21589       22248       22264        22438
# lane1             BOT_CARRY         TOP         MID       JUNGLE
# lane2                   MID         MID         TOP  BOT_SUPPORT
# lane3           BOT_SUPPORT         MID      JUNGLE          TOP
# lane4                   TOP      JUNGLE   UNDECIDED          MID
# lane5                JUNGLE   BOT_CARRY   BOT_CARRY          TOP
# lane6                JUNGLE      JUNGLE         MID       JUNGLE
# lane7             BOT_CARRY         MID      JUNGLE  BOT_SUPPORT
# lane8           BOT_SUPPORT         MID         MID    BOT_CARRY
# lane9                   TOP   UNDECIDED   UNDECIDED          TOP
# lane10                  TOP         TOP         TOP          MID
# gameId           4726733517  4755932188  4745808496   4743608731
# smiteException        False        True       False        False
# codeIndex              1568        1637        1638         1647
#
# [13 rows x 49 columns]

# %%
lane_calculated_new_0 = lane_calculated_new.drop(columns=jr_drop_new, axis=1)
lane_from_data_new_0 = lane_from_data_new.drop(columns=jr_drop_new, axis=1)

# %%
#피클로 데이터 저장
with open('position_70000_to_110000.pickle', 'wb') as f:
    pickle.dump(lane_calculated_new,f)
    pickle.dump(lane_calculated_new_0, f)

# %%
with open('mapdata_70000_to_110000.pickle', 'wb') as g:
    pickle.dump(match_timeline_list, g)

# %%
len(dat_result_perfect)
# Out:
# 1181

# %%
dat_result_with_pos = []
for dat in dat_result_perfect: #완벽히 포지션이 있는 애들만 확인.
    dat0 = dat.copy() #데이터 복제분
    for game_id in lane_calculated_new_0.loc['gameId']: #게임아이디로 동일성 확인
        if dat0['gameId'] == game_id:
            dat_team = []
            if dat0['teamId'] == 100:
                for l in range(5):
                    dat_team.append(lane_calculated_new_0.loc[f'lane{l+1}', lane_calculated_new_0.loc['gameId']==game_id].values[0])
            elif dat0['teamId'] == 200:
                for l in range(5):
                    dat_team.append(lane_calculated_new_0.loc[f'lane{l+6}', lane_calculated_new_0.loc['gameId']==game_id].values[0])
            if set(dat_team) == {'TOP', 'MID', 'BOT_CARRY', 'BOT_SUPPORT', 'JUNGLE'}: #한명씩 있을 때에만...
                for l in range(5):
                    dat0['participants'][l].insert(2, dat_team[l])
                dat_result_with_pos.append(dat0)
            break

# %%
dat_result_with_pos[0]
# Out:
# {'gameId': 4751789156,
#  'teamId': 100,
#  'win': True,
#  'participants': [['책임을지다', 'Ashe', 'BOT_CARRY', 56, 2.96, 38, 1.82, 55, 151],
#   ['paranoicl', 'Senna', 'BOT_SUPPORT', 70, 5.32, 56, 5.5, 63, 10],
#   ['KILLBURN', 'Maokai', 'TOP', 49, 2.54, 33, 1.38, 58, 43],
#   ['AtheartOnlyme ', 'Kassadin', 'MID', 40, 2.18, 52, 2.75, 53, 20],
#   ['Tuzai chang', "Rek'Sai", 'JUNGLE', 55, 3.38, 54, 3.76, 52, 321]]}

# %%
cnt =0
for dat in dat_result_with_pos:
    dat_res = [dat['participants'][l][2] for l in range(5)]
    if set(dat_res)!={'TOP', 'MID', 'BOT_CARRY', 'BOT_SUPPORT', 'JUNGLE'}:
        cnt +=1
print(cnt)
# Out:
# 0

# %%
len(dat_result_with_pos)
# Out:
# 1143

# %%
with open('Gameinfo_70000_to_110000_with_user_and_position_mod.pickle', 'wb') as f:
    pickle.dump(dat_result_with_pos, f)
