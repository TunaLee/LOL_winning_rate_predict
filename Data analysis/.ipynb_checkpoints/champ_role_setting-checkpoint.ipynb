# %%
Slayer=['Akali','Diana','Ekko','Evelynn','Fizz','Kassadin','Katarina','Kayn','Rengar',"Kha'Zix",'Kayn','Zed','Kassadin','Nocturne','Master Yi','Yone','Nidalee','Qiyana','Talon','LeBlanc','Pyke','Shaco']
Mage=['Anivia','Azir','Elise','Fiddlesticks','Heimerdinger','Kennen','Aurelion Sol','Cassiopeia','Karthus','Malzahar','Morgana','Ryze','Swain','Taliyah','Viktor','Vladimir','Ahri','Annie','Brand','Karma','Lissandra','Lux','Neeko','Orianna','Seraphine','Sylas','Syndra','Twisted Fate','Veigar','Zoe','Zyra','Ziggs','Xerath',"Vel'Koz"]
Fighter=['Camille','Jayce','Ganplank','Gragas','Gnar','Fiora','Singed','Riven','Rumble','Hecarim','Irelia','Kayle','Jarvan IV','Yasuo','Kled','Lee Sin','Olaf','Pantheon',"Rek'Sai",'Renekton','Skarner','Vi','Warwick','Wukong','Xin Zhao','Aatrox','Darius','Dr. Mundo','Lillia','Jax','Garen','Illaoi','Mordekaiser','Nasus','Sett','Shyvana','Trundle','Tryndamere','Udyr','Urgot','Volibear','Yorick']
Controller=['Bard','Ivern','Rakan','Zilean','Janna','Lulu','Nami','Sona','Soraka','Yuumi']
Marksman=['Aphelios','Ashe','Caitlyn','Corki','Draven','Ezreal','Teemo','Graves','Jhin','Jinx',"Kai'Sa",'Kalista','Kindred',"Kog'Maw",'Lucian','Miss Fortune','Quinn','Samira','Senna','Sivir','Tristana','Twitch','Varus','Vayne','Xayah']
Tank=['Alistar','Amumu','Blitzcrank','Taric','Thresh','Leona',"Cho'Gath",'Malphite','Maokai','Nautilus','Ornn','Rammus','Sejuani','Sion','Zac','Braum','Galio','Poppy','Shen','Tahm Kench','Taric','Nunu & Willump']

# %%
Slayer=list(set(Slayer))
Fighter=list(set(Fighter))
Mage=list(set(Mage))
Marksman=list(set(Marksman))
Controller=list(set(Controller))
Tank=list(set(Tank))
temp=sorted(Tank+Slayer+Mage+Marksman+Controller+Fighter)

# %%
len(temp)
# Out:
# 152

# %%
import pickle
import json
import pandas as pd
import numpy as np

# %%
with open('slayer.json','rb') as f:
    Slayer=json.load(f)
with open('mage.json','rb') as f:
    Mage=json.load(f)
with open('Fighter.json','rb') as f:
    Fighter=json.load(f)
with open('controller.json','rb') as f:
    Controller=json.load(f)
with open('marksman.json','rb') as f:
    Marksman=json.load(f)
with open('tank.json','rb') as f:
    Tank=json.load(f)

# %%
Slayer
# Out:
# ['nocturne',
#  'nidalee',
#  'rengar',
#  'leblanc',
#  'lee-sin',
#  'riven',
#  'master-yi',
#  'malzahar',
#  'vi',
#  'vayne',
#  'sylas',
#  'shaco',
#  'xin-zhao',
#  'ahri',
#  'akali',
#  'yasuo',
#  'ekko',
#  'yone',
#  'irelia',
#  'evelynn',
#  'jax',
#  'zed',
#  'kassadin',
#  'kha-zix',
#  'katarina',
#  'kayn',
#  'quinn',
#  'qiyana',
#  'talon',
#  'tristana',
#  'tryndamere',
#  'twitch',
#  'teemo',
#  'pyke',
#  'pantheon',
#  'fiora',
#  'fizz']

# %%
len(set(champ))
# Out:
# 152

# %%
with open('Gameinfo_0_to_48336.pickle','rb') as f:# 하나씩만 열어야함 잘못하면 메모리 터짐
    data=pickle.load(f)

# %%
data
# Out:
#         gameId   gameCreation gameDuration queueId     gameVersion  \
# 0   4762724097  1604534051182         1406     420   10.22.341.643
# 0   4762762998  1604532427821         1221     420   10.22.341.643
# 0   4762702321  1604529701521         1966     420   10.22.341.643
# 0   4762671911  1604527685414         1489     420   10.22.341.643
# 0   4762680943  1604525332197         1412     420   10.22.341.643
# ..         ...            ...          ...     ...             ...
# 0   4735691195  1603449513662         1391     420  10.21.339.2173
# 0   4735625888  1603447957810         1219     420  10.21.339.2173
# 0   4735405216  1603443390386         1409     420  10.21.339.2173
# 0   4735056589  1603437452224         2011     420  10.21.339.2173
# 0   4734947923  1603433671390         1809     420  10.21.339.2173
#
#                                                 teams  \
# 0   [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 0   [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 0   [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 0   [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 0   [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# ..                                                ...
# 0   [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 0   [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 0   [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 0   [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 0   [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
#
#                                          participants  \
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# ..                                                ...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
# 0   [{'participantId': 1, 'teamId': 100, 'champion...
#
#                                 participantIdentities
# 0   [{'participantId': 1, 'player': {'platformId':...
# 0   [{'participantId': 1, 'player': {'platformId':...
# 0   [{'participantId': 1, 'player': {'platformId':...
# 0   [{'participantId': 1, 'player': {'platformId':...
# 0   [{'participantId': 1, 'player': {'platformId':...
# ..                                                ...
# 0   [{'participantId': 1, 'player': {'platformId':...
# 0   [{'participantId': 1, 'player': {'platformId':...
# 0   [{'participantId': 1, 'player': {'platformId':...
# 0   [{'participantId': 1, 'player': {'platformId':...
# 0   [{'participantId': 1, 'player': {'platformId':...
#
# [34565 rows x 8 columns]

# %%
tmp=[i for i in range(len(data))]

# %%
data.index=range(len(data))

# %%
data
# Out:
#            gameId   gameCreation gameDuration queueId     gameVersion  \
# 0      4762724097  1604534051182         1406     420   10.22.341.643
# 1      4762762998  1604532427821         1221     420   10.22.341.643
# 2      4762702321  1604529701521         1966     420   10.22.341.643
# 3      4762671911  1604527685414         1489     420   10.22.341.643
# 4      4762680943  1604525332197         1412     420   10.22.341.643
# ...           ...            ...          ...     ...             ...
# 34560  4735691195  1603449513662         1391     420  10.21.339.2173
# 34561  4735625888  1603447957810         1219     420  10.21.339.2173
# 34562  4735405216  1603443390386         1409     420  10.21.339.2173
# 34563  4735056589  1603437452224         2011     420  10.21.339.2173
# 34564  4734947923  1603433671390         1809     420  10.21.339.2173
#
#                                                    teams  \
# 0      [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1      [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# 2      [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 3      [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 4      [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# ...                                                  ...
# 34560  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 34561  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 34562  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 34563  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 34564  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
#
#                                             participants  \
# 0      [{'participantId': 1, 'teamId': 100, 'champion...
# 1      [{'participantId': 1, 'teamId': 100, 'champion...
# 2      [{'participantId': 1, 'teamId': 100, 'champion...
# 3      [{'participantId': 1, 'teamId': 100, 'champion...
# 4      [{'participantId': 1, 'teamId': 100, 'champion...
# ...                                                  ...
# 34560  [{'participantId': 1, 'teamId': 100, 'champion...
# 34561  [{'participantId': 1, 'teamId': 100, 'champion...
# 34562  [{'participantId': 1, 'teamId': 100, 'champion...
# 34563  [{'participantId': 1, 'teamId': 100, 'champion...
# 34564  [{'participantId': 1, 'teamId': 100, 'champion...
#
#                                    participantIdentities
# 0      [{'participantId': 1, 'player': {'platformId':...
# 1      [{'participantId': 1, 'player': {'platformId':...
# 2      [{'participantId': 1, 'player': {'platformId':...
# 3      [{'participantId': 1, 'player': {'platformId':...
# 4      [{'participantId': 1, 'player': {'platformId':...
# ...                                                  ...
# 34560  [{'participantId': 1, 'player': {'platformId':...
# 34561  [{'participantId': 1, 'player': {'platformId':...
# 34562  [{'participantId': 1, 'player': {'platformId':...
# 34563  [{'participantId': 1, 'player': {'platformId':...
# 34564  [{'participantId': 1, 'player': {'platformId':...
#
# [34565 rows x 8 columns]

# %%
with open('')

# %%
data['participants'][1]
# Out:
# [{'participantId': 1,
#   'teamId': 100,
#   'championId': 201,
#   'spell1Id': 14,
#   'spell2Id': 4,
#   'stats': {'participantId': 1,
#    'win': True,
#    'item0': 3801,
#    'item1': 3857,
#    'item2': 3114,
#    'item3': 3109,
#    'item4': 2055,
#    'item5': 3009,
#    'item6': 3364,
#    'kills': 0,
#    'deaths': 3,
#    'assists': 19,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 0,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 908,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 22752,
#    'magicDamageDealt': 7144,
#    'physicalDamageDealt': 8099,
#    'trueDamageDealt': 7507,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 6167,
#    'magicDamageDealtToChampions': 4210,
#    'physicalDamageDealtToChampions': 1539,
#    'trueDamageDealtToChampions': 418,
#    'totalHeal': 963,
#    'totalUnitsHealed': 4,
#    'damageSelfMitigated': 11448,
#    'damageDealtToObjectives': 1395,
#    'damageDealtToTurrets': 1395,
#    'visionScore': 36,
#    'timeCCingOthers': 23,
#    'totalDamageTaken': 11449,
#    'magicalDamageTaken': 3997,
#    'physicalDamageTaken': 7183,
#    'trueDamageTaken': 268,
#    'goldEarned': 6381,
#    'goldSpent': 5350,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 29,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 95,
#    'champLevel': 10,
#    'visionWardsBoughtInGame': 4,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 13,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 1,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8465,
#    'perk0Var1': 1548,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8463,
#    'perk1Var1': 730,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8473,
#    'perk2Var1': 501,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8242,
#    'perk3Var1': 27,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8316,
#    'perk4Var1': 638,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8313,
#    'perk5Var1': 0,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8400,
#    'perkSubStyle': 8300,
#    'statPerk0': 5005,
#    'statPerk1': 5002,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 1,
#    'creepsPerMinDeltas': {'10-20': 1, '0-10': 1.8},
#    'xpPerMinDeltas': {'10-20': 416.1, '0-10': 268.1},
#    'goldPerMinDeltas': {'10-20': 359.5, '0-10': 216.5},
#    'damageTakenPerMinDeltas': {'10-20': 841.9, '0-10': 288.1},
#    'role': 'DUO_SUPPORT',
#    'lane': 'BOTTOM'}},
#  {'participantId': 2,
#   'teamId': 100,
#   'championId': 81,
#   'spell1Id': 7,
#   'spell2Id': 4,
#   'stats': {'participantId': 2,
#    'win': True,
#    'item0': 3042,
#    'item1': 1053,
#    'item2': 3025,
#    'item3': 3133,
#    'item4': 1054,
#    'item5': 3158,
#    'item6': 3363,
#    'kills': 6,
#    'deaths': 3,
#    'assists': 7,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 495,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 101970,
#    'magicDamageDealt': 10288,
#    'physicalDamageDealt': 90660,
#    'trueDamageDealt': 1022,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 11403,
#    'magicDamageDealtToChampions': 2712,
#    'physicalDamageDealtToChampions': 8317,
#    'trueDamageDealtToChampions': 374,
#    'totalHeal': 1581,
#    'totalUnitsHealed': 4,
#    'damageSelfMitigated': 4024,
#    'damageDealtToObjectives': 5560,
#    'damageDealtToTurrets': 5201,
#    'visionScore': 9,
#    'timeCCingOthers': 4,
#    'totalDamageTaken': 7739,
#    'magicalDamageTaken': 1929,
#    'physicalDamageTaken': 5639,
#    'trueDamageTaken': 170,
#    'goldEarned': 10262,
#    'goldSpent': 9100,
#    'turretKills': 2,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 154,
#    'neutralMinionsKilled': 15,
#    'neutralMinionsKilledTeamJungle': 6,
#    'neutralMinionsKilledEnemyJungle': 4,
#    'totalTimeCrowdControlDealt': 123,
#    'champLevel': 11,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 6,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': True,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 1,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8010,
#    'perk0Var1': 29,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8009,
#    'perk1Var1': 3543,
#    'perk1Var2': 500,
#    'perk1Var3': 0,
#    'perk2': 9103,
#    'perk2Var1': 19,
#    'perk2Var2': 30,
#    'perk2Var3': 0,
#    'perk3': 8014,
#    'perk3Var1': 193,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8345,
#    'perk4Var1': 3,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8347,
#    'perk5Var1': 0,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8300,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 2,
#    'creepsPerMinDeltas': {'10-20': 8.9, '0-10': 6.4},
#    'xpPerMinDeltas': {'10-20': 526.7, '0-10': 242},
#    'goldPerMinDeltas': {'10-20': 660.4000000000001, '0-10': 305},
#    'damageTakenPerMinDeltas': {'10-20': 426.4, '0-10': 339.9},
#    'role': 'DUO_CARRY',
#    'lane': 'BOTTOM'}},
#  {'participantId': 3,
#   'teamId': 100,
#   'championId': 98,
#   'spell1Id': 12,
#   'spell2Id': 4,
#   'stats': {'participantId': 3,
#    'win': True,
#    'item0': 0,
#    'item1': 2055,
#    'item2': 3067,
#    'item3': 3211,
#    'item4': 3068,
#    'item5': 3111,
#    'item6': 3364,
#    'kills': 2,
#    'deaths': 1,
#    'assists': 10,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 2,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 1210,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 54934,
#    'magicDamageDealt': 23040,
#    'physicalDamageDealt': 19989,
#    'trueDamageDealt': 11904,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 6901,
#    'magicDamageDealtToChampions': 2672,
#    'physicalDamageDealtToChampions': 3919,
#    'trueDamageDealtToChampions': 309,
#    'totalHeal': 473,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 21775,
#    'damageDealtToObjectives': 5971,
#    'damageDealtToTurrets': 714,
#    'visionScore': 9,
#    'timeCCingOthers': 22,
#    'totalDamageTaken': 16442,
#    'magicalDamageTaken': 6710,
#    'physicalDamageTaken': 9616,
#    'trueDamageTaken': 114,
#    'goldEarned': 6977,
#    'goldSpent': 6500,
#    'turretKills': 0,
#    'inhibitorKills': 1,
#    'totalMinionsKilled': 118,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 196,
#    'champLevel': 12,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 1,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': True,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 1,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8437,
#    'perk0Var1': 819,
#    'perk0Var2': 575,
#    'perk0Var3': 0,
#    'perk1': 8401,
#    'perk1Var1': 426,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8444,
#    'perk2Var1': 1430,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8451,
#    'perk3Var1': 156,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8126,
#    'perk4Var1': 372,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8106,
#    'perk5Var1': 5,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8400,
#    'perkSubStyle': 8100,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5003},
#   'timeline': {'participantId': 3,
#    'creepsPerMinDeltas': {'10-20': 5, '0-10': 6.8},
#    'xpPerMinDeltas': {'10-20': 480.20000000000005, '0-10': 455.1},
#    'goldPerMinDeltas': {'10-20': 385, '0-10': 253.3},
#    'csDiffPerMinDeltas': {'10-20': -1.3000000000000003,
#     '0-10': 0.7999999999999998},
#    'xpDiffPerMinDeltas': {'10-20': 89.50000000000001,
#     '0-10': 15.099999999999994},
#    'damageTakenPerMinDeltas': {'10-20': 945, '0-10': 536},
#    'damageTakenDiffPerMinDeltas': {'10-20': 270.3, '0-10': 144.29999999999998},
#    'role': 'SOLO',
#    'lane': 'TOP'}},
#  {'participantId': 4,
#   'teamId': 100,
#   'championId': 246,
#   'spell1Id': 4,
#   'spell2Id': 14,
#   'stats': {'participantId': 4,
#    'win': True,
#    'item0': 3142,
#    'item1': 3147,
#    'item2': 2033,
#    'item3': 3009,
#    'item4': 3044,
#    'item5': 0,
#    'item6': 3364,
#    'kills': 12,
#    'deaths': 2,
#    'assists': 7,
#    'largestKillingSpree': 8,
#    'largestMultiKill': 2,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 679,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 89337,
#    'magicDamageDealt': 4221,
#    'physicalDamageDealt': 80545,
#    'trueDamageDealt': 4569,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 21097,
#    'magicDamageDealtToChampions': 1001,
#    'physicalDamageDealtToChampions': 19402,
#    'trueDamageDealtToChampions': 694,
#    'totalHeal': 3354,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 5101,
#    'damageDealtToObjectives': 6597,
#    'damageDealtToTurrets': 3636,
#    'visionScore': 15,
#    'timeCCingOthers': 19,
#    'totalDamageTaken': 10507,
#    'magicalDamageTaken': 4469,
#    'physicalDamageTaken': 5723,
#    'trueDamageTaken': 314,
#    'goldEarned': 10796,
#    'goldSpent': 8825,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 145,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 61,
#    'champLevel': 12,
#    'visionWardsBoughtInGame': 6,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 8,
#    'wardsKilled': 3,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 1,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8112,
#    'perk0Var1': 774,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8143,
#    'perk1Var1': 682,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8135,
#    'perk3Var1': 2438,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8345,
#    'perk4Var1': 3,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8352,
#    'perk5Var1': 265,
#    'perk5Var2': 1135,
#    'perk5Var3': 875,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8300,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5003},
#   'timeline': {'participantId': 4,
#    'creepsPerMinDeltas': {'10-20': 7.1, '0-10': 7.199999999999999},
#    'xpPerMinDeltas': {'10-20': 492.1, '0-10': 458.20000000000005},
#    'goldPerMinDeltas': {'10-20': 561.7, '0-10': 443.1},
#    'csDiffPerMinDeltas': {'10-20': 0.8999999999999995,
#     '0-10': 0.7999999999999998},
#    'xpDiffPerMinDeltas': {'10-20': 92.89999999999998,
#     '0-10': 54.70000000000002},
#    'damageTakenPerMinDeltas': {'10-20': 569.5, '0-10': 429.6},
#    'damageTakenDiffPerMinDeltas': {'10-20': -419.1,
#     '0-10': -140.80000000000004},
#    'role': 'SOLO',
#    'lane': 'MIDDLE'}},
#  {'participantId': 5,
#   'teamId': 100,
#   'championId': 76,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 5,
#    'win': True,
#    'item0': 1414,
#    'item1': 2055,
#    'item2': 3157,
#    'item3': 2422,
#    'item4': 3057,
#    'item5': 3174,
#    'item6': 3364,
#    'kills': 9,
#    'deaths': 3,
#    'assists': 12,
#    'largestKillingSpree': 6,
#    'largestMultiKill': 2,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 322,
#    'doubleKills': 2,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 149041,
#    'magicDamageDealt': 121325,
#    'physicalDamageDealt': 19288,
#    'trueDamageDealt': 8427,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 14386,
#    'magicDamageDealtToChampions': 11877,
#    'physicalDamageDealtToChampions': 1453,
#    'trueDamageDealtToChampions': 1055,
#    'totalHeal': 14759,
#    'totalUnitsHealed': 5,
#    'damageSelfMitigated': 11796,
#    'damageDealtToObjectives': 24548,
#    'damageDealtToTurrets': 7924,
#    'visionScore': 22,
#    'timeCCingOthers': 5,
#    'totalDamageTaken': 18614,
#    'magicalDamageTaken': 4499,
#    'physicalDamageTaken': 13380,
#    'trueDamageTaken': 734,
#    'goldEarned': 10687,
#    'goldSpent': 9075,
#    'turretKills': 5,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 38,
#    'neutralMinionsKilled': 115,
#    'neutralMinionsKilledTeamJungle': 48,
#    'neutralMinionsKilledEnemyJungle': 37,
#    'totalTimeCrowdControlDealt': 150,
#    'champLevel': 13,
#    'visionWardsBoughtInGame': 5,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 6,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 1,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 963,
#    'perk0Var2': 14,
#    'perk0Var3': 0,
#    'perk1': 8143,
#    'perk1Var1': 391,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 30,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8135,
#    'perk3Var1': 3930,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8347,
#    'perk4Var1': 0,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8304,
#    'perk5Var1': 8,
#    'perk5Var2': 1,
#    'perk5Var3': 5,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8300,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 5,
#    'creepsPerMinDeltas': {'10-20': 3.3, '0-10': 0.2},
#    'xpPerMinDeltas': {'10-20': 660.3, '0-10': 360},
#    'goldPerMinDeltas': {'10-20': 651.4, '0-10': 353.70000000000005},
#    'damageTakenPerMinDeltas': {'10-20': 1040.5, '0-10': 723.4000000000001},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'participantId': 6,
#   'teamId': 200,
#   'championId': 80,
#   'spell1Id': 14,
#   'spell2Id': 4,
#   'stats': {'participantId': 6,
#    'win': False,
#    'item0': 3855,
#    'item1': 2031,
#    'item2': 1001,
#    'item3': 3179,
#    'item4': 1036,
#    'item5': 2055,
#    'item6': 3364,
#    'kills': 1,
#    'deaths': 9,
#    'assists': 5,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 221,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 18348,
#    'magicDamageDealt': 1477,
#    'physicalDamageDealt': 11750,
#    'trueDamageDealt': 5121,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 6973,
#    'magicDamageDealtToChampions': 162,
#    'physicalDamageDealtToChampions': 5908,
#    'trueDamageDealtToChampions': 902,
#    'totalHeal': 430,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 5310,
#    'damageDealtToObjectives': 0,
#    'damageDealtToTurrets': 0,
#    'visionScore': 28,
#    'timeCCingOthers': 17,
#    'totalDamageTaken': 13595,
#    'magicalDamageTaken': 6282,
#    'physicalDamageTaken': 6848,
#    'trueDamageTaken': 464,
#    'goldEarned': 4697,
#    'goldSpent': 3850,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 29,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 56,
#    'champLevel': 8,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 15,
#    'wardsKilled': 7,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8010,
#    'perk0Var1': 102,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8009,
#    'perk1Var1': 169,
#    'perk1Var2': 500,
#    'perk1Var3': 0,
#    'perk2': 9105,
#    'perk2Var1': 0,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8014,
#    'perk3Var1': 71,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8126,
#    'perk4Var1': 297,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8136,
#    'perk5Var1': 10,
#    'perk5Var2': 30,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8100,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 6,
#    'creepsPerMinDeltas': {'10-20': 1.8, '0-10': 1.1},
#    'xpPerMinDeltas': {'10-20': 292.1, '0-10': 189.7},
#    'goldPerMinDeltas': {'10-20': 206.3, '0-10': 163.4},
#    'damageTakenPerMinDeltas': {'10-20': 945.3, '0-10': 356.6},
#    'role': 'SOLO',
#    'lane': 'BOTTOM'}},
#  {'participantId': 7,
#   'teamId': 200,
#   'championId': 117,
#   'spell1Id': 12,
#   'spell2Id': 4,
#   'stats': {'participantId': 7,
#    'win': False,
#    'item0': 2033,
#    'item1': 3174,
#    'item2': 3222,
#    'item3': 3009,
#    'item4': 1004,
#    'item5': 1004,
#    'item6': 3340,
#    'kills': 0,
#    'deaths': 4,
#    'assists': 6,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 0,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 514,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 66576,
#    'magicDamageDealt': 46363,
#    'physicalDamageDealt': 12048,
#    'trueDamageDealt': 8165,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 9434,
#    'magicDamageDealtToChampions': 7334,
#    'physicalDamageDealtToChampions': 2100,
#    'trueDamageDealtToChampions': 0,
#    'totalHeal': 2233,
#    'totalUnitsHealed': 3,
#    'damageSelfMitigated': 7737,
#    'damageDealtToObjectives': 1234,
#    'damageDealtToTurrets': 752,
#    'visionScore': 6,
#    'timeCCingOthers': 28,
#    'totalDamageTaken': 11114,
#    'magicalDamageTaken': 2951,
#    'physicalDamageTaken': 7924,
#    'trueDamageTaken': 238,
#    'goldEarned': 6222,
#    'goldSpent': 5850,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 123,
#    'neutralMinionsKilled': 2,
#    'neutralMinionsKilledTeamJungle': 1,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 361,
#    'champLevel': 11,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8214,
#    'perk0Var1': 914,
#    'perk0Var2': 250,
#    'perk0Var3': 0,
#    'perk1': 8226,
#    'perk1Var1': 250,
#    'perk1Var2': 673,
#    'perk1Var3': 0,
#    'perk2': 8210,
#    'perk2Var1': 0,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8237,
#    'perk3Var1': 369,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8345,
#    'perk4Var1': 3,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8352,
#    'perk5Var1': 250,
#    'perk5Var2': 1268,
#    'perk5Var3': 965,
#    'perkPrimaryStyle': 8200,
#    'perkSubStyle': 8300,
#    'statPerk0': 5005,
#    'statPerk1': 5002,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 7,
#    'creepsPerMinDeltas': {'10-20': 6.300000000000001, '0-10': 6},
#    'xpPerMinDeltas': {'10-20': 390.7, '0-10': 440},
#    'goldPerMinDeltas': {'10-20': 300.6, '0-10': 262.2},
#    'csDiffPerMinDeltas': {'10-20': 1.3000000000000003,
#     '0-10': -0.7999999999999998},
#    'xpDiffPerMinDeltas': {'10-20': -89.50000000000001,
#     '0-10': -15.099999999999994},
#    'damageTakenPerMinDeltas': {'10-20': 674.7, '0-10': 391.70000000000005},
#    'damageTakenDiffPerMinDeltas': {'10-20': -270.3,
#     '0-10': -144.29999999999998},
#    'role': 'SOLO',
#    'lane': 'TOP'}},
#  {'participantId': 8,
#   'teamId': 200,
#   'championId': 517,
#   'spell1Id': 12,
#   'spell2Id': 4,
#   'stats': {'participantId': 8,
#    'win': False,
#    'item0': 3030,
#    'item1': 2033,
#    'item2': 3157,
#    'item3': 1082,
#    'item4': 1056,
#    'item5': 3158,
#    'item6': 3364,
#    'kills': 4,
#    'deaths': 5,
#    'assists': 3,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 2,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 407,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 69941,
#    'magicDamageDealt': 62636,
#    'physicalDamageDealt': 7169,
#    'trueDamageDealt': 135,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 11810,
#    'magicDamageDealtToChampions': 10527,
#    'physicalDamageDealtToChampions': 1148,
#    'trueDamageDealtToChampions': 135,
#    'totalHeal': 2299,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 9682,
#    'damageDealtToObjectives': 1646,
#    'damageDealtToTurrets': 179,
#    'visionScore': 17,
#    'timeCCingOthers': 21,
#    'totalDamageTaken': 16152,
#    'magicalDamageTaken': 5516,
#    'physicalDamageTaken': 9791,
#    'trueDamageTaken': 844,
#    'goldEarned': 8193,
#    'goldSpent': 8000,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 126,
#    'neutralMinionsKilled': 5,
#    'neutralMinionsKilledTeamJungle': 1,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 289,
#    'champLevel': 11,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8010,
#    'perk0Var1': 425,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8009,
#    'perk1Var1': 1049,
#    'perk1Var2': 500,
#    'perk1Var3': 0,
#    'perk2': 9105,
#    'perk2Var1': 17,
#    'perk2Var2': 40,
#    'perk2Var3': 0,
#    'perk3': 8299,
#    'perk3Var1': 306,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8345,
#    'perk4Var1': 3,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8347,
#    'perk5Var1': 0,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8300,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 8,
#    'creepsPerMinDeltas': {'10-20': 6.2, '0-10': 6.4},
#    'xpPerMinDeltas': {'10-20': 399.20000000000005, '0-10': 403.5},
#    'goldPerMinDeltas': {'10-20': 464, '0-10': 295.9},
#    'csDiffPerMinDeltas': {'10-20': -0.8999999999999995,
#     '0-10': -0.7999999999999998},
#    'xpDiffPerMinDeltas': {'10-20': -92.89999999999998,
#     '0-10': -54.70000000000002},
#    'damageTakenPerMinDeltas': {'10-20': 988.5999999999999,
#     '0-10': 570.4000000000001},
#    'damageTakenDiffPerMinDeltas': {'10-20': 419.1, '0-10': 140.80000000000004},
#    'role': 'SOLO',
#    'lane': 'MIDDLE'}},
#  {'participantId': 9,
#   'teamId': 200,
#   'championId': 5,
#   'spell1Id': 11,
#   'spell2Id': 4,
#   'stats': {'participantId': 9,
#    'win': False,
#    'item0': 1412,
#    'item1': 1001,
#    'item2': 3057,
#    'item3': 2055,
#    'item4': 3101,
#    'item5': 1028,
#    'item6': 3364,
#    'kills': 3,
#    'deaths': 8,
#    'assists': 5,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 243,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 61009,
#    'magicDamageDealt': 6095,
#    'physicalDamageDealt': 53418,
#    'trueDamageDealt': 1494,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 7456,
#    'magicDamageDealtToChampions': 790,
#    'physicalDamageDealtToChampions': 6101,
#    'trueDamageDealtToChampions': 564,
#    'totalHeal': 7708,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 7494,
#    'damageDealtToObjectives': 7698,
#    'damageDealtToTurrets': 0,
#    'visionScore': 13,
#    'timeCCingOthers': 13,
#    'totalDamageTaken': 19017,
#    'magicalDamageTaken': 6153,
#    'physicalDamageTaken': 12120,
#    'trueDamageTaken': 743,
#    'goldEarned': 6045,
#    'goldSpent': 5775,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 13,
#    'neutralMinionsKilled': 63,
#    'neutralMinionsKilledTeamJungle': 38,
#    'neutralMinionsKilledEnemyJungle': 13,
#    'totalTimeCrowdControlDealt': 156,
#    'champLevel': 9,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 2,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8230,
#    'perk0Var1': 14,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8275,
#    'perk1Var1': 12,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8234,
#    'perk2Var1': 5023,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8232,
#    'perk3Var1': 2,
#    'perk3Var2': 20,
#    'perk3Var3': 0,
#    'perk4': 9111,
#    'perk4Var1': 333,
#    'perk4Var2': 160,
#    'perk4Var3': 0,
#    'perk5': 9104,
#    'perk5Var1': 12,
#    'perk5Var2': 20,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8200,
#    'perkSubStyle': 8000,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5003},
#   'timeline': {'participantId': 9,
#    'creepsPerMinDeltas': {'10-20': 0.9, '0-10': 0.4},
#    'xpPerMinDeltas': {'10-20': 274.9, '0-10': 303.4},
#    'goldPerMinDeltas': {'10-20': 231.5, '0-10': 318.6},
#    'damageTakenPerMinDeltas': {'10-20': 1039, '0-10': 812.9000000000001},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'participantId': 10,
#   'teamId': 200,
#   'championId': 145,
#   'spell1Id': 4,
#   'spell2Id': 7,
#   'stats': {'participantId': 10,
#    'win': False,
#    'item0': 3006,
#    'item1': 3004,
#    'item2': 3124,
#    'item3': 1042,
#    'item4': 0,
#    'item5': 1055,
#    'item6': 3363,
#    'kills': 4,
#    'deaths': 3,
#    'assists': 3,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 2,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 517,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 78303,
#    'magicDamageDealt': 7174,
#    'physicalDamageDealt': 67650,
#    'trueDamageDealt': 3478,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 6516,
#    'magicDamageDealtToChampions': 1779,
#    'physicalDamageDealtToChampions': 4736,
#    'trueDamageDealtToChampions': 0,
#    'totalHeal': 2215,
#    'totalUnitsHealed': 3,
#    'damageSelfMitigated': 4745,
#    'damageDealtToObjectives': 2228,
#    'damageDealtToTurrets': 0,
#    'visionScore': 12,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 12663,
#    'magicalDamageTaken': 3616,
#    'physicalDamageTaken': 8486,
#    'trueDamageTaken': 560,
#    'goldEarned': 7868,
#    'goldSpent': 7750,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 163,
#    'neutralMinionsKilled': 10,
#    'neutralMinionsKilledTeamJungle': 10,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 0,
#    'champLevel': 11,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 7,
#    'wardsKilled': 3,
#    'firstBloodKill': True,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 9923,
#    'perk0Var1': 41,
#    'perk0Var2': 75,
#    'perk0Var3': 0,
#    'perk1': 8139,
#    'perk1Var1': 497,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 8,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8135,
#    'perk3Var1': 681,
#    'perk3Var2': 4,
#    'perk3Var3': 0,
#    'perk4': 8009,
#    'perk4Var1': 885,
#    'perk4Var2': 500,
#    'perk4Var3': 0,
#    'perk5': 9103,
#    'perk5Var1': 0,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8000,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 10,
#    'creepsPerMinDeltas': {'10-20': 10.1, '0-10': 6.199999999999999},
#    'xpPerMinDeltas': {'10-20': 490.1, '0-10': 267.2},
#    'goldPerMinDeltas': {'10-20': 363.2, '0-10': 364.2},
#    'damageTakenPerMinDeltas': {'10-20': 835.2, '0-10': 324.3},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}}]

# %%
for i in data['participants'][5]:
    print(i['timeline']['lane'])
# Out:
# BOTTOM
# BOTTOM
# MIDDLE
# JUNGLE
# TOP
# BOTTOM
# MIDDLE
# TOP
# MIDDLE
# JUNGLE
